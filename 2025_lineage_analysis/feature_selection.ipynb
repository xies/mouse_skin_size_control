# %% [markdown]
# # Content
# Random forest classifier models of Dividing v. Differentiating cells
# 1. Model of birth frame
# 2. Model of mother division frame
# 3. Model of mother division frame - group 1diff and 2diff daughters
# 4. Model of mother division frame -12h

# %% [markdown]
# ## 0. Load datasets

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection
from sklearn import ensemble, metrics, inspection

def get_balanced_df_by_category(df,category):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member)
        else:
            output.append(member.sample(num_per_category.min()))
    output = pd.concat(output,ignore_index=True)

    return output
    
def predict_feature(df:pd.DataFrame,
                    classifier,
                    feature2predict,
                    Niter:int=100,
                    rebalance:bool=True,
                    subsample=None):
    if subsample == None:
        subsample = len(df)
    Y_test = []
    Y_pred = []
    forests = []
    for i in tqdm(range(Niter)):
        
        df_ = get_balanced_df_by_category(df, df[feature2predict,'Meta'].values)
        
        y = df_[feature2predict,'Meta'].astype(float)
        X = df_.xs('Measurement',level=1,axis=1).astype(float)
        X = preprocessing.scale(X)
        
        X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y)
        
        model = classifier.fit(X_train,y_train)
        forests.append(model)
        
        Y_test.append(y_test)
        Y_pred.append(model.predict(X_test))
        
    return [np.stack((np.array(Y_test),np.array(Y_pred))),forests]

# %%
dirnames = {'R1':'/Users/xies/OneDrive - Stanford/Skin/Mesa et al/W-R1/',
           'R2':'/Users/xies/OneDrive - Stanford/Skin/Mesa et al/W-R2/'}
all_df = []
for name,dirname in dirnames.items():
    _df = pd.read_pickle(path.join(dirname,'Mastodon/single_timepoints_dynamics_aggregated_lookback_history.pkl'))
    _df = _df.drop_duplicates().sort_index().reset_index()
    _df['TrackID'] = name + '_' + _df['TrackID'].astype(str)
    _df = _df.set_index(['Frame','TrackID'])
    _df['Region'] = name
    all_df.append(_df)

all_df = pd.concat(all_df)
all_tracks = {trackID:t for trackID,t in all_df.reset_index().groupby('TrackID')}

# %%
len(all_tracks)
# Out:
# 2323

# %% [markdown]
# ### Isolate specific time points

# %%
df = all_df[all_df['Fate known','Meta']]
df = df[ ~df['Border','Meta'].astype(bool)]
df = df[ df['Cell type','Meta'] == 'Basal']

births = df[df['Birth frame','Meta']]
births_raw = births.copy()
print(f'Number of births: {len(births)}')

df = all_df[~np.isnan(all_df['Both daughters differentiated','Meta'].astype(float))]
df = df[ ~df['Border','Meta'].astype(bool)]
df = df[ df['Cell type','Meta'] == 'Basal']

divisions = df[df[('Divide next frame','Meta')]].copy()
divisions = divisions[~divisions['Border','Meta'].astype(bool)]
divisions = divisions.reset_index()
print(f'Number of mother divisions: {len(divisions)}')

prev_div_frame = [get_prev_or_next_frame(df,f,direction='prev') for _,f in divisions.iterrows()]
prev_div_frame = pd.concat(prev_div_frame,axis=1,ignore_index=False).T
#@todo: investigate efficiency of force-casting at different points
for col in df.columns:
    prev_div_frame[col] = prev_div_frame[col].astype(df[col].dtype)
prev_div_frame = prev_div_frame[~prev_div_frame['Border','Meta'].astype(bool)]
prev_div_frame = prev_div_frame.reset_index().rename(columns={'level_0':'Frame','level_1':'TrackID'}).set_index('TrackID')
print(f'Number of 12h prior to divisions: {len(prev_div_frame)}')

prev2_div_frame = [get_prev_or_next_frame(all_df,f,direction='prev', increment=2) for _,f in divisions.iterrows()]
prev2_div_frame = pd.concat(prev2_div_frame,axis=1).T
prev2_div_frame = prev2_div_frame[~prev2_div_frame['Border','Meta'].astype(bool)]
for col in df.columns:
    prev2_div_frame[col] = prev2_div_frame[col].astype(df[col].dtype)
print(f'Number of 24h prior to divisions: {len(prev2_div_frame)}')

prev3_div_frame = [get_prev_or_next_frame(all_df,f,direction='prev', increment=3) for _,f in divisions.iterrows()]
prev3_div_frame = pd.concat(prev3_div_frame,axis=1).T
prev3_div_frame = prev3_div_frame[~prev3_div_frame['Border','Meta'].astype(bool)]
for col in df.columns:
    prev3_div_frame[col] = prev3_div_frame[col].astype(df[col].dtype)
print(f'Number of 36h prior to divisions: {len(prev3_div_frame)}')

prev4_div_frame = [get_prev_or_next_frame(all_df,f,direction='prev', increment=4) for _,f in divisions.iterrows()]
prev4_div_frame = pd.concat(prev4_div_frame,axis=1).T
prev4_div_frame = prev4_div_frame[~prev4_div_frame['Border','Meta'].astype(bool)]
for col in df.columns:
    prev4_div_frame[col] = prev4_div_frame[col].astype(df[col].dtype)
print(f'Number of 48h prior to divisions: {len(prev4_div_frame)}')
# Out:
# Number of births: 764
# Number of mother divisions: 307
# Number of 12h prior to divisions: 243
# Number of 24h prior to divisions: 206
# Number of 36h prior to divisions: 157
# Number of 48h prior to divisions: 115

# %%
# Censor age / time til diff
features2drop = [f for f in births.columns.get_level_values(0) if 'Time to differentiation' in f]
features2drop += [f for f in births.columns.get_level_values(0) if 'Age' in f]
# Censor height information
features2drop = features2drop + ['Z','Mean curvature - cell coords','Z-cyto','Height to BM',
                                 'Basal area','Apical area','Relative Height to BM','Relative Height to BM at 1 frame prior']
# Censor all exponential rates (but not mother's)
features2drop = features2drop + [f for f in births.columns.get_level_values(0)
                                 if ('exponential' in f and 'frame prior' not in f \
                                         and 'G1' not in f)]

np.isnan(births['Cell volume G1 only exponential growth rate']).sum()
# Out:
# Metadata
# Measurement    348
# dtype: int64

# %%
metas = pd.DataFrame()
metas['name'] = births.xs('Meta',level=1,axis=1).columns
features = pd.DataFrame()

measurements = births.xs('Measurement',level=1,axis=1)
features['name'] = measurements.columns
features =features.set_index('name')
features['Num NA'] = measurements.isna().sum(axis=0)
feature_names = features.index
num_nas = (features['Num NA'] > 0).sum()

# print(f'Number of features with NAs: {num_nas}')
# print(features.sort_values('Num NA').tail(50))

# Set the acceptable number of NAs (will be dropped)
na_thresh = 350
features2drop += features[features['Num NA'] > na_thresh].index.values.tolist()

births = births.drop(columns=features2drop)
divisions = divisions.drop(columns=features2drop)
prev_div_frame = prev_div_frame.drop(columns=features2drop)
prev2_div_frame = prev2_div_frame.drop(columns=features2drop)
# Out:
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_5967/2971050117.py:19: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   births = births.drop(columns=features2drop)
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_5967/2971050117.py:20: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   divisions = divisions.drop(columns=features2drop)
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_5967/2971050117.py:21: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prev_div_frame = prev_div_frame.drop(columns=features2drop)
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_5967/2971050117.py:22: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prev2_div_frame = prev2_div_frame.drop(columns=features2drop)

# %%
conservative_feature_set
# Out:
# Index(['Nuclear volume', 'Nuclear solidity', 'Y', 'X', 'Nuclear height',
#        'Cell volume', 'Y-cyto', 'X-cyto', 'Axial component',
#        'Planar component 1',
#        ...
#        'Relative nuc_shcoeffs_L4M4S', 'Relative nuc_shcoeffs_L5M1S',
#        'Relative nuc_shcoeffs_L5M2S', 'Relative nuc_shcoeffs_L5M3S',
#        'Relative nuc_shcoeffs_L5M4S', 'Relative nuc_shcoeffs_L5M5S',
#        'Relative nuc_shcoeffs_surface_area',
#        'Relative Distance to closest macrophage',
#        'Relative Nuclear volume standard', 'Relative Cell volume standard'],
#       dtype='object', name='Name', length=753)

# %%
# Drop the NA samples and update the leftover features list

births = births.dropna(axis=0,subset=[(a,b) for (a,b) in births.columns if b == 'Measurement'], how='any')
divisions = divisions.dropna(axis=1)
prev_div_frame = prev_div_frame.dropna(axis=1)
prev2_div_frame = prev2_div_frame.dropna(axis=1)

print('---')
print(f'Number of births: {len(births)}')
print(f'Number of mother divisions: {len(divisions)}')
print(f'Number of 12h prior to divisions: {len(prev_div_frame)}')
print(f'Number of 24h prior to divisions: {len(prev2_div_frame)}')

print('---')
print(f'Births: {len(births.columns)} features')
print(f'Mother divisions: {len(divisions.columns)} features')
print(f'12h prior to divisions: {len(prev_div_frame.columns)} features')
print(f'24h prior to divisions: {len(prev2_div_frame.columns)} features')

birth_feature_set = births.xs('Measurement',level=1,axis=1).columns
conservative_feature_set = prev2_div_frame.xs('Measurement',level=1,axis=1).columns
assert(np.isnan(births[conservative_feature_set]).values.sum() == 0)
assert(np.isnan(divisions[conservative_feature_set]).values.sum() == 0)
assert(np.isnan(prev_div_frame[conservative_feature_set]).values.sum() == 0)
assert(np.isnan(prev2_div_frame[conservative_feature_set]).values.sum() == 0)
# Out:
# ---
# Number of births: 377
# Number of mother divisions: 307
# Number of 12h prior to divisions: 243
# Number of 24h prior to divisions: 206
# ---
# Births: 1366 features
# Mother divisions: 781 features
# 12h prior to divisions: 779 features
# 24h prior to divisions: 778 features

# %% [markdown]
# ## Recursive feature elimination CV: birth

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

min_features_to_select = 1  # Minimum number of features to consider
clf = ensemble.RandomForestClassifier()
cv = StratifiedKFold(5)

feature2predict = 'Will differentiate'
cols2keep = [(f,'Measurement') for f in conservative_feature_set]
cols2keep += [(feature2predict,'Meta')]

X = births[cols2keep].xs('Measurement',axis=1,level=1)
y = births['Will differentiate','Meta']

rfecv = RFECV(
    estimator=clf,
    step=1,
    cv=cv,
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
    n_jobs=2,
)
rfecv.fit(X, y)

print(f"Optimal number of features: {rfecv.n_features_}")
# Out:
# Optimal number of features: 443

# %%
rfecv.get_feature_names_out()
# Out:
# array(['Nuclear volume', 'Nuclear height', 'Cell volume', 'X-cyto',
#        'Axial component', 'Planar component 1', 'Planar component 2',
#        'Mean H2B intensity', 'Total H2B intensity',
#        'Mean FUCCI intensity', 'Total FUCCI intensity',
#        'Basal orientation', 'Basal eccentricity', 'Cell height',
#        'Collagen coherence', 'Collagen intensity',
#        'Gaussian curvature - cell coords', 'Mean curvature',
#        'cyto_shcoeffs_L1M0C', 'cyto_shcoeffs_L1M1C',
#        'cyto_shcoeffs_L2M0C', 'cyto_shcoeffs_L3M0C',
#        'cyto_shcoeffs_L3M2C', 'cyto_shcoeffs_L4M0C',
#        'cyto_shcoeffs_L4M1C', 'cyto_shcoeffs_L4M2C',
#        'cyto_shcoeffs_L4M3C', 'cyto_shcoeffs_L4M4C',
#        'cyto_shcoeffs_L5M0C', 'cyto_shcoeffs_L5M1C',
#        'cyto_shcoeffs_L5M2C', 'cyto_shcoeffs_L5M5C',
#        'cyto_shcoeffs_L3M1S', 'cyto_shcoeffs_L4M1S',
#        'cyto_shcoeffs_L4M2S', 'cyto_shcoeffs_L4M3S',
#        'cyto_shcoeffs_L4M4S', 'cyto_shcoeffs_L5M1S',
#        'cyto_shcoeffs_L5M2S', 'cyto_shcoeffs_L5M3S',
#        'cyto_shcoeffs_L5M4S', 'cyto_shcoeffs_L5M5S', 'nuc_shcoeffs_L0M0C',
#        'nuc_shcoeffs_L1M0C', 'nuc_shcoeffs_L1M1C', 'nuc_shcoeffs_L2M0C',
#        'nuc_shcoeffs_L3M0C', 'nuc_shcoeffs_L4M0C', 'nuc_shcoeffs_L4M1C',
#        'nuc_shcoeffs_L4M2C', 'nuc_shcoeffs_L4M3C', 'nuc_shcoeffs_L4M4C',
#        'nuc_shcoeffs_L5M0C', 'nuc_shcoeffs_L5M1C', 'nuc_shcoeffs_L5M2C',
#        'nuc_shcoeffs_L5M4C', 'nuc_shcoeffs_L2M2S', 'nuc_shcoeffs_L3M1S',
#        'nuc_shcoeffs_L3M3S', 'nuc_shcoeffs_L4M1S', 'nuc_shcoeffs_L4M2S',
#        'nuc_shcoeffs_L4M3S', 'nuc_shcoeffs_L4M4S', 'nuc_shcoeffs_L5M2S',
#        'nuc_shcoeffs_L5M3S', 'nuc_shcoeffs_L5M4S', 'nuc_shcoeffs_L5M5S',
#        'nuc_shcoeffs_surface_area', 'Distance to closest macrophage',
#        'Nuclear volume standard', 'Nuclear volume smoothed',
#        'Mean FUCCI intensity smoothed', 'Total H2B intensity smoothed',
#        'Basal area smoothed', 'Mean adjac Nuclear solidity',
#        'Mean adjac Axial angle', 'Mean adjac Planar angle',
#        'Mean adjac Mean H2B intensity', 'Mean adjac Total H2B intensity',
#        'Mean adjac Mean FUCCI intensity',
#        'Mean adjac Total FUCCI intensity', 'Mean adjac Basal area',
#        'Mean adjac Middle area', 'Mean adjac Cell height',
#        'Mean adjac Collagen orientation', 'Mean adjac Collagen coherence',
#        'Mean adjac Mean curvature - cell coords',
#        'Mean adjac Mean curvature', 'Mean adjac cyto_shcoeffs_L0M0C',
#        'Mean adjac cyto_shcoeffs_L1M0C', 'Mean adjac cyto_shcoeffs_L1M1C',
#        'Mean adjac cyto_shcoeffs_L3M0C', 'Mean adjac cyto_shcoeffs_L4M0C',
#        'Mean adjac cyto_shcoeffs_L4M2C', 'Mean adjac cyto_shcoeffs_L4M3C',
#        'Mean adjac cyto_shcoeffs_L5M0C', 'Mean adjac cyto_shcoeffs_L5M1C',
#        'Mean adjac cyto_shcoeffs_L5M3C', 'Mean adjac cyto_shcoeffs_L5M4C',
#        'Mean adjac cyto_shcoeffs_L5M5C', 'Mean adjac cyto_shcoeffs_L1M1S',
#        'Mean adjac cyto_shcoeffs_L2M2S', 'Mean adjac cyto_shcoeffs_L3M1S',
#        'Mean adjac cyto_shcoeffs_L3M2S', 'Mean adjac cyto_shcoeffs_L4M1S',
#        'Mean adjac cyto_shcoeffs_L5M1S', 'Mean adjac cyto_shcoeffs_L5M3S',
#        'Mean adjac cyto_shcoeffs_L5M5S',
#        'Mean adjac cyto_shcoeffs_surface_area',
#        'Mean adjac nuc_shcoeffs_L0M0C', 'Mean adjac nuc_shcoeffs_L1M0C',
#        'Mean adjac nuc_shcoeffs_L2M1C', 'Mean adjac nuc_shcoeffs_L3M0C',
#        'Mean adjac nuc_shcoeffs_L3M2C', 'Mean adjac nuc_shcoeffs_L3M3C',
#        'Mean adjac nuc_shcoeffs_L4M1C', 'Mean adjac nuc_shcoeffs_L4M2C',
#        'Mean adjac nuc_shcoeffs_L4M3C', 'Mean adjac nuc_shcoeffs_L5M2C',
#        'Mean adjac nuc_shcoeffs_L5M3C', 'Mean adjac nuc_shcoeffs_L5M4C',
#        'Mean adjac nuc_shcoeffs_L1M1S', 'Mean adjac nuc_shcoeffs_L3M1S',
#        'Mean adjac nuc_shcoeffs_L3M2S', 'Mean adjac nuc_shcoeffs_L4M2S',
#        'Mean adjac nuc_shcoeffs_L4M3S', 'Mean adjac nuc_shcoeffs_L4M4S',
#        'Mean adjac nuc_shcoeffs_L5M2S', 'Mean adjac nuc_shcoeffs_L5M3S',
#        'Mean adjac nuc_shcoeffs_L5M4S',
#        'Mean adjac nuc_shcoeffs_surface_area',
#        'Mean adjac Distance to closest macrophage',
#        'Mean adjac Nuclear volume standard',
#        'Mean adjac Cell volume standard', 'Median adjac Nuclear solidity',
#        'Median adjac Cell volume', 'Median adjac Axial component',
#        'Median adjac Planar component 1',
#        'Median adjac Planar component 2',
#        'Median adjac Total H2B intensity', 'Median adjac Apical area',
#        'Median adjac Basal area', 'Median adjac Basal orientation',
#        'Median adjac Height to BM',
#        'Median adjac Mean curvature - cell coords',
#        'Median adjac Gaussian curvature - cell coords',
#        'Median adjac Mean curvature', 'Median adjac cyto_shcoeffs_L0M0C',
#        'Median adjac cyto_shcoeffs_L1M0C',
#        'Median adjac cyto_shcoeffs_L2M0C',
#        'Median adjac cyto_shcoeffs_L2M1C',
#        'Median adjac cyto_shcoeffs_L2M2C',
#        'Median adjac cyto_shcoeffs_L3M1C',
#        'Median adjac cyto_shcoeffs_L3M3C',
#        'Median adjac cyto_shcoeffs_L4M0C',
#        'Median adjac cyto_shcoeffs_L4M2C',
#        'Median adjac cyto_shcoeffs_L5M0C',
#        'Median adjac cyto_shcoeffs_L5M2C',
#        'Median adjac cyto_shcoeffs_L5M5C',
#        'Median adjac cyto_shcoeffs_L1M1S',
#        'Median adjac cyto_shcoeffs_L2M1S',
#        'Median adjac cyto_shcoeffs_L3M1S',
#        'Median adjac cyto_shcoeffs_L3M2S',
#        'Median adjac cyto_shcoeffs_L5M1S',
#        'Median adjac cyto_shcoeffs_L5M2S',
#        'Median adjac nuc_shcoeffs_L1M0C',
#        'Median adjac nuc_shcoeffs_L1M1C',
#        'Median adjac nuc_shcoeffs_L2M0C',
#        'Median adjac nuc_shcoeffs_L3M0C',
#        'Median adjac nuc_shcoeffs_L3M1C',
#        'Median adjac nuc_shcoeffs_L3M2C',
#        'Median adjac nuc_shcoeffs_L3M3C',
#        'Median adjac nuc_shcoeffs_L4M1C',
#        'Median adjac nuc_shcoeffs_L5M0C',
#        'Median adjac nuc_shcoeffs_L2M1S',
#        'Median adjac nuc_shcoeffs_L2M2S',
#        'Median adjac nuc_shcoeffs_L3M2S',
#        'Median adjac nuc_shcoeffs_L3M3S',
#        'Median adjac nuc_shcoeffs_L4M1S',
#        'Median adjac nuc_shcoeffs_L4M2S',
#        'Median adjac nuc_shcoeffs_L4M3S',
#        'Median adjac nuc_shcoeffs_L5M3S',
#        'Median adjac nuc_shcoeffs_L5M4S',
#        'Median adjac nuc_shcoeffs_surface_area',
#        'Median adjac Distance to closest macrophage',
#        'Median adjac Nuclear volume standard',
#        'Median adjac Cell volume standard', 'Max adjac Nuclear volume',
#        'Max adjac Nuclear solidity', 'Max adjac Cell volume',
#        'Max adjac Planar component 1', 'Max adjac Axial angle',
#        'Max adjac Planar angle', 'Max adjac Total H2B intensity',
#        'Max adjac Mean FUCCI intensity', 'Max adjac Apical area',
#        'Max adjac Collagen coherence', 'Max adjac Basal alignment',
#        'Max adjac Mean curvature - cell coords',
#        'Max adjac Gaussian curvature - cell coords',
#        'Max adjac Mean curvature', 'Max adjac cyto_shcoeffs_L0M0C',
#        'Max adjac cyto_shcoeffs_L1M1C', 'Max adjac cyto_shcoeffs_L2M2C',
#        'Max adjac cyto_shcoeffs_L3M0C', 'Max adjac cyto_shcoeffs_L3M1C',
#        'Max adjac cyto_shcoeffs_L3M2C', 'Max adjac cyto_shcoeffs_L4M0C',
#        'Max adjac cyto_shcoeffs_L4M1C', 'Max adjac cyto_shcoeffs_L4M2C',
#        'Max adjac cyto_shcoeffs_L5M0C', 'Max adjac cyto_shcoeffs_L5M3C',
#        'Max adjac cyto_shcoeffs_L5M4C', 'Max adjac cyto_shcoeffs_L5M5C',
#        'Max adjac cyto_shcoeffs_L1M1S', 'Max adjac cyto_shcoeffs_L2M2S',
#        'Max adjac cyto_shcoeffs_L3M1S', 'Max adjac cyto_shcoeffs_L3M3S',
#        'Max adjac cyto_shcoeffs_L4M2S', 'Max adjac cyto_shcoeffs_L4M4S',
#        'Max adjac cyto_shcoeffs_L5M4S', 'Max adjac nuc_shcoeffs_L2M0C',
#        'Max adjac nuc_shcoeffs_L2M1C', 'Max adjac nuc_shcoeffs_L3M0C',
#        'Max adjac nuc_shcoeffs_L4M1C', 'Max adjac nuc_shcoeffs_L4M2C',
#        'Max adjac nuc_shcoeffs_L4M3C', 'Max adjac nuc_shcoeffs_L4M4C',
#        'Max adjac nuc_shcoeffs_L5M1C', 'Max adjac nuc_shcoeffs_L5M2C',
#        'Max adjac nuc_shcoeffs_L5M3C', 'Max adjac nuc_shcoeffs_L5M4C',
#        'Max adjac nuc_shcoeffs_L2M2S', 'Max adjac nuc_shcoeffs_L3M1S',
#        'Max adjac nuc_shcoeffs_L3M3S', 'Max adjac nuc_shcoeffs_L4M1S',
#        'Max adjac nuc_shcoeffs_L4M3S', 'Max adjac nuc_shcoeffs_L4M4S',
#        'Max adjac nuc_shcoeffs_L5M2S', 'Max adjac nuc_shcoeffs_L5M3S',
#        'Max adjac nuc_shcoeffs_L5M4S', 'Max adjac nuc_shcoeffs_L5M5S',
#        'Max adjac Distance to closest macrophage',
#        'Max adjac Nuclear volume standard', 'Min adjac Nuclear volume',
#        'Min adjac Nuclear solidity', 'Min adjac Cell volume',
#        'Min adjac Axial component', 'Min adjac Planar component 1',
#        'Min adjac Planar component 2', 'Min adjac Mean H2B intensity',
#        'Min adjac Mean FUCCI intensity',
#        'Min adjac Total FUCCI intensity',
#        'Min adjac Collagen orientation', 'Min adjac Collagen coherence',
#        'Min adjac Basal alignment', 'Min adjac Collagen intensity',
#        'Min adjac NC ratio', 'Min adjac Mean curvature - cell coords',
#        'Min adjac Gaussian curvature - cell coords',
#        'Min adjac Mean curvature', 'Min adjac cyto_shcoeffs_L0M0C',
#        'Min adjac cyto_shcoeffs_L1M0C', 'Min adjac cyto_shcoeffs_L1M1C',
#        'Min adjac cyto_shcoeffs_L3M0C', 'Min adjac cyto_shcoeffs_L3M3C',
#        'Min adjac cyto_shcoeffs_L4M0C', 'Min adjac cyto_shcoeffs_L4M2C',
#        'Min adjac cyto_shcoeffs_L4M4C', 'Min adjac cyto_shcoeffs_L5M1C',
#        'Min adjac cyto_shcoeffs_L5M2C', 'Min adjac cyto_shcoeffs_L5M3C',
#        'Min adjac cyto_shcoeffs_L5M4C', 'Min adjac cyto_shcoeffs_L2M1S',
#        'Min adjac cyto_shcoeffs_L3M1S', 'Min adjac cyto_shcoeffs_L3M2S',
#        'Min adjac cyto_shcoeffs_L3M3S', 'Min adjac cyto_shcoeffs_L4M2S',
#        'Min adjac cyto_shcoeffs_L4M3S', 'Min adjac cyto_shcoeffs_L5M1S',
#        'Min adjac cyto_shcoeffs_L5M2S', 'Min adjac cyto_shcoeffs_L5M3S',
#        'Min adjac cyto_shcoeffs_L5M4S',
#        'Min adjac cyto_shcoeffs_surface_area',
#        'Min adjac nuc_shcoeffs_L0M0C', 'Min adjac nuc_shcoeffs_L2M0C',
#        'Min adjac nuc_shcoeffs_L3M0C', 'Min adjac nuc_shcoeffs_L3M1C',
#        'Min adjac nuc_shcoeffs_L3M3C', 'Min adjac nuc_shcoeffs_L4M0C',
#        'Min adjac nuc_shcoeffs_L4M3C', 'Min adjac nuc_shcoeffs_L4M4C',
#        'Min adjac nuc_shcoeffs_L5M1C', 'Min adjac nuc_shcoeffs_L5M3C',
#        'Min adjac nuc_shcoeffs_L1M1S', 'Min adjac nuc_shcoeffs_L3M1S',
#        'Min adjac nuc_shcoeffs_L4M1S', 'Min adjac nuc_shcoeffs_L4M2S',
#        'Min adjac nuc_shcoeffs_L4M4S', 'Min adjac nuc_shcoeffs_L5M1S',
#        'Min adjac nuc_shcoeffs_L5M2S', 'Min adjac nuc_shcoeffs_L5M3S',
#        'Min adjac nuc_shcoeffs_L5M5S',
#        'Min adjac nuc_shcoeffs_surface_area',
#        'Min adjac Nuclear volume standard', 'Std adjac Nuclear height',
#        'Std adjac Cell volume', 'Std adjac Axial component',
#        'Std adjac Planar component 1', 'Std adjac Axial angle',
#        'Std adjac Mean H2B intensity', 'Std adjac Mean FUCCI intensity',
#        'Std adjac Apical area', 'Std adjac Basal area',
#        'Std adjac Basal orientation', 'Std adjac Basal eccentricity',
#        'Std adjac Cell height', 'Std adjac Collagen orientation',
#        'Std adjac Collagen coherence', 'Std adjac NC ratio',
#        'Std adjac Gaussian curvature - cell coords',
#        'Std adjac cyto_shcoeffs_L0M0C', 'Std adjac cyto_shcoeffs_L1M1C',
#        'Std adjac cyto_shcoeffs_L2M1C', 'Std adjac cyto_shcoeffs_L2M2C',
#        'Std adjac cyto_shcoeffs_L3M0C', 'Std adjac cyto_shcoeffs_L3M1C',
#        'Std adjac cyto_shcoeffs_L4M0C', 'Std adjac cyto_shcoeffs_L4M1C',
#        'Std adjac cyto_shcoeffs_L4M2C', 'Std adjac cyto_shcoeffs_L4M4C',
#        'Std adjac cyto_shcoeffs_L5M0C', 'Std adjac cyto_shcoeffs_L5M1C',
#        'Std adjac cyto_shcoeffs_L5M2C', 'Std adjac cyto_shcoeffs_L5M4C',
#        'Std adjac cyto_shcoeffs_L1M1S', 'Std adjac cyto_shcoeffs_L2M1S',
#        'Std adjac cyto_shcoeffs_L2M2S', 'Std adjac cyto_shcoeffs_L3M2S',
#        'Std adjac cyto_shcoeffs_L3M3S', 'Std adjac cyto_shcoeffs_L4M1S',
#        'Std adjac cyto_shcoeffs_L4M2S', 'Std adjac cyto_shcoeffs_L4M3S',
#        'Std adjac cyto_shcoeffs_L5M1S', 'Std adjac cyto_shcoeffs_L5M2S',
#        'Std adjac cyto_shcoeffs_L5M3S', 'Std adjac cyto_shcoeffs_L5M4S',
#        'Std adjac cyto_shcoeffs_surface_area',
#        'Std adjac nuc_shcoeffs_L1M0C', 'Std adjac nuc_shcoeffs_L1M1C',
#        'Std adjac nuc_shcoeffs_L2M0C', 'Std adjac nuc_shcoeffs_L3M0C',
#        'Std adjac nuc_shcoeffs_L3M2C', 'Std adjac nuc_shcoeffs_L4M1C',
#        'Std adjac nuc_shcoeffs_L4M2C', 'Std adjac nuc_shcoeffs_L4M4C',
#        'Std adjac nuc_shcoeffs_L5M0C', 'Std adjac nuc_shcoeffs_L5M2C',
#        'Std adjac nuc_shcoeffs_L5M3C', 'Std adjac nuc_shcoeffs_L5M4C',
#        'Std adjac nuc_shcoeffs_L1M1S', 'Std adjac nuc_shcoeffs_L2M1S',
#        'Std adjac nuc_shcoeffs_L3M2S', 'Std adjac nuc_shcoeffs_L3M3S',
#        'Std adjac nuc_shcoeffs_L4M3S', 'Std adjac nuc_shcoeffs_L4M4S',
#        'Std adjac nuc_shcoeffs_L5M1S', 'Std adjac nuc_shcoeffs_L5M4S',
#        'Std adjac nuc_shcoeffs_L5M5S',
#        'Std adjac nuc_shcoeffs_surface_area',
#        'Std adjac Distance to closest macrophage',
#        'Std adjac Nuclear volume standard',
#        'Std adjac Cell volume standard', 'Relative Nuclear volume',
#        'Relative Nuclear solidity', 'Relative Axial component',
#        'Relative Planar component 1', 'Relative Planar component 2',
#        'Relative Axial angle', 'Relative Mean H2B intensity',
#        'Relative Total H2B intensity', 'Relative Mean FUCCI intensity',
#        'Relative Apical area', 'Relative Basal area',
#        'Relative Basal eccentricity', 'Relative Middle area',
#        'Relative Cell height', 'Relative Collagen coherence',
#        'Relative Basal alignment', 'Relative Collagen intensity',
#        'Relative NC ratio', 'Relative Gaussian curvature - cell coords',
#        'Relative cyto_shcoeffs_L0M0C', 'Relative cyto_shcoeffs_L1M0C',
#        'Relative cyto_shcoeffs_L2M0C', 'Relative cyto_shcoeffs_L2M1C',
#        'Relative cyto_shcoeffs_L2M2C', 'Relative cyto_shcoeffs_L3M0C',
#        'Relative cyto_shcoeffs_L3M2C', 'Relative cyto_shcoeffs_L4M0C',
#        'Relative cyto_shcoeffs_L4M2C', 'Relative cyto_shcoeffs_L4M4C',
#        'Relative cyto_shcoeffs_L5M0C', 'Relative cyto_shcoeffs_L5M3C',
#        'Relative cyto_shcoeffs_L1M1S', 'Relative cyto_shcoeffs_L2M1S',
#        'Relative cyto_shcoeffs_L2M2S', 'Relative cyto_shcoeffs_L3M1S',
#        'Relative cyto_shcoeffs_L3M3S', 'Relative cyto_shcoeffs_L4M2S',
#        'Relative cyto_shcoeffs_L4M3S', 'Relative cyto_shcoeffs_L4M4S',
#        'Relative cyto_shcoeffs_L5M3S', 'Relative cyto_shcoeffs_L5M4S',
#        'Relative cyto_shcoeffs_L5M5S', 'Relative nuc_shcoeffs_L0M0C',
#        'Relative nuc_shcoeffs_L1M0C', 'Relative nuc_shcoeffs_L1M1C',
#        'Relative nuc_shcoeffs_L2M0C', 'Relative nuc_shcoeffs_L2M1C',
#        'Relative nuc_shcoeffs_L3M0C', 'Relative nuc_shcoeffs_L3M1C',
#        'Relative nuc_shcoeffs_L3M2C', 'Relative nuc_shcoeffs_L4M0C',
#        'Relative nuc_shcoeffs_L4M1C', 'Relative nuc_shcoeffs_L4M3C',
#        'Relative nuc_shcoeffs_L4M4C', 'Relative nuc_shcoeffs_L5M0C',
#        'Relative nuc_shcoeffs_L5M1C', 'Relative nuc_shcoeffs_L5M3C',
#        'Relative nuc_shcoeffs_L5M5C', 'Relative nuc_shcoeffs_L3M1S',
#        'Relative nuc_shcoeffs_L3M2S', 'Relative nuc_shcoeffs_L3M3S',
#        'Relative nuc_shcoeffs_L4M2S', 'Relative nuc_shcoeffs_L4M4S',
#        'Relative nuc_shcoeffs_L5M2S', 'Relative nuc_shcoeffs_L5M3S',
#        'Relative nuc_shcoeffs_L5M4S', 'Relative nuc_shcoeffs_L5M5S',
#        'Relative nuc_shcoeffs_surface_area',
#        'Relative Distance to closest macrophage',
#        'Relative Nuclear volume standard'], dtype=object)

# %% [markdown]
# ## Recursive feature elimination CV: division

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

min_features_to_select = 1  # Minimum number of features to consider
clf = ensemble.RandomForestClassifier()
cv = StratifiedKFold(5)

feature2predict = 'At least one daughter differentiated'
cols2keep = [(f,'Measurement') for f in conservative_feature_set]
cols2keep += [(feature2predict,'Meta')]

X = divisions[cols2keep].xs('Measurement',axis=1,level=1)
y = divisions['At least one daughter differentiated','Meta'].astype(bool)

rfecv = RFECV(
    estimator=clf,
    step=1,
    cv=cv,
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
    n_jobs=2,
)
rfecv.fit(X, y)

print(f"Optimal number of features: {rfecv.n_features_}")
# Out:
# Optimal number of features: 6

# %%
rfecv.get_feature_names_out()
# Out:
# array(['Mean curvature', 'cyto_shcoeffs_L3M0C', 'Basal area smoothed',
#        'Mean adjac Cell volume standard',
#        'Median adjac Cell volume standard', 'Relative Basal area'],
#       dtype=object)

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

min_features_to_select = 1  # Minimum number of features to consider
clf = ensemble.RandomForestClassifier()
cv = StratifiedKFold(5)

feature2predict = 'At least one daughter differentiated'
cols2keep = [(f,'Measurement') for f in conservative_feature_set]
cols2keep += [(feature2predict,'Meta')]

X = prev_div_frame[cols2keep].xs('Measurement',axis=1,level=1)
y = prev_div_frame['At least one daughter differentiated','Meta'].astype(bool)

rfecv = RFECV(
    estimator=clf,
    step=1,
    cv=cv,
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
    n_jobs=2,
)
rfecv.fit(X, y)

print(f"Optimal number of features: {rfecv.n_features_}")
# Out:
# Optimal number of features: 114

# %%
rfecv.get_feature_names_out()
# Out:
# array(['Axial component', 'Axial angle', 'Middle area',
#        'Collagen coherence', 'Mean curvature', 'cyto_shcoeffs_L1M0C',
#        'cyto_shcoeffs_L2M0C', 'cyto_shcoeffs_L3M0C',
#        'cyto_shcoeffs_L4M0C', 'cyto_shcoeffs_L5M4C',
#        'cyto_shcoeffs_L3M1S', 'cyto_shcoeffs_L3M2S',
#        'cyto_shcoeffs_L5M1S', 'cyto_shcoeffs_L5M2S',
#        'cyto_shcoeffs_surface_area', 'nuc_shcoeffs_L3M0C',
#        'nuc_shcoeffs_L4M0C', 'nuc_shcoeffs_L4M2C', 'nuc_shcoeffs_L5M0C',
#        'nuc_shcoeffs_L3M3S', 'nuc_shcoeffs_L4M3S', 'nuc_shcoeffs_L5M2S',
#        'nuc_shcoeffs_L5M3S', 'Nuclear volume smoothed',
#        'Basal area smoothed', 'Mean adjac Apical area',
#        'Mean adjac cyto_shcoeffs_L4M4C', 'Mean adjac cyto_shcoeffs_L5M1C',
#        'Mean adjac cyto_shcoeffs_L3M3S', 'Mean adjac cyto_shcoeffs_L5M3S',
#        'Mean adjac cyto_shcoeffs_L5M5S', 'Mean adjac nuc_shcoeffs_L2M1S',
#        'Mean adjac nuc_shcoeffs_L4M1S', 'Mean adjac nuc_shcoeffs_L4M4S',
#        'Mean adjac nuc_shcoeffs_L5M1S', 'Mean adjac nuc_shcoeffs_L5M3S',
#        'Median adjac Planar component 1', 'Median adjac Cell height',
#        'Median adjac Height to BM', 'Median adjac cyto_shcoeffs_L1M1C',
#        'Median adjac cyto_shcoeffs_L3M1C',
#        'Median adjac cyto_shcoeffs_L5M1C',
#        'Median adjac cyto_shcoeffs_L5M2C',
#        'Median adjac nuc_shcoeffs_L3M3C',
#        'Median adjac nuc_shcoeffs_L3M3S',
#        'Median adjac nuc_shcoeffs_L4M4S',
#        'Median adjac nuc_shcoeffs_L5M2S',
#        'Median adjac nuc_shcoeffs_L5M3S',
#        'Median adjac nuc_shcoeffs_L5M4S',
#        'Median adjac nuc_shcoeffs_surface_area',
#        'Median adjac Nuclear volume standard',
#        'Max adjac cyto_shcoeffs_L2M0C', 'Max adjac cyto_shcoeffs_L3M2C',
#        'Max adjac cyto_shcoeffs_L4M4C', 'Max adjac cyto_shcoeffs_L5M1C',
#        'Max adjac cyto_shcoeffs_L5M2C', 'Max adjac nuc_shcoeffs_L2M2C',
#        'Max adjac nuc_shcoeffs_L2M1S', 'Max adjac nuc_shcoeffs_L4M1S',
#        'Max adjac nuc_shcoeffs_L4M3S', 'Max adjac nuc_shcoeffs_L5M1S',
#        'Min adjac Nuclear solidity', 'Min adjac Mean H2B intensity',
#        'Min adjac Apical area', 'Min adjac cyto_shcoeffs_L3M0C',
#        'Min adjac cyto_shcoeffs_L5M2C', 'Min adjac nuc_shcoeffs_L0M0C',
#        'Min adjac nuc_shcoeffs_L3M0C', 'Min adjac nuc_shcoeffs_L3M3C',
#        'Min adjac nuc_shcoeffs_L5M4C', 'Min adjac nuc_shcoeffs_L1M1S',
#        'Min adjac nuc_shcoeffs_L3M2S', 'Min adjac nuc_shcoeffs_L4M3S',
#        'Min adjac nuc_shcoeffs_L5M2S', 'Std adjac Nuclear solidity',
#        'Std adjac Planar component 1', 'Std adjac Mean H2B intensity',
#        'Std adjac cyto_shcoeffs_L1M1C', 'Std adjac cyto_shcoeffs_L3M0C',
#        'Std adjac cyto_shcoeffs_L3M2C', 'Std adjac cyto_shcoeffs_L4M0C',
#        'Std adjac cyto_shcoeffs_L5M0C', 'Std adjac nuc_shcoeffs_L0M0C',
#        'Std adjac nuc_shcoeffs_L2M2C', 'Std adjac nuc_shcoeffs_L3M0C',
#        'Std adjac nuc_shcoeffs_L4M3C', 'Std adjac nuc_shcoeffs_L5M0C',
#        'Std adjac nuc_shcoeffs_L5M3C', 'Std adjac nuc_shcoeffs_L3M2S',
#        'Std adjac nuc_shcoeffs_L4M3S',
#        'Std adjac nuc_shcoeffs_surface_area',
#        'Std adjac Nuclear volume standard', 'Relative Nuclear solidity',
#        'Relative Axial component', 'Relative Mean H2B intensity',
#        'Relative Apical area', 'Relative Basal area',
#        'Relative Collagen orientation', 'Relative Collagen intensity',
#        'Relative Mean curvature - cell coords',
#        'Relative cyto_shcoeffs_L1M0C', 'Relative cyto_shcoeffs_L2M0C',
#        'Relative cyto_shcoeffs_L4M0C', 'Relative cyto_shcoeffs_L4M4C',
#        'Relative cyto_shcoeffs_L5M0C', 'Relative cyto_shcoeffs_L5M5C',
#        'Relative cyto_shcoeffs_L1M1S', 'Relative cyto_shcoeffs_L3M2S',
#        'Relative nuc_shcoeffs_L0M0C', 'Relative nuc_shcoeffs_L2M0C',
#        'Relative nuc_shcoeffs_L3M0C', 'Relative nuc_shcoeffs_L3M1C',
#        'Relative nuc_shcoeffs_L3M3S', 'Relative nuc_shcoeffs_L4M1S'],
#       dtype=object)
