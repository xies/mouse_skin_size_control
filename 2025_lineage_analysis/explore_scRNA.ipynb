# %%
import numpy as np
import pandas as pd
from os import path

df = pd.read_csv(
    '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Bioinformatics/Skin/Joost 2016/GSE67602_Joost_et_al_expression.txt',
    sep='\t',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import pandas as pd
#       3 from os import path
# ----> 5 df = pd.read_csv(
#       6     '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Bioinformatics/Skin/Joost 2016/GSE67602_Joost_et_al_expression.txt',
#       7     sep='\t',index_col=0)
#
# ...

# %%
# df[df.index.str.startswith('Act')]
# Out:
#            1772067055_A01  1772067055_A03  1772067055_A04  1772067055_A05  \
# Gene\Cell
# Actr1b                  0               0               0               0
# Actr3                   0               0               2               1
# Actr6                   0               0               0               0
# Actr2                   0               5               0               0
# Actg1                  12              47              11               8
# Actr10                  0               1               3               0
# Actn1                   0               0               0               2
# Actn2                   0               0               0               0
# Actbl2                  0               0               0               0
# Actr8                   0               0               0               0
# Actl9                   0               0               0               0
# ...
