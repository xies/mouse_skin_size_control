# %% [markdown]
# ## 0. Load datasets

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection, feature_selection, metrics, inspection, pipeline
from sklearn import ensemble
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted

# %matplotlib widget

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
model_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Random_forest_division_36h'

all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
basals = pd.read_pickle(path.join(dataset_dir,f'basals.pkl'))
divisions_36h = pd.read_pickle(path.join(dataset_dir,f'divisions_36h.pkl'))

# censor the 'answers'
features2drop = [(f,a) for f,a in divisions_36h.columns if 'Time' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'Manual' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'duration' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'Total' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'cell coords' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'smoothed' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in divisions_36h.columns if 'exponential' in f and not 'G1 only' in f]
features2drop += ['Z','Z-cyto']
division_24h = divisions_36h[~np.isnan(divisions_36h['Num daughter differentiated','Meta'])]
division_24h = divisions_36h.drop(features2drop,axis=1)
print(len(divisions_36h))
# Out:
# 470
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_39858/1192936962.py:18: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   division_24h = divisions_36h.drop(features2drop,axis=1)

# %%
# Grouped Standard Scaler
class GroupedStandardScaler(BaseEstimator, TransformerMixin):
    """
    Standardize features by removing the mean and scaling to unit variance,
    computed separately for each group defined by a categorical variable.
    
    Parameters
    ----------
    group_col : str
        Name of the categorical column to group by for standardization
    
    with_mean : bool, default=True
        If True, center the data before scaling
    
    with_std : bool, default=True
        If True, scale the data to unit variance
    
    Attributes
    ----------
    group_means_ : dict
        Dictionary mapping group values to mean arrays
    
    group_stds_ : dict
        Dictionary mapping group values to standard deviation arrays
    
    feature_names_ : list
        List of feature column names (excluding group_col)
    
    groups_ : array
        Unique group values seen during fit
    """
    
    def __init__(self, group_col, with_mean=True, with_std=True):
        self.group_col = group_col
        self.with_mean = with_mean
        self.with_std = with_std
    
    def fit(self, X, y=None):
        """
        Compute the mean and std to be used for later scaling, per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data used to compute the per-group means and standard deviations
            used for later scaling along the features axis.
        
        y : None
            Ignored
        
        Returns
        -------
        self : object
            Fitted scaler
        """
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Store feature names (excluding group column)
        self.feature_names_ = [col for col in X.columns if col != self.group_col]
        
        # Use groupby for vectorized computation
        grouped = X.groupby(self.group_col)[self.feature_names_]
        
        if self.with_mean:
            self.group_means_ = grouped.mean()
        else:
            self.group_means_ = pd.DataFrame(
                0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        if self.with_std:
            self.group_stds_ = grouped.std()
            # Replace zero std with 1 to avoid division by zero
            self.group_stds_ = self.group_stds_.replace(0, 1.0)
        else:
            self.group_stds_ = pd.DataFrame(
                1.0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        return self
    
    def transform(self, X):
        """
        Perform standardization by centering and scaling per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to transform
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy to avoid modifying original
        X_transformed = X.copy()
        
        # Align means and stds with X using merge (much faster than map)
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized standardization
        X_transformed[self.feature_names_] = (
            X[self.feature_names_].values - means_aligned[self.feature_names_].values
        ) / stds_aligned[self.feature_names_].values
        
        # Check for unseen groups (NaN values after join)
        if means_aligned[self.feature_names_].isna().any().any():
            unseen_groups = X.loc[means_aligned[self.feature_names_].isna().any(axis=1), self.group_col].unique()
            import warnings
            warnings.warn(f"Found unseen groups during transform: {unseen_groups}. These samples will not be standardized.")
            # Keep original values for unseen groups (where NaN resulted)
            nan_mask = means_aligned[self.feature_names_].isna().any(axis=1)
            X_transformed.loc[nan_mask, self.feature_names_] = X.loc[nan_mask, self.feature_names_]
        
        return X_transformed.drop(columns=self.group_col)
    
    def fit_transform(self, X, y=None):
        """
        Fit to data, then transform it.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            Input data
        
        y : None
            Ignored
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        return self.fit(X, y).transform(X)
    
    def inverse_transform(self, X):
        """
        Scale back the data to the original representation per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to inverse transform
        
        Returns
        -------
        X_original : pandas DataFrame of shape (n_samples, n_features)
            DataFrame in original scale
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy
        X_original = X.copy()
        
        # Align means and stds with X using merge
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized inverse transformation
        X_original[self.feature_names_] = (
            X[self.feature_names_].values * stds_aligned[self.feature_names_].values
        ) + means_aligned[self.feature_names_].values
        
        return X_original

# %%
# Helper functions
def get_balanced_df_by_category(df,category,subsample=None,replacement=True):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]

    num_to_sample = min(subsample if subsample is not None else num_per_category.min(), num_per_category.min())
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member.sample(num_to_sample,replace=replacement))
        else:
            output.append(member.sample(num_to_sample,replace=replacement))
    output = pd.concat(output,ignore_index=True)
    
    return output

def predict_feature(df:pd.DataFrame,
                    classifier,
                    feature2predict,
                    groupby_name = 'Region',
                    Niter:int=100,
                    model_params = {},
                    measurement_level_name:str='Measurement'):
    training_set = []
    Y_test = []
    Y_pred = []
    models = []
    for i in tqdm(range(Niter)):

        # rng = np.random.RandomState(0)
        df_ = get_balanced_df_by_category(df, df[feature2predict,'Meta'].values)
        
        pipe = pipeline.make_pipeline(preprocessing.StandardScaler(),
                                      classifier(random_state=i,**model_params) )
        
        y = df_[feature2predict,'Meta'].astype(float)
        X = df_.xs(measurement_level_name,level=1,axis=1).astype(float)
        X[np.isinf(X)] = np.nan
        # X['Region'] = df_['Region']
        X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,random_state=i+1)
        
        model = pipe.fit(X_train,y_train)
        models.append(model)
        
        Y_test.append(y_test)
        Y_pred.append(model.predict(X_test))

        training_set.append((X_train,y_train,X_test,y_test))
        
    return [np.stack((np.array(Y_test),np.array(Y_pred))),models,training_set]

# %% [markdown]
# ## 1. Predict from mother division frame

# %%
feature2predict = 'At least one daughter differentiated'
division_24h.droplevel(axis=1,level=1).groupby(feature2predict).count()
# Out:
# Name                                  Nuclear volume  Nuclear solidity    Y  \
# At least one daughter differentiated
# False                                             39                39   39
# True                                             116               116  116
#
# Name                                    X  Nuclear height  Cell volume  \
# At least one daughter differentiated
# False                                  39              39           39
# True                                  116             116          116
#
# Name                                  Y-cyto  X-cyto  Axial component  \
# At least one daughter differentiated
# False                                     39      39               39
# True                                     116     116              116
#
# Name                                  Planar component 1  ...  \
# At least one daughter differentiated                      ...
# False                                                 39  ...
# True                                                 116  ...
#
# Name                                  Diff from Min adjac Mean FUCCI intensity at 1 frame prior  \
# At least one daughter differentiated
# False                                                                                32
# True                                                                                 88
#
# Name                                  Diff from Mean adjac Mean curvature 10um at 1 frame prior  \
# At least one daughter differentiated
# False                                                                                32
# True                                                                                 88
#
# Name                                  Diff from Std adjac nuc_shcoeff_PC2 at 1 frame prior  \
# At least one daughter differentiated
# False                                                                                32
# True                                                                                 88
#
# Name                                  Diff from Relative Cell volume at 1 frame prior  \
# At least one daughter differentiated
# False                                                                              32
# True                                                                               88
#
# Name                                  Diff from Min adjac nuc_shcoeff_PC6 at 1 frame prior  \
# At least one daughter differentiated
# False                                                                                32
# True                                                                                 88
#
# Name                                  Num neighbor division 1 frame prior  \
# At least one daughter differentiated
# False                                                                  32
# True                                                                   88
#
# Name                                  Num neighbor delamination 1 frame prior  \
# At least one daughter differentiated
# False                                                                      32
# True                                                                       88
#
# Name                                  Num daughter differentiated  \
# At least one daughter differentiated
# False                                                          39
# True                                                          116
#
# Name                                  Both daughters differentiated  Region
# At least one daughter differentiated
# False                                                            39      39
# True                                                            116     116
#
# [2 rows x 919 columns]

# %%
# Run classifier
# axis0: observation axis1: prediction

predictions,models,training_set = predict_feature(divisions_36h,
                                     ensemble.RandomForestClassifier, feature2predict,Niter=100)
# Out:
#   0%|                                                                           | 0/100 [00:00<?, ?it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   1%|▋                                                                  | 1/100 [00:01<02:10,  1.31s/it]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   2%|█▎                                                                 | 2/100 [00:01<01:30,  1.09it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   3%|██                                                                 | 3/100 [00:02<01:15,  1.28it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   4%|██▋                                                                | 4/100 [00:03<01:16,  1.26it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   5%|███▎                                                               | 5/100 [00:04<01:24,  1.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   6%|████                                                               | 6/100 [00:05<01:20,  1.16it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   7%|████▋                                                              | 7/100 [00:06<01:18,  1.18it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   8%|█████▎                                                             | 8/100 [00:06<01:16,  1.20it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   9%|██████                                                             | 9/100 [00:07<01:13,  1.23it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  10%|██████▌                                                           | 10/100 [00:08<01:07,  1.32it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  11%|███████▎                                                          | 11/100 [00:09<01:27,  1.01it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  12%|███████▉                                                          | 12/100 [00:10<01:18,  1.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  13%|████████▌                                                         | 13/100 [00:12<01:41,  1.17s/it]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  14%|█████████▏                                                        | 14/100 [00:12<01:18,  1.10it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  15%|█████████▉                                                        | 15/100 [00:13<01:05,  1.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  16%|██████████▌                                                       | 16/100 [00:13<00:53,  1.58it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  17%|███████████▏                                                      | 17/100 [00:13<00:51,  1.63it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  18%|███████████▉                                                      | 18/100 [00:14<00:43,  1.89it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  19%|████████████▌                                                     | 19/100 [00:14<00:39,  2.05it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  20%|█████████████▏                                                    | 20/100 [00:15<00:44,  1.80it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  21%|█████████████▊                                                    | 21/100 [00:15<00:37,  2.10it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  22%|██████████████▌                                                   | 22/100 [00:16<00:40,  1.95it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  23%|███████████████▏                                                  | 23/100 [00:16<00:35,  2.19it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  24%|███████████████▊                                                  | 24/100 [00:17<00:38,  1.97it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  25%|████████████████▌                                                 | 25/100 [00:17<00:33,  2.21it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  26%|█████████████████▏                                                | 26/100 [00:17<00:32,  2.28it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  27%|█████████████████▊                                                | 27/100 [00:18<00:35,  2.08it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  28%|██████████████████▍                                               | 28/100 [00:18<00:32,  2.23it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  29%|███████████████████▏                                              | 29/100 [00:19<00:31,  2.28it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  30%|███████████████████▊                                              | 30/100 [00:19<00:33,  2.06it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  31%|████████████████████▍                                             | 31/100 [00:20<00:30,  2.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  32%|█████████████████████                                             | 32/100 [00:20<00:32,  2.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  33%|█████████████████████▊                                            | 33/100 [00:21<00:30,  2.22it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  34%|██████████████████████▍                                           | 34/100 [00:21<00:27,  2.38it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  35%|███████████████████████                                           | 35/100 [00:22<00:31,  2.09it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  36%|███████████████████████▊                                          | 36/100 [00:22<00:27,  2.31it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  37%|████████████████████████▍                                         | 37/100 [00:22<00:26,  2.35it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  38%|█████████████████████████                                         | 38/100 [00:23<00:31,  1.95it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  39%|█████████████████████████▋                                        | 39/100 [00:23<00:28,  2.17it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  40%|██████████████████████████▍                                       | 40/100 [00:24<00:25,  2.31it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  41%|███████████████████████████                                       | 41/100 [00:24<00:27,  2.15it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  42%|███████████████████████████▋                                      | 42/100 [00:25<00:23,  2.42it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  43%|████████████████████████████▍                                     | 43/100 [00:25<00:21,  2.66it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  44%|█████████████████████████████                                     | 44/100 [00:25<00:24,  2.26it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  45%|█████████████████████████████▋                                    | 45/100 [00:26<00:25,  2.17it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  46%|██████████████████████████████▎                                   | 46/100 [00:26<00:22,  2.42it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  47%|███████████████████████████████                                   | 47/100 [00:27<00:19,  2.66it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  48%|███████████████████████████████▋                                  | 48/100 [00:27<00:22,  2.27it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  49%|████████████████████████████████▎                                 | 49/100 [00:27<00:20,  2.52it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  50%|█████████████████████████████████                                 | 50/100 [00:28<00:19,  2.58it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  51%|█████████████████████████████████▋                                | 51/100 [00:28<00:22,  2.22it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  52%|██████████████████████████████████▎                               | 52/100 [00:29<00:23,  2.06it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  53%|██████████████████████████████████▉                               | 53/100 [00:29<00:20,  2.28it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  54%|███████████████████████████████████▋                              | 54/100 [00:30<00:21,  2.18it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  55%|████████████████████████████████████▎                             | 55/100 [00:30<00:22,  2.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  56%|████████████████████████████████████▉                             | 56/100 [00:31<00:19,  2.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  57%|█████████████████████████████████████▌                            | 57/100 [00:31<00:18,  2.39it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  58%|██████████████████████████████████████▎                           | 58/100 [00:31<00:16,  2.53it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  59%|██████████████████████████████████████▉                           | 59/100 [00:32<00:18,  2.19it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  60%|███████████████████████████████████████▌                          | 60/100 [00:32<00:16,  2.44it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  61%|████████████████████████████████████████▎                         | 61/100 [00:33<00:16,  2.42it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  62%|████████████████████████████████████████▉                         | 62/100 [00:33<00:15,  2.53it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  63%|█████████████████████████████████████████▌                        | 63/100 [00:34<00:19,  1.94it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  64%|██████████████████████████████████████████▏                       | 64/100 [00:34<00:16,  2.23it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  65%|██████████████████████████████████████████▉                       | 65/100 [00:34<00:14,  2.50it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  66%|███████████████████████████████████████████▌                      | 66/100 [00:35<00:13,  2.46it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  67%|████████████████████████████████████████████▏                     | 67/100 [00:36<00:17,  1.88it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  68%|████████████████████████████████████████████▉                     | 68/100 [00:36<00:14,  2.15it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  69%|█████████████████████████████████████████████▌                    | 69/100 [00:36<00:12,  2.42it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ...
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  77%|██████████████████████████████████████████████████▊               | 77/100 [00:40<00:10,  2.11it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  78%|███████████████████████████████████████████████████▍              | 78/100 [00:40<00:09,  2.39it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  79%|████████████████████████████████████████████████████▏             | 79/100 [00:41<00:07,  2.63it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  80%|████████████████████████████████████████████████████▊             | 80/100 [00:41<00:07,  2.71it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  81%|█████████████████████████████████████████████████████▍            | 81/100 [00:42<00:10,  1.81it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  82%|██████████████████████████████████████████████████████            | 82/100 [00:42<00:08,  2.07it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  83%|██████████████████████████████████████████████████████▊           | 83/100 [00:42<00:07,  2.35it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  84%|███████████████████████████████████████████████████████▍          | 84/100 [00:43<00:06,  2.55it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  85%|████████████████████████████████████████████████████████          | 85/100 [00:43<00:05,  2.72it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  86%|████████████████████████████████████████████████████████▊         | 86/100 [00:44<00:06,  2.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  87%|█████████████████████████████████████████████████████████▍        | 87/100 [00:44<00:05,  2.36it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  88%|██████████████████████████████████████████████████████████        | 88/100 [00:44<00:04,  2.60it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  89%|██████████████████████████████████████████████████████████▋       | 89/100 [00:45<00:04,  2.58it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  90%|███████████████████████████████████████████████████████████▍      | 90/100 [00:45<00:03,  2.63it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  91%|████████████████████████████████████████████████████████████      | 91/100 [00:46<00:04,  2.03it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  92%|████████████████████████████████████████████████████████████▋     | 92/100 [00:46<00:03,  2.09it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  93%|█████████████████████████████████████████████████████████████▍    | 93/100 [00:47<00:03,  2.25it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  94%|██████████████████████████████████████████████████████████████    | 94/100 [00:47<00:02,  2.45it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  95%|██████████████████████████████████████████████████████████████▋   | 95/100 [00:47<00:01,  2.63it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  96%|███████████████████████████████████████████████████████████████▎  | 96/100 [00:48<00:01,  2.82it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  97%|████████████████████████████████████████████████████████████████  | 97/100 [00:48<00:01,  2.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  98%|████████████████████████████████████████████████████████████████▋ | 98/100 [00:49<00:00,  2.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#  99%|█████████████████████████████████████████████████████████████████▎| 99/100 [00:49<00:00,  2.52it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# 100%|█████████████████████████████████████████████████████████████████| 100/100 [00:49<00:00,  2.00it/s]

# %%
feat_names = divisions_36h.xs('Measurement',level=1,axis=1).columns
importances = pd.DataFrame(columns = feat_names,index=range(len(models)))
for i,m in enumerate(models):
    importances.loc[i,:] = m[1].feature_importances_

plt.figure()
importances.dropna(how='all').mean(axis=0).sort_values().dropna().tail(20).plot.bar()
plt.ylabel('Impurity importance')
plt.tight_layout()
plt.show()

importances.dropna(how='all').mean(axis=0).sort_values().to_csv(path.join(model_dir,'importances.csv'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Feature selection

# %%
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Mean curvature',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='cyto_shcoeffs_L3M0C',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Basal area',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Median adjac Cell volume',kind='violin')

# %% [markdown]
# ### RFE

# %%
from sklearn import feature_selection

X = divisions.xs('Measurement',level=1,axis=1)
y = divisions[feature2predict,'Meta'].astype(bool)
m = ensemble.RandomForestClassifier().fit(X,y)

results = feature_selection.RFECV(m).fit(X,y)

# %%
plt.errorbar(x=results.cv_results_['n_features'][:50],
        y=results.cv_results_['mean_test_score'][:50],
        yerr=results.cv_results_['std_test_score'][:50])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
print(f'# optimal features: {results.n_features_}')

selected = X.columns[ results.ranking_ == 1]
print(selected)
# Out:
# # optimal features: 2
# Index(['cyto_shcoeffs_L3M0C', 'Relative Height to BM'], dtype='object', name='Name')

# %% [markdown]
# ## 2. ExtraTreesClassifier

# %%
# Run classifier
# axis0: observation axis1: prediction

predictions,models = predict_feature(divisions, ensemble.ExtraTreesClassifier(), feature2predict,Niter=1000)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:51<00:00, 19.46it/s]

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.title('Predict daughter-fate from division frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
# plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
# plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')

# %%
feat_names = divisions.xs('Measurement',level=1,axis=1).columns
importances = pd.DataFrame(columns = feat_names,index=range(len(models)))
for i,m in enumerate(models):
    importances.loc[i,feat_names[m[1].get_support()]] = m[2].feature_importances_

importances.dropna(how='all').mean(axis=0).sort_values().dropna().tail(20).plot.bar()

plt.ylabel('Impurity importance')
# Out:
# Text(0, 0.5, 'Impurity importance')

# %%
from sklearn import feature_selection

X = divisions.xs('Measurement',level=1,axis=1)
y = divisions[feature2predict,'Meta'].astype(bool)
m = ensemble.ExtraTreesClassifier().fit(X,y)

results = feature_selection.RFECV(m).fit(X,y)

# %%
plt.errorbar(x=results.cv_results_['n_features'][:50],
        y=results.cv_results_['mean_test_score'][:50],
        yerr=results.cv_results_['std_test_score'][:50])

print(f'# optimal features: {results.n_features_}')

selected = X.columns[ results.ranking_ == 1]
print(selected)
# Out:
# # optimal features: 9
# Index(['Basal area', 'Height to BM', 'cyto_shcoeffs_L3M0C',
#        'nuc_shcoeffs_L3M2S', 'Median adjac nuc_shcoeffs_L5M2S',
#        'Min adjac Planar component 1', 'Relative Total H2B intensity',
#        'Relative Basal area', 'Relative Height to BM'],
#       dtype='object', name='Name')

# %%
results.ranking_[X.columns == 'Mean curvature']
# Out:
# array([1])

# %% [markdown]
# ## Misc: visualizations

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
divisions_12h = pd.read_pickle(path.join(dataset_dir,f'divisions_12h.pkl'))

sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell volume exponential growth rate',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Mean curvature',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Basal area',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Relative Basal area',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell volume',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Relative Cell volume',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell cycle duration',kind='swarm')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='G1 duration',kind='swarm')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='SG2 duration',kind='swarm')
# Out:
# /opt/miniconda3/envs/python39/lib/python3.9/site-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/miniconda3/envs/python39/lib/python3.9/site-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
