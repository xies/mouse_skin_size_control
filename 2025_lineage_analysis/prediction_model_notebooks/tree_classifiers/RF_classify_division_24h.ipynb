# %% [markdown]
# ## 0. Load datasets

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection, feature_selection, metrics, inspection, pipeline
from sklearn import ensemble
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted

# %matplotlib widget

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
basals = pd.read_pickle(path.join(dataset_dir,f'basals.pkl'))
division_24h = pd.read_pickle(path.join(dataset_dir,f'divisions_24h.pkl'))

# censor the 'answers'
features2drop = [(f,a) for f,a in division_24h.columns if 'Time' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'Manual' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'duration' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'Total' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'cell coords' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'smoothed' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in division_24h.columns if 'exponential' in f and not 'G1 only' in f]
features2drop += ['Z','Z-cyto']
division_24h = division_24h[~np.isnan(division_24h['Num daughter differentiated','Meta'])]
division_24h = division_24h.drop(features2drop,axis=1)
print(len(division_24h))
# Out:
# 204
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/3008297092.py:16: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   division_24h = division_24h.drop(features2drop,axis=1)

# %%
# Grouped Standard Scaler
class GroupedStandardScaler(BaseEstimator, TransformerMixin):
    """
    Standardize features by removing the mean and scaling to unit variance,
    computed separately for each group defined by a categorical variable.
    
    Parameters
    ----------
    group_col : str
        Name of the categorical column to group by for standardization
    
    with_mean : bool, default=True
        If True, center the data before scaling
    
    with_std : bool, default=True
        If True, scale the data to unit variance
    
    Attributes
    ----------
    group_means_ : dict
        Dictionary mapping group values to mean arrays
    
    group_stds_ : dict
        Dictionary mapping group values to standard deviation arrays
    
    feature_names_ : list
        List of feature column names (excluding group_col)
    
    groups_ : array
        Unique group values seen during fit
    """
    
    def __init__(self, group_col, with_mean=True, with_std=True):
        self.group_col = group_col
        self.with_mean = with_mean
        self.with_std = with_std
    
    def fit(self, X, y=None):
        """
        Compute the mean and std to be used for later scaling, per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data used to compute the per-group means and standard deviations
            used for later scaling along the features axis.
        
        y : None
            Ignored
        
        Returns
        -------
        self : object
            Fitted scaler
        """
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Store feature names (excluding group column)
        self.feature_names_ = [col for col in X.columns if col != self.group_col]
        
        # Use groupby for vectorized computation
        grouped = X.groupby(self.group_col)[self.feature_names_]
        
        if self.with_mean:
            self.group_means_ = grouped.mean()
        else:
            self.group_means_ = pd.DataFrame(
                0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        if self.with_std:
            self.group_stds_ = grouped.std()
            # Replace zero std with 1 to avoid division by zero
            self.group_stds_ = self.group_stds_.replace(0, 1.0)
        else:
            self.group_stds_ = pd.DataFrame(
                1.0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        return self
    
    def transform(self, X):
        """
        Perform standardization by centering and scaling per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to transform
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy to avoid modifying original
        X_transformed = X.copy()
        
        # Align means and stds with X using merge (much faster than map)
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized standardization
        X_transformed[self.feature_names_] = (
            X[self.feature_names_].values - means_aligned[self.feature_names_].values
        ) / stds_aligned[self.feature_names_].values
        
        # Check for unseen groups (NaN values after join)
        if means_aligned[self.feature_names_].isna().any().any():
            unseen_groups = X.loc[means_aligned[self.feature_names_].isna().any(axis=1), self.group_col].unique()
            import warnings
            warnings.warn(f"Found unseen groups during transform: {unseen_groups}. These samples will not be standardized.")
            # Keep original values for unseen groups (where NaN resulted)
            nan_mask = means_aligned[self.feature_names_].isna().any(axis=1)
            X_transformed.loc[nan_mask, self.feature_names_] = X.loc[nan_mask, self.feature_names_]
        
        return X_transformed.drop(columns=self.group_col)
    
    def fit_transform(self, X, y=None):
        """
        Fit to data, then transform it.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            Input data
        
        y : None
            Ignored
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        return self.fit(X, y).transform(X)
    
    def inverse_transform(self, X):
        """
        Scale back the data to the original representation per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to inverse transform
        
        Returns
        -------
        X_original : pandas DataFrame of shape (n_samples, n_features)
            DataFrame in original scale
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy
        X_original = X.copy()
        
        # Align means and stds with X using merge
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized inverse transformation
        X_original[self.feature_names_] = (
            X[self.feature_names_].values * stds_aligned[self.feature_names_].values
        ) + means_aligned[self.feature_names_].values
        
        return X_original

# %%
# Helper functions
def get_balanced_df_by_category(df,category,subsample=None,replacement=True):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]

    num_to_sample = min(subsample if subsample is not None else num_per_category.min(), num_per_category.min())
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member.sample(num_to_sample,replace=replacement))
        else:
            output.append(member.sample(num_to_sample,replace=replacement))
    output = pd.concat(output,ignore_index=True)
    
    return output

def predict_feature(df:pd.DataFrame,
                    classifier,
                    feature2predict,
                    groupby_name = 'Region',
                    Niter:int=100,
                    model_params = {},
                    measurement_level_name:str='Measurement'):
    training_set = []
    Y_test = []
    Y_pred = []
    models = []
    for i in tqdm(range(Niter)):

        # rng = np.random.RandomState(0)
        df_ = get_balanced_df_by_category(df, df[feature2predict,'Meta'].values)
        
        pipe = pipeline.make_pipeline(GroupedStandardScaler('Region'),
                                      classifier(random_state=i,**model_params) )
        
        y = df_[feature2predict,'Meta'].astype(float)
        X = df_.xs(measurement_level_name,level=1,axis=1).astype(float)
        X[np.isinf(X)] = np.nan
        X['Region'] = df_['Region']
        X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,random_state=i+1)
        
        model = pipe.fit(X_train,y_train)
        models.append(model)
        
        Y_test.append(y_test)
        Y_pred.append(model.predict(X_test))

        training_set.append((X_train,y_train,X_test,y_test))
        
    return [np.stack((np.array(Y_test),np.array(Y_pred))),models,training_set]

# %% [markdown]
# ## 1. Predict from mother division frame

# %%
feature2predict = 'At least one daughter differentiated'
division_24h.droplevel(axis=1,level=1).groupby(feature2predict).count()
# Out:
# Name                                  Nuclear volume  Nuclear solidity    Y  \
# At least one daughter differentiated
# False                                             47                47   47
# True                                             157               157  157
#
# Name                                    X  Nuclear height  Cell volume  \
# At least one daughter differentiated
# False                                  47              47           47
# True                                  157             157          157
#
# Name                                  Y-cyto  X-cyto  Axial component  \
# At least one daughter differentiated
# False                                     47      47               47
# True                                     157     157              157
#
# Name                                  Planar component 1  ...  \
# At least one daughter differentiated                      ...
# False                                                 47  ...
# True                                                 157  ...
#
# Name                                  Std adjac Mean curvature 10um at 1 frame prior  \
# At least one daughter differentiated
# False                                                                             39
# True                                                                             122
#
# Name                                  Max adjac cyto_shcoeffs_L1M1C at 1 frame prior  \
# At least one daughter differentiated
# False                                                                             39
# True                                                                             122
#
# Name                                  Min adjac cyto_shcoeffs_L1M1S at 1 frame prior  \
# At least one daughter differentiated
# False                                                                             39
# True                                                                             122
#
# Name                                  Median adjac Apical area at 1 frame prior  \
# At least one daughter differentiated
# False                                                                        39
# True                                                                        122
#
# Name                                  Std adjac Axial angle at 1 frame prior  \
# At least one daughter differentiated
# False                                                                     39
# True                                                                     122
#
# Name                                  Num neighbor division 1 frame prior  \
# At least one daughter differentiated
# False                                                                  39
# True                                                                  122
#
# Name                                  Num neighbor delamination 1 frame prior  \
# At least one daughter differentiated
# False                                                                      39
# True                                                                      122
#
# Name                                  Num daughter differentiated  \
# At least one daughter differentiated
# False                                                          47
# True                                                          157
#
# Name                                  Both daughters differentiated  Region
# At least one daughter differentiated
# False                                                            47      47
# True                                                            157     157
#
# [2 rows x 1387 columns]

# %%
# Run classifier
# axis0: observation axis1: prediction

predictions,models,training_set = predict_feature(division_24h,
                                     ensemble.RandomForestClassifier, feature2predict,Niter=100)
# Out:
#   0%|                                                                                                | 0/100 [00:00<?, ?it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   1%|▉                                                                                       | 1/100 [00:00<01:05,  1.50it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   2%|█▊                                                                                      | 2/100 [00:01<01:03,  1.54it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   3%|██▋                                                                                     | 3/100 [00:01<01:02,  1.56it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   4%|███▌                                                                                    | 4/100 [00:04<01:55,  1.21s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   5%|████▍                                                                                   | 5/100 [00:04<01:34,  1.00it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   6%|█████▎                                                                                  | 6/100 [00:05<01:22,  1.14it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   7%|██████▏                                                                                 | 7/100 [00:05<01:14,  1.25it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   8%|███████                                                                                 | 8/100 [00:07<01:43,  1.12s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#   9%|███████▉                                                                                | 9/100 [00:08<01:28,  1.03it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  10%|████████▋                                                                              | 10/100 [00:08<01:17,  1.16it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  11%|█████████▌                                                                             | 11/100 [00:09<01:10,  1.27it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  12%|██████████▍                                                                            | 12/100 [00:10<01:05,  1.35it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  13%|███████████▎                                                                           | 13/100 [00:12<01:33,  1.07s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  14%|████████████▏                                                                          | 14/100 [00:12<01:20,  1.07it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  15%|█████████████                                                                          | 15/100 [00:13<01:11,  1.19it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  16%|█████████████▉                                                                         | 16/100 [00:13<01:05,  1.29it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  17%|██████████████▊                                                                        | 17/100 [00:14<01:00,  1.37it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  18%|███████████████▋                                                                       | 18/100 [00:16<01:27,  1.06s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  19%|████████████████▌                                                                      | 19/100 [00:17<01:15,  1.07it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  20%|█████████████████▍                                                                     | 20/100 [00:17<01:07,  1.19it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  21%|██████████████████▎                                                                    | 21/100 [00:18<01:01,  1.29it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  22%|███████████████████▏                                                                   | 22/100 [00:18<00:57,  1.35it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  23%|████████████████████                                                                   | 23/100 [00:20<01:24,  1.10s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  24%|████████████████████▉                                                                  | 24/100 [00:21<01:12,  1.04it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  25%|█████████████████████▊                                                                 | 25/100 [00:22<01:04,  1.16it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  26%|██████████████████████▌                                                                | 26/100 [00:22<00:59,  1.25it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  27%|███████████████████████▍                                                               | 27/100 [00:23<00:54,  1.33it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  28%|████████████████████████▎                                                              | 28/100 [00:25<01:22,  1.15s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  29%|█████████████████████████▏                                                             | 29/100 [00:26<01:11,  1.00s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  30%|██████████████████████████                                                             | 30/100 [00:26<01:02,  1.11it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  31%|██████████████████████████▉                                                            | 31/100 [00:27<00:56,  1.22it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  32%|███████████████████████████▊                                                           | 32/100 [00:28<00:52,  1.30it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  33%|████████████████████████████▋                                                          | 33/100 [00:28<00:49,  1.36it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  34%|█████████████████████████████▌                                                         | 34/100 [00:30<01:13,  1.11s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  35%|██████████████████████████████▍                                                        | 35/100 [00:31<01:03,  1.03it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  36%|███████████████████████████████▎                                                       | 36/100 [00:32<00:55,  1.15it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  37%|████████████████████████████████▏                                                      | 37/100 [00:32<00:50,  1.24it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  38%|█████████████████████████████████                                                      | 38/100 [00:33<00:47,  1.32it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  39%|█████████████████████████████████▉                                                     | 39/100 [00:33<00:43,  1.39it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  40%|██████████████████████████████████▊                                                    | 40/100 [00:36<01:08,  1.14s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  41%|███████████████████████████████████▋                                                   | 41/100 [00:36<00:58,  1.02it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  42%|████████████████████████████████████▌                                                  | 42/100 [00:37<00:50,  1.14it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  43%|█████████████████████████████████████▍                                                 | 43/100 [00:37<00:45,  1.24it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  44%|██████████████████████████████████████▎                                                | 44/100 [00:38<00:42,  1.32it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  45%|███████████████████████████████████████▏                                               | 45/100 [00:39<00:39,  1.39it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  46%|████████████████████████████████████████                                               | 46/100 [00:41<00:59,  1.10s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  47%|████████████████████████████████████████▉                                              | 47/100 [00:41<00:51,  1.04it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  48%|█████████████████████████████████████████▊                                             | 48/100 [00:42<00:44,  1.16it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  49%|██████████████████████████████████████████▋                                            | 49/100 [00:43<00:40,  1.27it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  50%|███████████████████████████████████████████▌                                           | 50/100 [00:43<00:37,  1.35it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  51%|████████████████████████████████████████████▎                                          | 51/100 [00:44<00:34,  1.41it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  52%|█████████████████████████████████████████████▏                                         | 52/100 [00:46<00:55,  1.15s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  53%|██████████████████████████████████████████████                                         | 53/100 [00:47<00:46,  1.00it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  54%|██████████████████████████████████████████████▉                                        | 54/100 [00:47<00:40,  1.13it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  55%|███████████████████████████████████████████████▊                                       | 55/100 [00:48<00:36,  1.24it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  56%|████████████████████████████████████████████████▋                                      | 56/100 [00:49<00:33,  1.33it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  57%|█████████████████████████████████████████████████▌                                     | 57/100 [00:49<00:30,  1.39it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  58%|██████████████████████████████████████████████████▍                                    | 58/100 [00:52<00:49,  1.18s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  59%|███████████████████████████████████████████████████▎                                   | 59/100 [00:52<00:41,  1.02s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  60%|████████████████████████████████████████████████████▏                                  | 60/100 [00:53<00:36,  1.11it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  61%|█████████████████████████████████████████████████████                                  | 61/100 [00:53<00:32,  1.22it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  62%|█████████████████████████████████████████████████████▉                                 | 62/100 [00:54<00:29,  1.30it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  63%|██████████████████████████████████████████████████████▊                                | 63/100 [00:55<00:27,  1.37it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  64%|███████████████████████████████████████████████████████▋                               | 64/100 [00:55<00:25,  1.42it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  65%|████████████████████████████████████████████████████████▌                              | 65/100 [00:58<00:41,  1.18s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  66%|█████████████████████████████████████████████████████████▍                             | 66/100 [00:58<00:34,  1.02s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  67%|██████████████████████████████████████████████████████████▎                            | 67/100 [00:59<00:29,  1.11it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  68%|███████████████████████████████████████████████████████████▏                           | 68/100 [01:00<00:26,  1.22it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  69%|████████████████████████████████████████████████████████████                           | 69/100 [01:00<00:23,  1.31it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  70%|████████████████████████████████████████████████████████████▉                          | 70/100 [01:01<00:21,  1.38it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  71%|█████████████████████████████████████████████████████████████▊                         | 71/100 [01:01<00:20,  1.43it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  72%|██████████████████████████████████████████████████████████████▋                        | 72/100 [01:04<00:34,  1.24s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  73%|███████████████████████████████████████████████████████████████▌                       | 73/100 [01:05<00:28,  1.06s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  74%|████████████████████████████████████████████████████████████████▍                      | 74/100 [01:05<00:24,  1.07it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  75%|█████████████████████████████████████████████████████████████████▎                     | 75/100 [01:06<00:20,  1.19it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  76%|██████████████████████████████████████████████████████████████████                     | 76/100 [01:06<00:18,  1.29it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  77%|██████████████████████████████████████████████████████████████████▉                    | 77/100 [01:07<00:16,  1.36it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  78%|███████████████████████████████████████████████████████████████████▊                   | 78/100 [01:08<00:15,  1.43it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  79%|████████████████████████████████████████████████████████████████████▋                  | 79/100 [01:10<00:26,  1.28s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  80%|█████████████████████████████████████████████████████████████████████▌                 | 80/100 [01:11<00:21,  1.08s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  81%|██████████████████████████████████████████████████████████████████████▍                | 81/100 [01:12<00:18,  1.05it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  82%|███████████████████████████████████████████████████████████████████████▎               | 82/100 [01:12<00:15,  1.17it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  83%|████████████████████████████████████████████████████████████████████████▏              | 83/100 [01:13<00:13,  1.27it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  84%|█████████████████████████████████████████████████████████████████████████              | 84/100 [01:14<00:11,  1.36it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  85%|█████████████████████████████████████████████████████████████████████████▉             | 85/100 [01:14<00:10,  1.41it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  86%|██████████████████████████████████████████████████████████████████████████▊            | 86/100 [01:15<00:09,  1.46it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  87%|███████████████████████████████████████████████████████████████████████████▋           | 87/100 [01:17<00:16,  1.23s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  88%|████████████████████████████████████████████████████████████████████████████▌          | 88/100 [01:18<00:12,  1.05s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  89%|█████████████████████████████████████████████████████████████████████████████▍         | 89/100 [01:19<00:10,  1.08it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  90%|██████████████████████████████████████████████████████████████████████████████▎        | 90/100 [01:19<00:08,  1.19it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  91%|███████████████████████████████████████████████████████████████████████████████▏       | 91/100 [01:20<00:06,  1.29it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  92%|████████████████████████████████████████████████████████████████████████████████       | 92/100 [01:20<00:05,  1.36it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  93%|████████████████████████████████████████████████████████████████████████████████▉      | 93/100 [01:21<00:04,  1.42it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  94%|█████████████████████████████████████████████████████████████████████████████████▊     | 94/100 [01:22<00:04,  1.47it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  95%|██████████████████████████████████████████████████████████████████████████████████▋    | 95/100 [01:24<00:06,  1.23s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  96%|███████████████████████████████████████████████████████████████████████████████████▌   | 96/100 [01:25<00:04,  1.05s/it]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  97%|████████████████████████████████████████████████████████████████████████████████████▍  | 97/100 [01:25<00:02,  1.07it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  98%|█████████████████████████████████████████████████████████████████████████████████████▎ | 98/100 [01:26<00:01,  1.18it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
#  99%|██████████████████████████████████████████████████████████████████████████████████████▏| 99/100 [01:27<00:00,  1.27it/s]/var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_93909/1984456293.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['Region'] = df_['Region']
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:27<00:00,  1.14it/s]

# %%
feat_names = division_24h.xs('Measurement',level=1,axis=1).columns
importances = pd.DataFrame(columns = feat_names,index=range(len(models)))
for i,m in enumerate(models):
    importances.loc[i,:] = m[1].feature_importances_

plt.figure()
importances.dropna(how='all').mean(axis=0).sort_values().dropna().tail(20).plot.bar()
plt.tight_layout()
plt.ylabel('Impurity importance')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Feature selection

# %%
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Mean curvature',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='cyto_shcoeffs_L3M0C',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Basal area',kind='violin')
sb.catplot(divisions.droplevel(axis=1,level=1),x=feature2predict,y='Median adjac Cell volume',kind='violin')

# %% [markdown]
# ### RFE

# %%
from sklearn import feature_selection

X = divisions.xs('Measurement',level=1,axis=1)
y = divisions[feature2predict,'Meta'].astype(bool)
m = ensemble.RandomForestClassifier().fit(X,y)

results = feature_selection.RFECV(m).fit(X,y)

# %%
plt.errorbar(x=results.cv_results_['n_features'][:50],
        y=results.cv_results_['mean_test_score'][:50],
        yerr=results.cv_results_['std_test_score'][:50])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
print(f'# optimal features: {results.n_features_}')

selected = X.columns[ results.ranking_ == 1]
print(selected)
# Out:
# # optimal features: 2
# Index(['cyto_shcoeffs_L3M0C', 'Relative Height to BM'], dtype='object', name='Name')

# %% [markdown]
# ## 2. ExtraTreesClassifier

# %%
# Run classifier
# axis0: observation axis1: prediction

predictions,models = predict_feature(divisions, ensemble.ExtraTreesClassifier(), feature2predict,Niter=1000)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:51<00:00, 19.46it/s]

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.title('Predict daughter-fate from division frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
# plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
# plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict daughter-fate from division frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')

# %%
feat_names = divisions.xs('Measurement',level=1,axis=1).columns
importances = pd.DataFrame(columns = feat_names,index=range(len(models)))
for i,m in enumerate(models):
    importances.loc[i,feat_names[m[1].get_support()]] = m[2].feature_importances_

importances.dropna(how='all').mean(axis=0).sort_values().dropna().tail(20).plot.bar()

plt.ylabel('Impurity importance')
# Out:
# Text(0, 0.5, 'Impurity importance')

# %%
from sklearn import feature_selection

X = divisions.xs('Measurement',level=1,axis=1)
y = divisions[feature2predict,'Meta'].astype(bool)
m = ensemble.ExtraTreesClassifier().fit(X,y)

results = feature_selection.RFECV(m).fit(X,y)

# %%
plt.errorbar(x=results.cv_results_['n_features'][:50],
        y=results.cv_results_['mean_test_score'][:50],
        yerr=results.cv_results_['std_test_score'][:50])

print(f'# optimal features: {results.n_features_}')

selected = X.columns[ results.ranking_ == 1]
print(selected)
# Out:
# # optimal features: 9
# Index(['Basal area', 'Height to BM', 'cyto_shcoeffs_L3M0C',
#        'nuc_shcoeffs_L3M2S', 'Median adjac nuc_shcoeffs_L5M2S',
#        'Min adjac Planar component 1', 'Relative Total H2B intensity',
#        'Relative Basal area', 'Relative Height to BM'],
#       dtype='object', name='Name')

# %%
results.ranking_[X.columns == 'Mean curvature']
# Out:
# array([1])

# %% [markdown]
# ## Misc: visualizations

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
divisions_12h = pd.read_pickle(path.join(dataset_dir,f'divisions_12h.pkl'))

sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell volume exponential growth rate',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Mean curvature',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Basal area',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Relative Basal area',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell volume',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Relative Cell volume',kind='box')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='Cell cycle duration',kind='swarm')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='G1 duration',kind='swarm')
sb.catplot(divisions_12h.droplevel(axis=1,level=1),x='Num daughter differentiated',y='SG2 duration',kind='swarm')
# Out:
# /opt/miniconda3/envs/python39/lib/python3.9/site-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/miniconda3/envs/python39/lib/python3.9/site-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
