# %%
import numpy as np
import pandas as pd

# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from sklearn import preprocessing, model_selection, linear_model
from sklearn import ensemble, metrics

dirname = '/Users/xies/OneDrive - Stanford/Skin/Mesa et al/W-R1/'
all_df = pd.read_pickle(path.join(dirname,'Mastodon/single_timepoints_dynamics_aggregated_lookback_history.pkl'))
all_df = all_df.drop_duplicates().sort_index()
all_tracks = {trackID:t for trackID,t in all_df.reset_index().groupby('TrackID')}

# %%
df = all_df[all_df['Fate known','Meta']]
df = df[ ~df['Border','Meta']]
df = df[ df['Cell type','Meta'] == 'Basal']

births = df[df['Birth frame','Meta']]
births[('Relative basal area','Measurement')] = \
    births['Basal area','Measurement'] / births['Mean adjac Basal area','Measurement']

births
# Out:
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_27940/3640751628.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   births[('Relative basal area','Measurement')] = \
# Name          Nuclear volume Nuclear solidity Nuclear bbox top  \
# Metadata         Measurement      Measurement      Measurement
# Frame TrackID
# 1     3             116.6250         0.848954             41.0
#       4             101.6875         0.813500             42.0
#       29            151.6250         0.854526             49.0
#       30            143.4375         0.811815             41.0
#       39            138.8750         0.915157             44.0
# ...                      ...              ...              ...
# 12    827            96.8750         0.738799             49.0
#       869           121.8750         0.845620             47.0
# 13    823           134.4375         0.831465             48.0
#       844           132.0625         0.916305             44.0
#       1022          101.9375         0.780756             43.0
#
# Name          Nuclear bbox bottom           Z           Y           X  \
# Metadata              Measurement Measurement Measurement Measurement
# Frame TrackID
# 1     3                      51.0   45.346731  107.626340   36.175643
#       4                      52.0   46.580824  106.917179   41.199754
#       29                     56.0   51.597279   22.018343   78.469291
#       30                     52.0   46.395643   18.079521   82.449455
#       39                     54.0   47.996850   47.045792   87.840684
# ...                           ...         ...         ...         ...
# 12    827                    58.0   52.716774   19.161290   12.363387
#       869                    56.0   50.438974   57.029615   42.455897
# 13    823                    59.0   52.760112   12.942701   22.346467
#       844                    55.0   48.685282   18.620800   97.751775
#       1022                   51.0   46.083998  109.656652   15.609135
#
# Name          Nuclear height Cell volume      Z-cyto  ...  \
# Metadata         Measurement Measurement Measurement  ...
# Frame TrackID                                         ...
# 1     3                -10.0    278.5000   44.794434  ...
#       4                -10.0    294.6250   46.476665  ...
#       29                -7.0    291.5000   51.080189  ...
#       30               -11.0    497.6875   47.175688  ...
#       39               -10.0    345.6875   47.974146  ...
# ...                      ...         ...         ...  ...
# 12    827               -9.0    330.9375   53.250803  ...
#       869               -9.0    329.2500   49.575740  ...
# 13    823              -11.0    365.0000   52.984589  ...
#       844              -11.0    275.6875   48.847654  ...
#       1022              -8.0    271.1250   45.722222  ...
#
# Name          Mean adjac Cell volume standard at 1 frame prior  \
# Metadata                                           Measurement
# Frame TrackID
# 1     3                                               0.908434
#       4                                               0.908434
#       29                                              0.916417
#       30                                              0.916417
#       39                                              1.035935
# ...                                                        ...
# 12    827                                             1.034912
#       869                                              1.03202
# 13    823                                             0.907546
#       844                                              0.97493
#       1022                                            0.902094
#
# Name          Std adjac cyto_shcoeffs_L4M5C at 1 frame prior  \
# Metadata                                         Measurement
# Frame TrackID
# 1     3                                                  0.0
#       4                                                  0.0
#       29                                                 0.0
#       30                                                 0.0
#       39                                                 0.0
# ...                                                      ...
# 12    827                                                0.0
#       869                                                0.0
# 13    823                                                0.0
#       844                                                0.0
#       1022                                               0.0
#
# Name          Median adjac Apical area smoothed at 1 frame prior  \
# Metadata                                             Measurement
# Frame TrackID
# 1     3                                                     7.75
#       4                                                     7.75
#       29                                                 15.0625
#       30                                                 15.0625
#       39                                                 5.03125
# ...                                                          ...
# 12    827                                              27.340625
#       869                                               8.435938
# 13    823                                              23.625893
#       844                                               14.68125
#       1022                                                  12.4
#
# Name          Std adjac cyto_shcoeffs_L1M5C at 1 frame prior  \
# Metadata                                         Measurement
# Frame TrackID
# 1     3                                                  0.0
#       4                                                  0.0
#       29                                                 0.0
#       30                                                 0.0
#       39                                                 0.0
# ...                                                      ...
# 12    827                                                0.0
#       869                                                0.0
# 13    823                                                0.0
#       844                                                0.0
#       1022                                               0.0
#
# Name          Num neighbor division 1 frame prior  \
# Metadata                              Measurement
# Frame TrackID
# 1     3                                       1.0
#       4                                       1.0
#       29                                      1.0
#       30                                      1.0
#       39                                      0.0
# ...                                           ...
# 12    827                                     1.0
#       869                                     0.0
# 13    823                                     0.0
#       844                                     0.0
#       1022                                    0.0
#
# Name          Num neighbor delamination 1 frame prior  \
# Metadata                                  Measurement
# Frame TrackID
# 1     3                                           0.0
#       4                                           0.0
#       29                                          0.0
#       30                                          0.0
#       39                                          0.0
# ...                                               ...
# 12    827                                         0.0
#       869                                         0.0
# 13    823                                         0.0
#       844                                         1.0
#       1022                                        0.0
#
# Name          Num daughter differentiated  \
# Metadata                             Meta
# Frame TrackID
# 1     3                               NaN
#       4                               NaN
#       29                              NaN
#       30                              NaN
#       39                              NaN
# ...                                   ...
# 12    827                             NaN
#       869                             NaN
# 13    823                             NaN
#       844                             NaN
#       1022                            NaN
#
# Name          At least one daughter differentiated  \
# Metadata                                      Meta
# Frame TrackID
# 1     3                                        NaN
#       4                                        NaN
#       29                                       NaN
#       30                                       NaN
#       39                                       NaN
# ...                                            ...
# 12    827                                      NaN
#       869                                      NaN
# 13    823                                      NaN
#       844                                      NaN
#       1022                                     NaN
#
# Name          Both daughters differentiated Relative basal area
# Metadata                               Meta         Measurement
# Frame TrackID
# 1     3                                 NaN            1.059543
#       4                                 NaN            0.551845
#       29                                NaN            0.801679
#       30                                NaN                 NaN
#       39                                NaN            0.686334
# ...                                     ...                 ...
# 12    827                               NaN            0.653351
#       869                               NaN            0.137687
# 13    823                               NaN            1.066863
#       844                               NaN            0.274859
#       1022                              NaN            0.124577
#
# [397 rows x 2344 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 features
#
# NameError: name 'features' is not defined

# %%
measurements = births.xs('Measurement',level=1,axis=1)
features = pd.DataFrame()
features['name'] = measurements.columns
features =features.set_index('name')
features['Num NA'] = measurements.isna().sum(axis=0)

_df = births.droplevel(level=1,axis=1)[['Basal area',
                                        'Relative basal area',
                                        'Cell volume exponential growth rate',
                                        'Mean curvature',
                                        'Will differentiate']].dropna()
_df = _df.rename(columns={'Basal area':'barea',
                  'Relative basal area':'rel_barea',
                  'Cell volume exponential growth rate':'vol_gr',
                  'Mean curvature':'mean_curv',
                  'Will differentiate':'diff',
                 })

_df = _df.reset_index(drop=True).astype(float)
X = _df.drop(columns='diff')
y = _df['diff']

X = preprocessing.StandardScaler().fit_transform(X)
X = pd.DataFrame(X,columns=['barea','rel_barea','vol_gr','mean_curv'])

# %%
import statsmodels.api as sm

X = sm.tools.add_constant(X)

model = sm.Logit(y,X).fit_regularized()
model.summary()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3393756477356428
#             Iterations: 29
#             Function evaluations: 29
#             Gradient evaluations: 29
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   diff   No. Observations:                  276
# Model:                          Logit   Df Residuals:                      271
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 29 Jul 2025   Pseudo R-squ.:                  0.5062
# Time:                        22:09:05   Log-Likelihood:                -93.668
# converged:                       True   LL-Null:                       -189.67
# Covariance Type:            nonrobust   LLR p-value:                 1.956e-40
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5796      0.194     -2.992      0.003      -0.959      -0.200
# barea         -1.0842      0.364     -2.979      0.003      -1.797      -0.371
# rel_barea     -0.1994      0.292     -0.682      0.495      -0.772       0.373
# vol_gr        -2.7924      0.342     -8.155      0.000      -3.464      -2.121
# mean_curv      0.1354      0.224      0.606      0.545      -0.303       0.574
# ==============================================================================
# """

# %%
effect_sizes = model.params
log_pvals = -np.log10(model.pvalues)
plt.scatter(effect_sizes,log_pvals)
plt.xlim([-3,3])
plt.hlines(-np.log10(0.01),xmin=-3,xmax=3, color='red')
plt.xlabel('Effect size'); plt.ylabel('-Log10(p)')

for name in effect_sizes.index:
    plt.text(x=effect_sizes[name]+0.1,y=log_pvals[name]+0.1,s=name)

# %%
[idx for idx in effect_sizes.index]
# Out:
# ['const', 'barea', 'rel_barea', 'vol_gr', 'mean_curv']

# %%
sb.regplot(_df,x='vol_gr',y='diff',logistic=True,y_jitter=0.1)
# Out:
# <Axes: xlabel='vol_gr', ylabel='diff'>

# %%
sb.regplot(_df,x='barea',y='diff',logistic=True,y_jitter=0.1)
# Out:
# <Axes: xlabel='barea', ylabel='diff'>

# %%
births[births['Basal area','Measurement'] > 80]
# Out:
# Name          Nuclear volume Nuclear solidity Nuclear bbox top  \
# Metadata         Measurement      Measurement      Measurement
# Frame TrackID
# 2     911           129.9375         0.845466             51.0
# 3     482           113.8125         0.798334             44.0
#
# Name          Nuclear bbox bottom           Z           Y           X  \
# Metadata              Measurement Measurement Measurement Measurement
# Frame TrackID
# 2     911                    60.0   55.427128     7.41366   31.979798
# 3     482                    54.0   48.035695   103.98078   76.032949
#
# Name          Nuclear height Cell volume      Z-cyto  ...  \
# Metadata         Measurement Measurement Measurement  ...
# Frame TrackID                                         ...
# 2     911               -9.0    831.1875   54.644785  ...
# 3     482              -10.0   1111.9375   50.151088  ...
#
# Name          Mean adjac Cell volume standard at 1 frame prior  \
# Metadata                                           Measurement
# Frame TrackID
# 2     911                                             0.847685
# 3     482                                             0.962292
#
# Name          Std adjac cyto_shcoeffs_L4M5C at 1 frame prior  \
# Metadata                                         Measurement
# Frame TrackID
# 2     911                                                0.0
# 3     482                                                0.0
#
# Name          Median adjac Apical area smoothed at 1 frame prior  \
# Metadata                                             Measurement
# Frame TrackID
# 2     911                                              13.720052
# 3     482                                              13.094643
#
# Name          Std adjac cyto_shcoeffs_L1M5C at 1 frame prior  \
# Metadata                                         Measurement
# Frame TrackID
# 2     911                                                0.0
# 3     482                                                0.0
#
# Name          Num neighbor division 1 frame prior  \
# Metadata                              Measurement
# Frame TrackID
# 2     911                                     0.0
# 3     482                                     0.0
#
# Name          Num neighbor delamination 1 frame prior  \
# Metadata                                  Measurement
# Frame TrackID
# 2     911                                         2.0
# 3     482                                         0.0
#
# Name          Num daughter differentiated  \
# Metadata                             Meta
# Frame TrackID
# 2     911                             NaN
# 3     482                             NaN
#
# Name          At least one daughter differentiated  \
# Metadata                                      Meta
# Frame TrackID
# 2     911                                      NaN
# 3     482                                      NaN
#
# Name          Both daughters differentiated Relative basal area
# Metadata                               Meta         Measurement
# Frame TrackID
# 2     911                               NaN            2.945483
# 3     482                               NaN            4.186462
#
# [2 rows x 2344 columns]

# %%
sb.heatmap(model.cov_params(), annot=True)
# Out:
# <Axes: >

# %%
sb.regplot(X,x='barea',y='vol_gr')
# Out:
# <Axes: xlabel='barea', ylabel='vol_gr'>
