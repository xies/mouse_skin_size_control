# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection, feature_selection, metrics, inspection, pipeline

from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted
from sklearn import covariance

# %matplotlib widget

# %%
# Helper functions
def get_balanced_df_by_category(df,category,subsample=None,replacement=True):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]

    num_to_sample = min(subsample if subsample is not None else num_per_category.min(), num_per_category.min())
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member.sample(num_to_sample,replace=replacement))
        else:
            output.append(member.sample(num_to_sample,replace=replacement))
    output = pd.concat(output,ignore_index=True)
    
    return output
    
def calculate_condition_number(X,estimator=covariance.MinCovDet):
    C = estimator().fit(X)
    cov = pd.DataFrame(C.covariance_,index=X.columns,columns=X.columns)
    D,L = linalg.eig(cov)
    cond_number = D.max() / D.min()
    return cond_number,cov


# Rank co-correlates
def print_top_cocorrelates(cov,num2print=50):
    cov_no_diag = cov.values
    cov_no_diag[np.eye(len(cov)).astype(bool)] = np.nan
    cov_no_diag[np.triu(np.ones(len(cov))).astype(bool)] = np.nan
    cov_no_diag = pd.DataFrame(cov_no_diag,index=cov.index,columns=cov.columns)
    return cov_no_diag.stack().dropna().abs().sort_values().tail(num2print)

# %%
# Grouped Standard Scaler
class GroupedStandardScaler(BaseEstimator, TransformerMixin):
    """
    Standardize features by removing the mean and scaling to unit variance,
    computed separately for each group defined by a categorical variable.
    
    Parameters
    ----------
    group_col : str
        Name of the categorical column to group by for standardization
    
    with_mean : bool, default=True
        If True, center the data before scaling
    
    with_std : bool, default=True
        If True, scale the data to unit variance
    
    Attributes
    ----------
    group_means_ : dict
        Dictionary mapping group values to mean arrays
    
    group_stds_ : dict
        Dictionary mapping group values to standard deviation arrays
    
    feature_names_ : list
        List of feature column names (excluding group_col)
    
    groups_ : array
        Unique group values seen during fit
    """
    
    def __init__(self, group_col, with_mean=True, with_std=True):
        self.group_col = group_col
        self.with_mean = with_mean
        self.with_std = with_std
    
    def fit(self, X, y=None):
        """
        Compute the mean and std to be used for later scaling, per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data used to compute the per-group means and standard deviations
            used for later scaling along the features axis.
        
        y : None
            Ignored
        
        Returns
        -------
        self : object
            Fitted scaler
        """
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Store feature names (excluding group column)
        self.feature_names_ = [col for col in X.columns if col != self.group_col]
        
        # Use groupby for vectorized computation
        grouped = X.groupby(self.group_col)[self.feature_names_]
        
        if self.with_mean:
            self.group_means_ = grouped.mean()
        else:
            self.group_means_ = pd.DataFrame(
                0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        if self.with_std:
            self.group_stds_ = grouped.std()
            # Replace zero std with 1 to avoid division by zero
            self.group_stds_ = self.group_stds_.replace(0, 1.0)
        else:
            self.group_stds_ = pd.DataFrame(
                1.0, 
                index=grouped.groups.keys(), 
                columns=self.feature_names_
            )
        
        return self
    
    def transform(self, X):
        """
        Perform standardization by centering and scaling per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to transform
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy to avoid modifying original
        X_transformed = X.copy()
        
        # Align means and stds with X using merge (much faster than map)
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized standardization
        X_transformed[self.feature_names_] = (
            X[self.feature_names_].values - means_aligned[self.feature_names_].values
        ) / stds_aligned[self.feature_names_].values
        
        # Check for unseen groups (NaN values after join)
        if means_aligned[self.feature_names_].isna().any().any():
            unseen_groups = X.loc[means_aligned[self.feature_names_].isna().any(axis=1), self.group_col].unique()
            import warnings
            warnings.warn(f"Found unseen groups during transform: {unseen_groups}. These samples will not be standardized.")
            # Keep original values for unseen groups (where NaN resulted)
            nan_mask = means_aligned[self.feature_names_].isna().any(axis=1)
            X_transformed.loc[nan_mask, self.feature_names_] = X.loc[nan_mask, self.feature_names_]
        
        return X_transformed.drop(columns=self.group_col)
    
    def fit_transform(self, X, y=None):
        """
        Fit to data, then transform it.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            Input data
        
        y : None
            Ignored
        
        Returns
        -------
        X_transformed : pandas DataFrame of shape (n_samples, n_features)
            Transformed DataFrame
        """
        return self.fit(X, y).transform(X)
    
    def inverse_transform(self, X):
        """
        Scale back the data to the original representation per group.
        
        Parameters
        ----------
        X : pandas DataFrame of shape (n_samples, n_features)
            The data to inverse transform
        
        Returns
        -------
        X_original : pandas DataFrame of shape (n_samples, n_features)
            DataFrame in original scale
        """
        check_is_fitted(self, ['group_means_', 'group_stds_', 'feature_names_'])
        
        if not isinstance(X, pd.DataFrame):
            raise ValueError("X must be a pandas DataFrame")
        
        if self.group_col not in X.columns:
            raise ValueError(f"group_col '{self.group_col}' not found in DataFrame")
        
        # Create a copy
        X_original = X.copy()
        
        # Align means and stds with X using merge
        means_aligned = X[[self.group_col]].join(
            self.group_means_, on=self.group_col, how='left'
        )
        stds_aligned = X[[self.group_col]].join(
            self.group_stds_, on=self.group_col, how='left'
        )
        
        # Vectorized inverse transformation
        X_original[self.feature_names_] = (
            X[self.feature_names_].values * stds_aligned[self.feature_names_].values
        ) + means_aligned[self.feature_names_].values
        
        return X_original

# %%
# Load data
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
model_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/'

all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
basals = pd.read_pickle(path.join(dataset_dir,f'basals.pkl'))
births = pd.read_pickle(path.join(dataset_dir,f'births.pkl'))

# censor the 'answers'
features2drop = [(f,a) for f,a in births.columns if 'Time' in f]
features2drop += [(f,a) for f,a in births.columns if 'smoothed' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in births.columns if 'standard' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in births.columns if 'cell coords' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in births.columns if 'duration' in f]
features2drop += [(f,a) for f,a in births.columns if 'Manual' in f]
features2drop += [(f,a) for f,a in births.columns if '2um' in f]
features2drop += [(f,a) for f,a in births.columns if '10um' in f]
features2drop += [(f,a) for f,a in births.columns if '15um' in f]
features2drop += [(f,a) for f,a in births.columns if 'Total' in f]
features2drop += ['Z','Z-cyto']
births = births.drop(columns=features2drop)
print(len(births))

feature2predict = 'Will divide'
_df = births.dropna(subset=[(feature2predict,'Meta')])

y = _df[feature2predict,'Meta']
X = _df.xs('Measurement',level=1,axis=1)

important_features = X.columns
X_scaled = preprocessing.StandardScaler().fit_transform(X)

# X['Region'] = [f[0] for f in X.index.get_level_values(1).str.split('_',expand=True)]
# X_scaled = GroupedStandardScaler('Region').fit_transform(X)
X_scaled = pd.DataFrame(X_scaled,index=X.index,columns= important_features)
print(X_scaled.shape)
# Out:
# 1333
# (1333, 788)
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19992/1981834484.py:21: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   births = births.drop(columns=features2drop)
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %% [markdown]
# # 1. Pre-selection method: RF trees

# %%
# Take top 50 features by importance and see their correlation matrix
importances = pd.read_csv(path.join(model_dir,'Random_forest_birth/importances.csv'),
                         index_col=0)
importances = importances.rename(columns={'0':'RF_imp'})

num_to_take = 20

important_features = importances.sort_values(by='RF_imp').tail(num_to_take).index

plt.close('all')
fig = plt.figure(figsize=(8,4))
plt.plot(importances.sort_values(by='RF_imp')['RF_imp'][::-1][:num_to_take+10] )
plt.vlines(x=num_to_take-0.5,ymin=0,ymax=0.01,color='r')
plt.xticks(rotation=90)
plt.tight_layout()
fig.savefig(path.join(model_dir,'Random_forest_division/importance_cutoff.svg'))

features2keep = important_features
# Out:
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19992/1529983995.py:15: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Calculate the condition number
from numpy import linalg

plt.figure(figsize=(8,7))
cond_num, cov = calculate_condition_number(X_scaled)
sb.heatmap(cov)
plt.tight_layout()
print(cov.shape)

D,L = linalg.eig(cov)
print(f'Condition number: {cond_num}')

# print_top_cocorrelates(cov)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 from numpy import linalg
#       4 plt.figure(figsize=(8,7))
# ----> 5 cond_num, cov = calculate_condition_number(X_scaled)
#       6 sb.heatmap(cov)
#       7 plt.tight_layout()
#
# Cell In[3], line 23, in calculate_condition_number(X, estimator)
#      22 def calculate_condition_number(X,estimator=covariance.MinCovDet):
# ---> 23     C = estimator().fit(X)
#      24     cov = pd.DataFrame(C.covariance_,index=X.columns,columns=X.columns)
#      25     D,L = linalg.eig(cov)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/covariance/_robust_covariance.py:744, in MinCovDet.fit(self, X, y)
#     726 @_fit_context(prefer_skip_nested_validation=True)
#     727 def fit(self, X, y=None):
#     728     """Fit a Minimum Covariance Determinant with the FastMCD algorithm.
#     729
#     730     Parameters
#    (...)    742         Returns the instance itself.
#     743     """
# --> 744     X = validate_data(self, X, ensure_min_samples=2, estimator="MinCovDet")
#     745     random_state = check_random_state(self.random_state)
#     746     n_samples, n_features = X.shape
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# MinCovDet does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # 1. Single feature selector

# %%
# Single feature Logistic

features = X_scaled.columns

results = pd.DataFrame(index=features,columns=['Coef','Pval','-LogP'])

for f in features:
    X = _df.droplevel(axis=1,level=1)[f].astype(float)
    if np.isnan(X).any():
        continue
    model = Logit(endog=y_,exog=_df.droplevel(axis=1,level=1)[f].astype(float)).fit_regularized()
    
    results.loc[f,'Coef'] = model.params.values
    results.loc[f,'Pval'] = model.pvalues.values
    results.loc[f,'-LogP'] = -np.log10(model.pvalues.values)

results['Abs coef'] = results['Coef'].abs()
results.sort_values(by='Coef')
# Out:
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5651849060785634
#             Iterations: 7
#             Function evaluations: 12
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5485705290138231
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5931150372356201
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5610246779709124
#             Iterations: 7
#             Function evaluations: 11
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5428054746762039
#             Iterations: 7
#             Function evaluations: 9
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5562981491189714
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5930494241617225
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5610377470386003
#             Iterations: 7
#             Function evaluations: 11
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5733132838967914
#             Iterations: 6
#             Function evaluations: 8
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.54357788622883
#             Iterations: 6
#             Function evaluations: 9
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5416386962666688
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5993096701161746
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5576527262664666
#             Iterations: 6
#             Function evaluations: 11
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5523814841268644
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5512925926488661
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5825734449027463
#             Iterations: 7
#             Function evaluations: 11
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5980639290191034
#             Iterations: 6
#             Function evaluations: 10
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6929894401369497
#             Iterations: 3
#             Function evaluations: 6
#             Gradient evaluations: 3
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5514909359231128
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5650011865104654
#             Iterations: 5
#             Function evaluations: 10
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5391128726231079
#             Iterations: 6
#             Function evaluations: 9
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6700578299391812
#             Iterations: 5
#             Function evaluations: 8
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5509975918395835
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5805279095357542
#             Iterations: 7
#             Function evaluations: 8
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5809390720263578
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5610246779709083
#             Iterations: 6
#             Function evaluations: 12
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5931150372355369
#             Iterations: 7
#             Function evaluations: 12
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5586700562513992
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5469440253777692
#             Iterations: 6
#             Function evaluations: 11
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5233093869085641
#             Iterations: 6
#             Function evaluations: 9
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6516663653941561
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6907904753899022
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5545435020567452
#             Iterations: 5
#             Function evaluations: 15
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5604428837978982
#             Iterations: 5
#             Function evaluations: 13
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5691778691628359
#             Iterations: 7
#             Function evaluations: 9
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6376677040068105
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6200228674226227
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6895400613027743
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6866204612265887
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6916341409484593
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5905469637347227
#             Iterations: 5
#             Function evaluations: 5
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6919812109363788
#             Iterations: 5
#             Function evaluations: 5
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6917264768550013
#             Iterations: 5
#             Function evaluations: 5
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6906741318231235
#             Iterations: 5
#             Function evaluations: 5
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6931452584165602
#             Iterations: 4
#             Function evaluations: 4
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6770467767059852
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6931118738048784
#             Iterations: 4
#             Function evaluations: 4
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.693143921636191
#             Iterations: 4
#             Function evaluations: 4
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.
# Diff from Min adjac Planar component 1 at 1 fra...                     NaN
# Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame...                     NaN
# Num neighbor division 1 frame prior                                    NaN
# Num neighbor delamination 1 frame prior                                NaN
#
#                                                                  -LogP  \
# Name
# Min adjac Gaussian curvature 5um                    11.494320346277846
# Mean adjac Mean curvature 5um                         8.71404651844046
# Median adjac Mean curvature 5um                      7.071228391965693
# Min adjac Mean curvature 5um                        14.654051129701829
# Mean curvature 5um                                   5.458857337443788
# ...                                                                ...
# Diff from Mean adjac Collagen coherence at 1 fr...                 NaN
# Diff from Min adjac Planar component 1 at 1 fra...                 NaN
# Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame...                 NaN
# Num neighbor division 1 frame prior                                NaN
# Num neighbor delamination 1 frame prior                            NaN
#
#                                                      Abs coef
# Name
# Min adjac Gaussian curvature 5um                    33.684383
# Mean adjac Mean curvature 5um                        6.134555
# Median adjac Mean curvature 5um                      4.789099
# Min adjac Mean curvature 5um                         2.781813
# Mean curvature 5um                                   2.288941
# ...                                                       ...
# Diff from Mean adjac Collagen coherence at 1 fr...        NaN
# Diff from Min adjac Planar component 1 at 1 fra...        NaN
# Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame...        NaN
# Num neighbor division 1 frame prior                       NaN
# Num neighbor delamination 1 frame prior                   NaN
#
# [839 rows x 4 columns]

# %%
results.dropna().sort_values(by='-LogP',ascending=False).head(260)
features2keep = results.dropna().sort_values(by='-LogP',ascending=False).head(260).index

# %% [markdown]
# # Condition number of remaining features

# %%
# Eliminate covarying features

# features2keep = important_features.drop(['Relative Total H2B intensity',
#                                          'Basal area',
                                         # 'Relative Nuclear volume',
                                        # ])
# features2keep = ['Relative Basal area','Mean curvature 5um','Relative Nuclear volume',
#                 'Std adjac nuc_shcoeffs_L2M0C']
features2keep = important_features
# features2keep = features

cond_num, cov_ = calculate_condition_number(X_scaled[pd.Index(features2keep)])
print(cond_num)
X_ = X_scaled[features2keep]
plt.close('all')
plt.figure()
sb.heatmap(cov_)
plt.tight_layout()

print_top_cocorrelates(cov_,num2print=20)
# cov_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 12
#       9 features2keep = important_features
#      10 # features2keep = features
# ---> 12 cond_num, cov_ = calculate_condition_number(X_scaled[pd.Index(features2keep)])
#      13 print(cond_num)
#      14 X_ = X_scaled[features2keep]
#
# Cell In[6], line 25, in calculate_condition_number(X, estimator)
#      24 def calculate_condition_number(X,estimator=covariance.MinCovDet):
# ---> 25     C = estimator().fit(X)
#      26     cov = pd.DataFrame(C.covariance_,index=X.columns,columns=X.columns)
#      27     D,L = linalg.eig(cov)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/covariance/_robust_covariance.py:744, in MinCovDet.fit(self, X, y)
#     726 @_fit_context(prefer_skip_nested_validation=True)
#     727 def fit(self, X, y=None):
#     728     """Fit a Minimum Covariance Determinant with the FastMCD algorithm.
#     729
#     730     Parameters
#    (...)    742         Returns the instance itself.
#     743     """
# --> 744     X = validate_data(self, X, ensure_min_samples=2, estimator="MinCovDet")
#     745     random_state = check_random_state(self.random_state)
#     746     n_samples, n_features = X.shape
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# MinCovDet does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# # ElastiNet

# %%
# Data prep
from statsmodels.api import Logit, GLM, families
from sklearn import model_selection, metrics
from statsmodels.tools import tools

features2keep =features2keep.drop('Relative Cell volume G1 only exponential growth rate')
X_ = X_scaled[features2keep].astype(float)
X_ = pd.DataFrame(tools.add_constant(X_))
y_ = np.asarray(y).astype(bool)

data_ = X_
data_['endog'] = y_
data_ = data_.dropna(axis=0)

# %%
# Test small set of model regularization - crossvalidation accuracy
# CV_accuracy = pd.DataFrame()
Niter = 50
alphas = 10.**np.arange(-5,-1)
L1Ws = [1,0.8,0.5,0.2,0.1,0.01,0]

index = pd.MultiIndex.from_product([range(Niter),alphas,L1Ws],names=['iter','alpha','L1'])
CV_accuracy = pd.DataFrame(index=index,columns=['Score'])
CV_AUC = pd.DataFrame(index=index,columns=['Score'])
# CV_params = pd.DataFrame(columns=list(features2keep)+['constant'],index=range(Niter))

for a in tqdm(alphas):
    for l1w in L1Ws:
        for i in range(Niter):
            X_train,X_test,y_train,y_test = model_selection.train_test_split(data_.drop(columns='endog').values,data_['endog'].values)
            model = GLM(endog = y_train,exog= X_train,
                            family=families.Binomial()).fit_regularized(alpha = 0.1,L1_wt=0.01) # L2-biased to reduce collinearity
            y_pred = model.predict(X_test) > 0.5
            CV_accuracy.loc[(i,a,l1w),'Score'] = metrics.accuracy_score(y_test,y_pred)
            CV_AUC.loc[(i,a,l1w),'Score'] = metrics.roc_auc_score(y_test,y_pred)
            # CV_params.loc[(i,a,l1w)] = model.params

CV_accuracy.reset_index()
plt.close('all')
plt.figure()
plt.subplot(1,2,1)
sb.lineplot(CV_accuracy.reset_index(),x='alpha',y='Score',hue='L1',estimator='mean',errorbar='se')
plt.subplot(1,2,2)
sb.lineplot(CV_AUC,x='alpha',y='Score',hue='L1')
# Out:
#   0%|                                                                               | 0/4 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 17
#      14 for i in range(Niter):
#      15     X_train,X_test,y_train,y_test = model_selection.train_test_split(data_.drop(columns='endog').values,data_['endog'].values)
#      16     model = GLM(endog = y_train,exog= X_train,
# ---> 17                     family=families.Binomial()).fit_regularized(alpha = 0.1,L1_wt=0.01) # L2-biased to reduce collinearity
#      18     y_pred = model.predict(X_test) > 0.5
#      19     CV_accuracy.loc[(i,a,l1w),'Score'] = metrics.accuracy_score(y_test,y_pred)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1454, in GLM.fit_regularized(self, method, alpha, start_params, refit, opt_method, **kwargs)
#    1451 defaults["score_kwds"] = sckw
#    1452 defaults["hess_kwds"] = hekw
# -> 1454 result = fit_elasticnet(self, method=method,
#    1455                         alpha=alpha,
#    1456                         start_params=start_params,
#    1457                         refit=refit,
#    1458                         **defaults)
#    1460 self.mu = self.predict(result.params)
#    1461 self.scale = self.estimate_scale(self.mu)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/base/elastic_net.py:197, in fit_elasticnet(model, method, maxiter, alpha, L1_wt, start_params, cnvrg_tol, zero_tol, refit, check_step, loglike_kwds, score_kwds, hess_kwds)
#     195 # Do the one-dimensional optimization.
#     196 func, grad, hess = fgh_list[k]
# --> 197 params[k] = _opt_1d(
#     198     func, grad, hess, model_1var, params[k], alpha[k]*L1_wt,
#     199     tol=btol, check_step=check_step)
#     201 # Update the active set
#     202 if itr > 0 and np.abs(params[k]) < zero_tol:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/base/elastic_net.py:348, in _opt_1d(func, grad, hess, model, start, L1_wt, tol, check_step)
#     346 if not check_step:
#     347     return x + h
# --> 348 f1 = func(x + h, model) + L1_wt*np.abs(x + h)
#     349 if f1 <= f + L1_wt*np.abs(x) + 1e-10:
#     350     return x + h
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/base/elastic_net.py:44, in _gen_npfuncs.<locals>.nploglike(params, model)
#      42 nobs = model.nobs
#      43 pen_llf = alpha[k] * (1 - L1_wt) * np.sum(params**2) / 2
# ---> 44 llf = model.loglike(np.r_[params], **loglike_kwds)
#      45 return - llf / nobs + pen_llf
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:449, in GLM.loglike(self, params, scale)
#     447 if scale is None:
#     448     scale = self.estimate_scale(expval)
# --> 449 llf = self.family.loglike(self.endog, expval, self.var_weights,
#     450                           self.freq_weights, scale)
#     451 return llf
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:328, in Family.loglike(self, endog, mu, var_weights, freq_weights, scale)
#     293 def loglike(self, endog, mu, var_weights=1., freq_weights=1., scale=1.):
#     294     r"""
#     295     The log-likelihood function in terms of the fitted mean response.
#     296
#    (...)    326     log-likelihood ratio.
#     327     """
# --> 328     ll_obs = self.loglike_obs(endog, mu, var_weights, scale)
#     329     return np.sum(ll_obs * freq_weights)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/families/family.py:1057, in Binomial.loglike_obs(self, endog, mu, var_weights, scale)
#    1051 y = endog * n  # Number of successes
#    1053 # note that mu is still in (0,1), i.e. not converted back
#    1054 return (
#    1055     special.gammaln(n + 1) - special.gammaln(y + 1) -
#    1056     special.gammaln(n - y + 1) + y * np.log(mu / (1 - mu + 1e-20)) +
# -> 1057     n * np.log(1 - mu + 1e-20)) * var_weights
#
# KeyboardInterrupt:

# %%
# ElastiNet GLM regularized
from statsmodels.api import Logit, GLM, families
from statsmodels.base.elastic_net import RegularizedResults
from scipy import stats

Niter = 1000

alpha = 0.01
l1w = 0.1

CV_params = pd.DataFrame(columns=list(features2keep)+['constant'],index=range(Niter))
CV_results = pd.DataFrame()
CV_confusion = np.zeros((Niter,2,2))
for i in tqdm(range(Niter)):
    
    data_balanced = get_balanced_df_by_category(data_,category='endog')
    X_train,X_test,y_train,y_test = model_selection.train_test_split(
        data_balanced.drop(columns='endog').values,data_balanced['endog'].values)
    
    model = GLM(endog = y_train, exog = X_train,
                family=families.Binomial()).fit_regularized(alpha = alpha,L1_wt=l1w)
    CV_params.loc[i] = model.params
    y_pred = model.predict(X_test) > 0.5
    CV_results.loc[i,'Accuracy'] = metrics.accuracy_score(y_test,y_pred)
    CV_results.loc[i,'AUC'] = metrics.roc_auc_score(y_test,y_pred)
    CV_confusion[i,:,:] = metrics.confusion_matrix(y_test,y_pred)


avg_results = pd.DataFrame({'mean':CV_params.mean(),
                            'std':CV_params.std(),
                            'effect_magnitude':CV_params.mean().abs(),
                           'snr':CV_params.mean().abs()/CV_params.std(),
                           'pval':(CV_params == 0).sum(axis=0)/Niter})

avg_results.sort_values(by='snr')
avg_results['-LogP'] = -np.log10(avg_results['pval'])

avg_results.sort_values(by='effect_magnitude')

{col:stats.ttest_1samp(CV_params[col].astype(float), popmean=0) for col in CV_params.columns}
# Out:
#   0%|                                                                            | 0/1000 [00:00<?, ?it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   0%|                                                                    | 1/1000 [00:00<02:33,  6.51it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   0%|▏                                                                   | 2/1000 [00:00<02:21,  7.05it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   0%|▏                                                                   | 3/1000 [00:00<02:24,  6.91it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   0%|▎                                                                   | 4/1000 [00:00<02:23,  6.93it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   0%|▎                                                                   | 5/1000 [00:00<02:21,  7.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▍                                                                   | 6/1000 [00:00<02:22,  6.98it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▍                                                                   | 7/1000 [00:01<02:20,  7.07it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▌                                                                   | 8/1000 [00:01<02:21,  7.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▌                                                                   | 9/1000 [00:01<02:20,  7.04it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▋                                                                  | 10/1000 [00:01<02:20,  7.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▋                                                                  | 11/1000 [00:01<02:20,  7.02it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▊                                                                  | 12/1000 [00:01<02:21,  6.99it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▊                                                                  | 13/1000 [00:01<02:15,  7.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   1%|▉                                                                  | 14/1000 [00:01<02:14,  7.32it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█                                                                  | 15/1000 [00:02<02:09,  7.58it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█                                                                  | 16/1000 [00:02<02:13,  7.39it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▏                                                                 | 17/1000 [00:02<02:18,  7.10it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▏                                                                 | 18/1000 [00:02<02:14,  7.28it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▎                                                                 | 19/1000 [00:02<02:16,  7.16it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▎                                                                 | 20/1000 [00:02<02:16,  7.16it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▍                                                                 | 21/1000 [00:02<02:17,  7.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▍                                                                 | 22/1000 [00:03<02:11,  7.42it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▌                                                                 | 23/1000 [00:03<02:14,  7.27it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▌                                                                 | 24/1000 [00:03<02:17,  7.12it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   2%|█▋                                                                 | 25/1000 [00:03<02:16,  7.15it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|█▋                                                                 | 26/1000 [00:03<02:16,  7.13it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|█▊                                                                 | 27/1000 [00:03<02:19,  6.97it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|█▉                                                                 | 28/1000 [00:03<02:21,  6.87it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|█▉                                                                 | 29/1000 [00:04<02:17,  7.06it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|██                                                                 | 30/1000 [00:04<02:12,  7.33it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|██                                                                 | 31/1000 [00:04<02:11,  7.34it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|██▏                                                                | 32/1000 [00:04<02:14,  7.17it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|██▏                                                                | 33/1000 [00:04<02:13,  7.25it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   3%|██▎                                                                | 34/1000 [00:04<02:12,  7.30it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██▎                                                                | 35/1000 [00:04<02:13,  7.25it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██▍                                                                | 36/1000 [00:05<02:13,  7.20it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██▍                                                                | 37/1000 [00:05<02:17,  7.03it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██▌                                                                | 38/1000 [00:05<02:18,  6.95it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██▌                                                                | 39/1000 [00:05<02:16,  7.03it/s]/opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")
#   4%|██
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# {'Axial component': TtestResult(statistic=np.float64(-86.65554260655513), pvalue=np.float64(0.0), df=np.int64(999)),
#  'Relative Distance to closest macrophage': TtestResult(statistic=np.float64(-10.943344752827795), pvalue=np.float64(2.104775417179147e-26), df=np.int64(999)),
#  'Relative Nuclear volume': TtestResult(statistic=np.float64(-5.987182758121753), pvalue=np.float64(2.9742501713682236e-09), df=np.int64(999)),
#  'Relative nuc_shcoeffs_surface_area': TtestResult(statistic=np.float64(76.57446685210563), pvalue=np.float64(0.0), df=np.int64(999)),
#  'Nuclear volume G1 only exponential growth rate': TtestResult(statistic=np.float64(45.48278338302934), pvalue=np.float64(1.2837577827137972e-245), df=np.int64(999)),
#  'Nuclear volume smoothed growth rate': TtestResult(statistic=np.float64(158.7613332425024), pvalue=np.float64(0.0), df=np.int64(999)),
#  'Cell volume G1 only exponential growth rate': TtestResult(statistic=np.float64(81.31765106591436), pvalue=np.float64(0.0), df=np.int64(999)),
#  'Height to BM': TtestResult(statistic=np.float64(148.03509960783362), pvalue=np.float64(0.0), df=np.int64(999)),
#  'Subbasal collagen intensity smoothed growth rate': TtestResult(statistic=np.float64(30.67210645413842), pvalue=np.float64(4.069409771267031e-146), df=np.int64(999)),
#  'Basal area smoothed growth rate': TtestResult(statistic=np.float64(-25.055596656566), pvalue=np.float64(6.791170948602188e-108), df=np.int64(999)),
#  'Apical area smoothed growth rate': TtestResult(statistic=np.float64(9.81065810817001), pvalue=np.float64(9.375562450026707e-22), df=np.int64(999)),
#  'Basal alignment to basal footprint smoothed growth rate': TtestResult(statistic=np.float64(16.536039184052438), pvalue=np.float64(1.78191758615239e-54), df=np.int64(999)),
#  'Diff from Height to BM at 1 frame prior': TtestResult(statistic=np.float64(19.50948379765909), pvalue=np.float64(4.504619487128458e-72), df=np.int64(999)),
#  'nuc_shcoeff_PC5': TtestResult(statistic=np.float64(-52.27622274759048), pvalue=np.float64(3.793886382701658e-288), df=np.int64(999)),
#  'Cell volume smoothed growth rate': TtestResult(statistic=np.float64(5.09778648803234), pvalue=np.float64(4.1091999885878433e-07), df=np.int64(999)),
#  'Diff from Relative Height to BM at 1 frame prior': TtestResult(statistic=np.float64(-6.408551648338089), pvalue=np.float64(2.260193022237967e-10), df=np.int64(999)),
#  'Relative Height to BM': TtestResult(statistic=np.float64(3.5209949694646285), pvalue=np.float64(0.0004493441383897105), df=np.int64(999)),
#  'Basal area': TtestResult(statistic=np.float64(-18.182526577490044), pvalue=np.float64(4.859323976786849e-64), df=np.int64(999)),
#  'Relative Basal area': TtestResult(statistic=np.float64(32.64999068375927), pvalue=np.float64(1.0551542208946113e-159), df=np.int64(999)),
#  'constant': TtestResult(statistic=np.float64(49.36524246042442), pvalue=np.float64(3.2024369604995607e-270), df=np.int64(999))}

# %%
print(CV_results['Accuracy'].mean())
plt.close('all')
fig = plt.figure()
plt.subplot(1,2,1)
sb.histplot(CV_results['Accuracy'],bins=50,stat='proportion')
plt.vlines(x=CV_results['Accuracy'].mean(),ymin=0,ymax=0.1,color='red')
plt.subplot(1,2,2)
sb.histplot(CV_results['AUC'],bins=50,stat='proportion')
plt.vlines(x=CV_results['AUC'].mean(),ymin=0,ymax=0.1,color='red')
fig.savefig(path.join(model_dir,'Linear_model_birth/GLM_CV_accuracy.svg'))
# Out:
# 0.7801855670103094
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

fig = plt.figure()
sb.heatmap(CV_confusion.mean(axis=0)/len(y_test)*100,annot=True,vmin=0,vmax=50)
plt.tight_layout()
fig.savefig(path.join(model_dir,'Linear_model_birth/GLM_CV_confusion.svg'))

fig = plt.figure(figsize=(5,10))
sb.barplot(CV_params[CV_params.columns[avg_results['effect_magnitude'].argsort()]])
plt.ylabel('Effect magnitude')
plt.xticks(rotation=90)
plt.tight_layout()

fig.savefig(path.join(model_dir,'Linear_model_birth/GLM_CV_coefficients.svg'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
features2plot = CV_params.columns[avg_results['effect_magnitude'].argsort()][-5:]
plt.close('all')
for i,f in enumerate(features2plot):
    fig = sb.catplot(births.droplevel(axis=1,level=1),x='Region',y=f, kind='violin',hue=feature2predict)
    fig.savefig(path.join(model_dir,f'Differentiation visualizations/catplot_{f}.svg'))

plt.ylim([-10,20])
fig = sb.catplot(births.droplevel(axis=1,level=1),x=feature2predict,y='NC ratio',hue='Region',kind='box')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # PCA

# %%
model_dir
# Out:
# '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/'

# %%
pca

# %%
from sklearn import cross_decomposition
from ppca import PPCA
pca = PPCA()
pca.fit(X_scaled.values)

# X_transformed = pd.DataFrame(pca.x_scores_,columns=[f't{i+1}' for i in range(2)],
#                             index=X.index)
# X_transformed
# plt.figure()
# ax = sb.scatterplot(x=X_transformed['t1'],y=X_transformed['t2'],hue=y_)

# pd.Series(pls.coef_[0,:],index=X_scaled.columns)
# accuracy = metrics.accuracy_score(y_,pls.predict(X_scaled.values) > 0.5)
# print(f'Accuracy: {accuracy * 100:.0f}%')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[133], line 4
#       2 from ppca import PPCA
#       3 pca = PPCA()
# ----> 4 pca.fit(X_scaled.values)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/ppca/_ppca.py:75, in PPCA.fit(self, data, d, tol, min_obs, verbose)
#      73 # m-step
#      74 XX = np.dot(X.T, X)
# ---> 75 C = np.dot(np.dot(data.T, X), np.linalg.pinv(XX + N*Sx))
#      76 CC = np.dot(C.T, C)
#      77 recon = np.dot(X, C.T)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2212, in pinv(a, rcond, hermitian, rtol)
#    2210     return wrap(res)
#    2211 a = a.conjugate()
# -> 2212 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2214 # discard small singular values
#    2215 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/numpy/linalg/_linalg.py:1796, in svd(a, full_matrices, compute_uv, hermitian)
#    1792 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1793 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1794               invalid='call', over='ignore', divide='ignore',
#    1795               under='ignore'):
# -> 1796     u, s, vh = gufunc(a, signature=signature)
#    1797 u = u.astype(result_t, copy=False)
#    1798 s = s.astype(_realType(result_t), copy=False)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/numpy/linalg/_linalg.py:113, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     112 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 113     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
X_loadings = pd.Series(pls.coef_[0,:],index=X_scaled.columns)
X_loadings.abs().sort_values().tail(10)
# Out:
# Name
# nuc_shcoeff_PC0                       0.010056
# Median adjac Mean curvature 15um      0.010162
# Relative nuc_shcoeffs_surface_area    0.010520
# Max adjac Mean curvature 15um         0.010526
# cyto_shcoeff_PC5                      0.010630
# Median adjac Mean curvature 10um      0.010684
# Relative Mean H2B intensity           0.011507
# Relative Total H2B intensity          0.012306
# Basal area                            0.013635
# Relative Basal area                   0.014293
# dtype: float64

# %%
_df.droplevel(axis=1,level=1).sort_values(by='cyto_shcoeff_PC5').tail(10)
# Out:
# Name           Nuclear volume  Nuclear solidity          Y          X  \
# Frame TrackID
# 1     R2_614         183.4375          0.816639  53.110221  15.699148
# 0     R2_467         236.9375          0.814918  87.626550  19.929306
# 7     R1_977         308.3125          0.906801  98.889520  57.276353
# 0     R2_417         255.6875          0.842984  53.702762  22.986311
# 4     R2_928         198.7500          0.889510  83.901336  83.853302
# 2     R2_493         316.8750          0.869938  97.586686  57.485454
# 0     R2_754         244.5000          0.869720  44.744312  62.720412
# 4     R1_1036        271.6875          0.935845  53.986772  76.344548
#       R2_577         232.2500          0.863383  46.105826  25.960441
# 6     R2_891         207.1875          0.899349  89.143363  98.394721
#
# Name           Nuclear height  Cell volume     Y-cyto     X-cyto  \
# Frame TrackID
# 1     R2_614             -9.0     584.4375  53.161560  15.964629
# 0     R2_467            -11.0     615.1250  87.509805  19.638641
# 7     R1_977            -15.0     685.5625  98.592989  57.201431
# 0     R2_417            -12.0     717.4375  53.778683  23.107566
# 4     R2_928            -10.0     539.0000  83.803137  83.934949
# 2     R2_493            -12.0     634.1875  97.263674  57.448458
# 0     R2_754            -10.0     625.6250  44.974750  62.583017
# 4     R1_1036           -11.0     681.0625  54.327636  76.456731
#       R2_577            -11.0     660.4375  46.074075  25.748841
# 6     R2_891             -9.0     628.9375  89.205654  98.740535
#
# Name           Axial component  Planar component 1  ...  \
# Frame TrackID                                       ...
# 1     R2_614         17.113087            8.219607  ...
# 0     R2_467          8.551352           22.691235  ...
# 7     R1_977          6.893717           26.637240  ...
# 0     R2_417          8.796992           21.077037  ...
# 4     R2_928          8.680936           17.537834  ...
# 2     R2_493          9.486334           17.002592  ...
# 0     R2_754          9.531980           15.675935  ...
# 4     R1_1036         9.346459           17.316046  ...
#       R2_577          8.319667           20.321350  ...
# 6     R2_891          9.355092           17.731490  ...
#
# Name           Diff from Min adjac cyto_shcoeff_PC7 at 1 frame prior  \
# Frame TrackID
# 1     R2_614                                           -0.711779
# 0     R2_467                                                 NaN
# 7     R1_977                                            0.961209
# 0     R2_417                                                 NaN
# 4     R2_928                                            0.147186
# 2     R2_493                                           -0.471597
# 0     R2_754                                                 NaN
# 4     R1_1036                                          -1.100429
#       R2_577                                            0.025920
# 6     R2_891                                            0.170110
#
# Name           Diff from Mean adjac Collagen coherence at 1 frame prior  \
# Frame TrackID
# 1     R2_614                                           -0.092867
# 0     R2_467                                                 NaN
# 7     R1_977                                           -0.187392
# 0     R2_417                                                 NaN
# 4     R2_928                                           -0.057477
# 2     R2_493                                            0.008630
# 0     R2_754                                                 NaN
# 4     R1_1036                                          -0.158346
#       R2_577                                           -0.001494
# 6     R2_891                                            0.055437
#
# Name           Diff from Min adjac Planar component 1 at 1 frame prior  \
# Frame TrackID
# 1     R2_614                                           -2.174275
# 0     R2_467                                                 NaN
# 7     R1_977                                            2.261676
# 0     R2_417                                                 NaN
# 4     R2_928                                            2.342234
# 2     R2_493                                            3.063683
# 0     R2_754                                                 NaN
# 4     R1_1036                                           3.678700
#       R2_577                                            5.766337
# 6     R2_891                                            9.199043
#
# Name           Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame prior  \
# Frame TrackID
# 1     R2_614                                           -0.859874
# 0     R2_467                                                 NaN
# 7     R1_977                                            0.187532
# 0     R2_417                                                 NaN
# 4     R2_928                                            0.397828
# 2     R2_493                                           -0.352577
# 0     R2_754                                                 NaN
# 4     R1_1036                                           0.703683
#       R2_577                                           -0.824165
# 6     R2_891                                            0.032137
#
# Name           Num neighbor division 1 frame prior  \
# Frame TrackID
# 1     R2_614                                   1.0
# 0     R2_467                                   NaN
# 7     R1_977                                   1.0
# 0     R2_417                                   NaN
# 4     R2_928                                   0.0
# 2     R2_493                                   1.0
# 0     R2_754                                   NaN
# 4     R1_1036                                  1.0
#       R2_577                                   1.0
# 6     R2_891                                   0.0
#
# Name           Num neighbor delamination 1 frame prior  \
# Frame TrackID
# 1     R2_614                                       0.0
# 0     R2_467                                       NaN
# 7     R1_977                                       2.0
# 0     R2_417                                       NaN
# 4     R2_928                                       1.0
# 2     R2_493                                       1.0
# 0     R2_754                                       NaN
# 4     R1_1036                                      1.0
#       R2_577                                       1.0
# 6     R2_891                                       1.0
#
# Name           Num daughter differentiated  \
# Frame TrackID
# 1     R2_614                           0.0
# 0     R2_467                           1.0
# 7     R1_977                           2.0
# 0     R2_417                           0.0
# 4     R2_928                           1.0
# 2     R2_493                           0.0
# 0     R2_754                           0.0
# 4     R1_1036                          0.0
#       R2_577                           1.0
# 6     R2_891                           0.0
#
# Name           At least one daughter differentiated  \
# Frame TrackID
# 1     R2_614                                  False
# 0     R2_467                                   True
# 7     R1_977                                   True
# 0     R2_417                                  False
# 4     R2_928                                   True
# 2     R2_493                                  False
# 0     R2_754                                  False
# 4     R1_1036                                 False
#       R2_577                                   True
# 6     R2_891                                  False
#
# Name           Both daughters differentiated  Region
# Frame TrackID
# 1     R2_614                           False      R2
# 0     R2_467                           False      R2
# 7     R1_977                            True      R1
# 0     R2_417                           False      R2
# 4     R2_928                           False      R2
# 2     R2_493                           False      R2
# 0     R2_754                           False      R2
# 4     R1_1036                          False      R1
#       R2_577                           False      R2
# 6     R2_891                           False      R2
#
# [10 rows x 1006 columns]

# %%
_df.droplevel(axis=1,level=1).sort_values(by='cyto_shcoeff_PC5').head(10)
# Out:
# Name           Nuclear volume  Nuclear solidity          Y          X  \
# Frame TrackID
# 3     R2_208         159.8750          0.533139  24.030102  28.324081
#       R1_1083        210.9375          0.855730  70.511704  98.287704
# 7     R2_6           254.3750          0.702693  20.955098  95.258477
# 3     R2_85          250.9375          0.858273  57.962204  79.332379
# 0     R1_1074        203.5000          0.826396  97.397343  69.768811
# 6     R2_21          273.5625          0.917610  67.728239  59.270619
# 8     R1_686         292.7500          0.922774  23.320880  68.941877
# 1     R1_24          249.5000          0.890674   7.703219  79.354897
# 2     R2_12          199.7500          0.851359  15.048576  10.479662
# 6     R1_989         331.3125          0.715385  46.132664  12.816261
#
# Name           Nuclear height  Cell volume     Y-cyto     X-cyto  \
# Frame TrackID
# 3     R2_208            -10.0     749.8125  23.946007  28.399183
#       R1_1083           -13.0     546.8125  70.784547  98.579552
# 7     R2_6              -11.0     853.0000  21.242032  95.518538
# 3     R2_85             -10.0     608.5625  57.674309  79.188123
# 0     R1_1074           -12.0     716.7500  97.991215  69.883328
# 6     R2_21             -10.0     721.5000  68.030665  59.878097
# 8     R1_686            -11.0     590.1250  23.441511  69.047130
# 1     R1_24             -11.0     740.3750   7.283999  79.093935
# 2     R2_12             -10.0     647.7500  15.193000  10.236926
# 6     R1_989            -11.0     710.5000  45.987883  13.101535
#
# Name           Axial component  Planar component 1  ...  \
# Frame TrackID                                       ...
# 3     R2_208         10.486834           17.262470  ...
#       R1_1083         7.352584           17.548808  ...
# 7     R2_6           12.350902           16.249520  ...
# 3     R2_85           8.003747           16.253811  ...
# 0     R1_1074         8.173750           22.066080  ...
# 6     R2_21           9.631969           16.978085  ...
# 8     R1_686          9.846128           15.450702  ...
# 1     R1_24          11.811411           20.800684  ...
# 2     R2_12           8.654770           20.753989  ...
# 6     R1_989         12.477260           12.038947  ...
#
# Name           Diff from Min adjac cyto_shcoeff_PC7 at 1 frame prior  \
# Frame TrackID
# 3     R2_208                                           -0.234667
#       R1_1083                                           0.000325
# 7     R2_6                                             -0.526080
# 3     R2_85                                            -0.437424
# 0     R1_1074                                                NaN
# 6     R2_21                                            -0.139574
# 8     R1_686                                           -1.014982
# 1     R1_24                                             0.514406
# 2     R2_12                                            -0.449455
# 6     R1_989                                           -0.201387
#
# Name           Diff from Mean adjac Collagen coherence at 1 frame prior  \
# Frame TrackID
# 3     R2_208                                            0.206083
#       R1_1083                                           0.095967
# 7     R2_6                                             -0.129869
# 3     R2_85                                            -0.171868
# 0     R1_1074                                                NaN
# 6     R2_21                                            -0.177656
# 8     R1_686                                            0.004094
# 1     R1_24                                            -0.053487
# 2     R2_12                                            -0.061927
# 6     R1_989                                           -0.085267
#
# Name           Diff from Min adjac Planar component 1 at 1 frame prior  \
# Frame TrackID
# 3     R2_208                                            0.151109
#       R1_1083                                           0.147781
# 7     R2_6                                             -4.128248
# 3     R2_85                                             0.151993
# 0     R1_1074                                                NaN
# 6     R2_21                                             1.740610
# 8     R1_686                                           -0.711649
# 1     R1_24                                             0.263467
# 2     R2_12                                             7.590622
# 6     R1_989                                           -4.126283
#
# Name           Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame prior  \
# Frame TrackID
# 3     R2_208                                            0.313417
#       R1_1083                                          -0.498147
# 7     R2_6                                              0.806576
# 3     R2_85                                             1.030777
# 0     R1_1074                                                NaN
# 6     R2_21                                             0.195031
# 8     R1_686                                           -0.328227
# 1     R1_24                                             0.084700
# 2     R2_12                                            -0.636983
# 6     R1_989                                            0.181034
#
# Name           Num neighbor division 1 frame prior  \
# Frame TrackID
# 3     R2_208                                   1.0
#       R1_1083                                  3.0
# 7     R2_6                                     1.0
# 3     R2_85                                    0.0
# 0     R1_1074                                  NaN
# 6     R2_21                                    0.0
# 8     R1_686                                   0.0
# 1     R1_24                                    0.0
# 2     R2_12                                    0.0
# 6     R1_989                                   0.0
#
# Name           Num neighbor delamination 1 frame prior  \
# Frame TrackID
# 3     R2_208                                       1.0
#       R1_1083                                      0.0
# 7     R2_6                                         1.0
# 3     R2_85                                        1.0
# 0     R1_1074                                      NaN
# 6     R2_21                                        2.0
# 8     R1_686                                       1.0
# 1     R1_24                                        1.0
# 2     R2_12                                        0.0
# 6     R1_989                                       1.0
#
# Name           Num daughter differentiated  \
# Frame TrackID
# 3     R2_208                           2.0
#       R1_1083                          1.0
# 7     R2_6                             2.0
# 3     R2_85                            1.0
# 0     R1_1074                          1.0
# 6     R2_21                            0.0
# 8     R1_686                           2.0
# 1     R1_24                            2.0
# 2     R2_12                            1.0
# 6     R1_989                           0.0
#
# Name           At least one daughter differentiated  \
# Frame TrackID
# 3     R2_208                                   True
#       R1_1083                                  True
# 7     R2_6                                     True
# 3     R2_85                                    True
# 0     R1_1074                                  True
# 6     R2_21                                   False
# 8     R1_686                                   True
# 1     R1_24                                    True
# 2     R2_12                                    True
# 6     R1_989                                  False
#
# Name           Both daughters differentiated  Region
# Frame TrackID
# 3     R2_208                            True      R2
#       R1_1083                          False      R1
# 7     R2_6                              True      R2
# 3     R2_85                            False      R2
# 0     R1_1074                          False      R1
# 6     R2_21                            False      R2
# 8     R1_686                            True      R1
# 1     R1_24                             True      R1
# 2     R2_12                            False      R2
# 6     R1_989                           False      R1
#
# [10 rows x 1006 columns]

# %%
plt.figure()
sb.scatterplot(divisions.droplevel(axis=1,level=1),x='Relative Basal area',y='cyto_shcoeff_PC5',hue=feature2predict)
# Out:
# <Axes: xlabel='Relative Basal area', ylabel='cyto_shcoeff_PC5'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Reconstruct 'average' cell shape?

# %%
_df.droplevel(axis=1,level=1).sort_values(by='Basal area',ascending=False)
# Out:
# Name           Nuclear volume  Nuclear solidity          Y          X  \
# Frame TrackID
# 7     R2_490         112.7500          0.770611  99.791159  13.083010
# 2     R2_615         103.3125          0.793948  52.724743  12.575166
# 1     R1_267          99.1250          0.793794  26.574874  81.109710
# 8     R2_507         141.1875          0.810258  95.456397  24.269256
# 9     R1_723         173.8125          0.871514  62.208109  99.368123
#
# Name           Nuclear height  Cell volume     Y-cyto     X-cyto  \
# Frame TrackID
# 7     R2_490             -8.0     537.2500  99.312704  13.515356
# 2     R2_615             -8.0     457.1875  53.119139  12.617943
# 1     R1_267             -6.0     310.8125  26.551076  81.302886
# 8     R2_507             -8.0     400.3125  94.901366  24.124200
# 9     R1_723             -9.0     451.6875  62.486820  99.756538
#
# Name           Axial component  Planar component 1  ...  \
# Frame TrackID                                       ...
# 7     R2_490          8.781168           14.739592  ...
# 2     R2_615         10.456585           20.012671  ...
# 1     R1_267          9.931091            6.311298  ...
# 8     R2_507         11.487718           16.920295  ...
# 9     R1_723          8.965966            9.640949  ...
#
# Name           Diff from Min adjac cyto_shcoeff_PC7 at 1 frame prior  \
# Frame TrackID
# 7     R2_490                                           -1.088939
# 2     R2_615                                           -0.124268
# 1     R1_267                                           -0.362993
# 8     R2_507                                           -0.494375
# 9     R1_723                                           -0.279248
#
# Name           Diff from Mean adjac Collagen coherence at 1 frame prior  \
# Frame TrackID
# 7     R2_490                                            0.299328
# 2     R2_615                                            0.372945
# 1     R1_267                                            0.271423
# 8     R2_507                                            0.447847
# 9     R1_723                                            0.216071
#
# Name           Diff from Min adjac Planar component 1 at 1 frame prior  \
# Frame TrackID
# 7     R2_490                                            5.479608
# 2     R2_615                                            4.203276
# 1     R1_267                                            2.513568
# 8     R2_507                                            8.136146
# 9     R1_723                                            5.539937
#
# Name           Diff from Mean adjac nuc_shcoeff_PC3 at 1 frame prior  \
# Frame TrackID
# 7     R2_490                                            0.421466
# 2     R2_615                                           -0.616887
# 1     R1_267                                            0.300673
# 8     R2_507                                           -0.945651
# 9     R1_723                                            0.009197
#
# Name           Num neighbor division 1 frame prior  \
# Frame TrackID
# 7     R2_490                                   0.0
# 2     R2_615                                   1.0
# 1     R1_267                                   1.0
# 8     R2_507                                   0.0
# 9     R1_723                                   2.0
#
# Name           Num neighbor delamination 1 frame prior  \
# Frame TrackID
# 7     R2_490                                       0.0
# 2     R2_615                                       0.0
# 1     R1_267                                       2.0
# 8     R2_507                                       0.0
# 9     R1_723                                       2.0
#
# Name           Num daughter differentiated  \
# Frame TrackID
# 7     R2_490                           NaN
# 2     R2_615                           0.0
# 1     R1_267                           0.0
# 8     R2_507                           NaN
# 9     R1_723                           NaN
#
# Name           At least one daughter differentiated  \
# Frame TrackID
# 7     R2_490                                    NaN
# 2     R2_615                                  False
# 1     R1_267                                  False
# 8     R2_507                                    NaN
# 9     R1_723                                    NaN
#
# Name           Both daughters differentiated  Region
# Frame TrackID
# 7     R2_490                             NaN      R2
# 2     R2_615                           False      R2
# 1     R1_267                           False      R1
# 8     R2_507                             NaN      R2
# 9     R1_723                             NaN      R1
#
# [5 rows x 869 columns]

# %%
from aicsshparam import shtools

cells2avg = _df.droplevel(axis=1,level=1).sort_values(by='Basal area',ascending=False).head(10)
nuc_coeffs = [f for f in cells2avg.columns if 'nuc_shcoeff' in f and not 'adjac' in f and not 'Relative' in f and not 'surface' in f]
cyto_coeffs = [f for f in cells2avg.columns if 'cyto_shcoeff' in f and not 'adjac' in f and not 'Relative' in f and not 'surface' in f]
mean_nuc = cells2avg[nuc_coeffs].mean()

shtools.get_even_reconstruction_from_coeffs(
# Out:
# Name
# nuc_shcoeff_PC0   -0.309231
# nuc_shcoeff_PC1   -0.987443
# nuc_shcoeff_PC2    0.257013
# nuc_shcoeff_PC3   -0.218399
# nuc_shcoeff_PC4    0.366756
# dtype: float64
