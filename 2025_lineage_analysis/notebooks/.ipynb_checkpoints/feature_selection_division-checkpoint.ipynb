# %% [markdown]
# ## 0. Load datasets

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection, feature_selection, metrics, inspection, pipeline
from sklearn import ensemble, linear_model

def get_balanced_df_by_category(df,category):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member)
        else:
            output.append(member.sample(num_per_category.min()))
    output = pd.concat(output,ignore_index=True)

    return output
    
def predict_feature(df:pd.DataFrame,
                    classifier,
                    feature2predict,
                    Niter:int=100,
                    rebalance:bool=True,
                    subsample=None,
                    measurement_level_name:str='Measurement'):
    if subsample == None:
        subsample = len(df)
    Y_test = []
    Y_pred = []
    models = []
    for i in tqdm(range(Niter)):

        # rng = np.random.RandomState(0)
        df_ = get_balanced_df_by_category(df, df[feature2predict,'Meta'].values)
        
        pipe = pipeline.make_pipeline(preprocessing.StandardScaler(),
                                      classifier() )
        
        y = df_[feature2predict,'Meta'].astype(float)
        X = df_.xs(measurement_level_name,level=1,axis=1).astype(float)
        X[np.isinf(X)] = np.nan
        X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y)
        
        model = pipe.fit(X_train,y_train)
        models.append(model)
        
        Y_test.append(y_test)
        Y_pred.append(model.predict(X_test))
        
    return [np.stack((np.array(Y_test),np.array(Y_pred))),models]

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
divisions = pd.read_pickle(path.join(dataset_dir,f'divisions.pkl'))

# censor the 'answers'
features2drop = [(f,a) for f,a in divisions.columns if 'Time' in f]
features2drop += [(f,a) for f,a in divisions.columns if 'smoothed' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in divisions.columns if 'standard' in f and not 'rate' in f]
features2drop += [(f,a) for f,a in divisions.columns if 'cell coords' in f and not 'rate' in f]
features2drop += ['Z','Z-cyto']
divisions = divisions.drop(columns=features2drop)
print(len(divisions))
# Out:
# 668
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_97283/312790672.py:11: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   divisions = divisions.drop(columns=features2drop)

# %%
feature2predict = 'At least one daughter differentiated'

X = divisions.xs('Measurement',axis=1,level=1).dropna(axis=1)
y = divisions[feature2predict,'Meta']

I = ~y.isnull()
X = X[I]
y = y[I].astype(bool)

estimator = ensemble.RandomForestClassifier()

selector = feature_selection.RFECV(estimator,step=1).fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 12
#       8 y = y[I].astype(bool)
#      10 estimator = ensemble.RandomForestClassifier()
# ---> 12 selector = feature_selection.RFECV(estimator,step=1).fit(X,y)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = [
#      67     "{}={}".format(name, arg)
#      68     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      69 ]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:897, in RFECV.fit(self, X, y, groups, **params)
#     894     parallel = Parallel(n_jobs=self.n_jobs)
#     895     func = delayed(_rfe_single_fit)
# --> 897 step_results = parallel(
#     898     func(clone(rfe), self.estimator, X, y, train, test, scorer, routed_params)
#     899     for train, test in cv.split(X, y, **routed_params.splitter.split)
#     900 )
#     901 scores, supports, rankings, step_n_features = zip(*step_results)
#     903 step_n_features_rev = np.array(step_n_features[0])[::-1]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:898, in <genexpr>(.0)
#     894     parallel = Parallel(n_jobs=self.n_jobs)
#     895     func = delayed(_rfe_single_fit)
#     897 step_results = parallel(
# --> 898     func(clone(rfe), self.estimator, X, y, train, test, scorer, routed_params)
#     899     for train, test in cv.split(X, y, **routed_params.splitter.split)
#     900 )
#     901 scores, supports, rankings, step_n_features = zip(*step_results)
#     903 step_n_features_rev = np.array(step_n_features[0])[::-1]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:52, in _rfe_single_fit(rfe, estimator, X, y, train, test, scorer, routed_params)
#      45 fit_params = _check_method_params(
#      46     X, params=routed_params.estimator.fit, indices=train
#      47 )
#      48 score_params = _check_method_params(
#      49     X=X, params=routed_params.scorer.score, indices=test
#      50 )
# ---> 52 rfe._fit(
#      53     X_train,
#      54     y_train,
#      55     lambda estimator, features: _score(
#      56         estimator,
#      57         X_test[:, features],
#      58         y_test,
#      59         scorer,
#      60         score_params=score_params,
#      61     ),
#      62     **fit_params,
#      63 )
#      65 return rfe.step_scores_, rfe.step_support_, rfe.step_ranking_, rfe.step_n_features_
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:334, in RFE._fit(self, X, y, step_score, **fit_params)
#     331 if self.verbose > 0:
#     332     print("Fitting estimator with %d features." % np.sum(support_))
# --> 334 estimator.fit(X[:, features], y, **fit_params)
#     336 # Compute step values on the previous selection iteration because
#     337 # 'estimator' must use features that have not been eliminated yet
#     338 if step_score:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree._fit(
#     189         X,
#     190         y,
#     191         sample_weight=curr_sample_weight,
#     192         check_input=False,
#     193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
#     196     tree._fit(
#     197         X,
#     198         y,
#    (...)    201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/tree/_classes.py:239, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     231 def _fit(
#     232     self,
#     233     X,
#    (...)    237     missing_values_in_feature_mask=None,
#     238 ):
# --> 239     random_state = check_random_state(self.random_state)
#     241     if check_input:
#     242         # Need to validate separately here.
#     243         # We can't pass multi_output=True because that would allow y to be
#    (...)    246         # _compute_missing_values_in_feature_mask will check for finite values and
#     247         # compute the missing mask if the tree supports missing values
#     248         check_X_params = dict(
#     249             dtype=DTYPE, accept_sparse="csc", ensure_all_finite=False
#     250         )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/sklearn/utils/validation.py:1513, in check_random_state(seed)
#    1511     return np.random.mtrand._rand
#    1512 if isinstance(seed, numbers.Integral):
# -> 1513     return np.random.RandomState(seed)
#    1514 if isinstance(seed, np.random.RandomState):
#    1515     return seed
#
# File numpy/random/mtrand.pyx:185, in numpy.random.mtrand.RandomState.__init__()
#
# File _mt19937.pyx:132, in numpy.random._mt19937.MT19937.__init__()
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/numpy/_core/_ufunc_config.py:449, in errstate.__call__.<locals>.inner(*args, **kwargs)
#     446 _token = _extobj_contextvar.set(extobj)
#     447 try:
#     448     # Call the original, decorated, function:
# --> 449     return func(*args, **kwargs)
#     450 finally:
#     451     _extobj_contextvar.reset(_token)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3381, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3377 exec_count = self.execution_count
#    3378 if result.error_in_exec:
#    3379     # Store formatted traceback and error details
#    3380     self.history_manager.exceptions[exec_count] = (
# -> 3381         self._format_exception_for_storage(result.error_in_exec)
#    3382     )
#    3384 # Each cell is a *single* input, regardless of how many lines it has
#    3385 self.execution_count += 1
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3435, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3432         stb = evalue._render_traceback_()
#    3433     else:
#    3434         # Otherwise, use InteractiveTB to format the traceback.
# -> 3435         stb = self.InteractiveTB.structured_traceback(
#    3436             etype, evalue, tb, tb_offset=1
#    3437         )
#    3438 except Exception:
#    3439     # In case formatting fails, fallback to Python's built-in formatting.
#    3440     stb = traceback.format_exception(etype, evalue, tb)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/stack_data/core.py:360, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     358 if pygmented and self.frame_info.scope:
#     359     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 360     start_line, lines = self.frame_info._pygmented_scope_lines
#     361     result = lines[self.lineno - start_line]
#     362     if strip_leading_indent:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/stack_data/core.py:780, in FrameInfo._pygmented_scope_lines(self)
#     777     ranges = []
#     779 code = atok.get_text(scope)
# --> 780 lines = _pygmented_with_ranges(formatter, code, ranges)
#     782 start_line = line_range(scope)[0]
#     784 return start_line, lines
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/stack_data/utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     161             length += len(value)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 return pygments.highlight(code, lexer, formatter).splitlines()
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:660, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     658         pass
#     659     else:
# --> 660         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     662 return type.__call__(cls, *args, **kwds)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:599, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     597 tokendefs = tokendefs or cls.tokens[name]
#     598 for state in list(tokendefs):
# --> 599     cls._process_state(tokendefs, processed, state)
#     600 return processed
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:563, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     560 if isinstance(tdef, include):
#     561     # it's a state reference
#     562     assert tdef != state, f"circular state reference {state!r}"
# --> 563     tokens.extend(cls._process_state(unprocessed, processed,
#     564                                      str(tdef)))
#     565     continue
#     566 if isinstance(tdef, _inherit):
#     567     # should be processed already, but may not in the case of:
#     568     # 1. the state has no counterpart in any parent
#     569     # 2. the state includes more than one 'inherit'
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:579, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     576 assert type(tdef) is tuple, f"wrong rule def {tdef!r}"
#     578 try:
# --> 579     rex = cls._process_regex(tdef[0], rflags, state)
#     580 except Exception as err:
#     581     raise ValueError(f"uncompilable regex {tdef[0]!r} in state {state!r} of {cls!r}: {err}") from err
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:507, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     505 """Preprocess the regular expression component of a token definition."""
#     506 if isinstance(regex, Future):
# --> 507     regex = regex.get()
#     508 return re.compile(regex, rflags).match
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/lexer.py:495, in words.get(self)
#     494 def get(self):
# --> 495     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      83 """Return a compiled regex that matches any string in the given list.
#      84
#      85 The strings to match must be literal strings, not regexes.  They will be
#    (...)     88 *prefix* and *suffix* are pre- and appended to the final regex.
#      89 """
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
#     [... skipping similar frames: <genexpr> at line 77 (2 times), regex_opt_inner at line 77 (2 times)]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:63, in regex_opt_inner(strings, open_paren)
#      59     plen = len(prefix)
#      60     # we have a prefix for all strings
#      61     # print '-> prefix:', prefix
#      62     return open_paren + escape(prefix) \
# ---> 63         + regex_opt_inner([s[plen:] for s in strings], '(?:') \
#      64         + close_paren
#      65 # is there a suffix?
#      66 strings_rev = [s[::-1] for s in strings]
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      71     return open_paren \
#      72         + regex_opt_inner(sorted(s[:-slen] for s in strings), '(?:') \
#      73         + escape(suffix[::-1]) + close_paren
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recursive feature elimination CV: division

# %%
selector.get_feature_names_out()

# %% [markdown]
# ## RFECV: Frame prev to division
