# %% [markdown]
# ## 0. Load datasets

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from measurements import get_prev_or_next_frame
from sklearn import preprocessing, model_selection
from sklearn import ensemble, metrics, inspection, linear_model

def get_balanced_df_by_category(df,category):
    # assert(logical.dtype == bool)
    
    # Find the category with least members
    categories = {cat:mem for cat, mem in df.groupby(category)}
    num_per_category = np.array([len(mem) for mem in categories.values()])
    smallest_category = list(categories.keys())[num_per_category.argmin()]
    
    output = []
    for cat, member in categories.items():
        if cat == smallest_category:
            output.append(member)
        else:
            output.append(member.sample(num_per_category.min()))
    output = pd.concat(output,ignore_index=True)

    return output
    
def predict_feature(df:pd.DataFrame,
                    classifier,
                    feature2predict,
                    Niter:int=100,
                    rebalance:bool=True,
                    subsample=None):
    if subsample == None:
        subsample = len(df)
    Y_test = []
    Y_pred = []
    forests = []
    for i in tqdm(range(Niter)):
        
        df_ = get_balanced_df_by_category(df, df[feature2predict,'Meta'].values)
        
        y = df_[feature2predict,'Meta'].astype(float)
        X = df_.xs('PCA',level=1,axis=1).astype(float)
        X = preprocessing.scale(X)
        
        X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y)
        
        model = classifier.fit(X_train,y_train)
        forests.append(model)
        
        Y_test.append(y_test)
        Y_pred.append(model.predict(X_test))
        
    return [np.stack((np.array(Y_test),np.array(Y_pred))),forests]

# %%
dataset_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Dataset pickles'
all_df = pd.read_pickle(path.join(dataset_dir,f'all_df.pkl'))
births = pd.read_pickle(path.join(dataset_dir,f'births.pkl'))

pca_dir = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Mesa et al/Lineage models/Probabilistic PCA'
basals_pca = pd.read_pickle(path.join(pca_dir,'basals/transformed.pkl'))
basals_components = pd.read_pickle(path.join(pca_dir,'basals/components.pkl'))

# %% [markdown]
# ## 1. Categorize cell from its birth frame

# %% [markdown]
# ### Random forest

# %%
# Run classifier
# axis0: observation axis1: prediction

feature2predict = 'Will differentiate'
basals_pca = basals_pca[basals_pca['Fate known','Meta']]
basals_pca = basals_pca[basals_pca['Frac of neighbors are border','Meta'] < .2]
basals_pca = basals_pca[basals_pca['Cell cycle phase','Meta'] == 'G1']
predictions,models = predict_feature(basals_pca, ensemble.RandomForestClassifier(), feature2predict)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [01:01<00:00,  1.62it/s]

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.title('Predict self-fate from birth frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict self-fate from birth frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')

# %% [markdown]
# ### Plot the impurity importances

# %%
pca_names = basals_pca.xs('PCA',level=1,axis=1).columns
importances = pd.DataFrame([m.feature_importances_ for m in models],columns=pca_names)
importances.mean(axis=0).sort_values().tail(20).plot.bar()

plt.ylabel('Impurity importance')
# Out:
# Text(0, 0.5, 'Impurity importance')

# %%
basals_components[5].sort_values().tail(20)
# Out:
# Name
# Median adjac Basal area at 1 frame prior                    0.053983
# Mean adjac Total FUCCI intensity at 1 frame prior           0.054462
# Min adjac Planar component 1 at 1 frame prior               0.054559
# Min adjac cyto_shcoeffs_L1M0C                               0.054619
# Min adjac cyto_shcoeffs_L1M0C at 1 frame prior              0.054957
# Mean adjac Basal area at 1 frame prior                      0.055543
# Min adjac cyto_shcoeffs_surface_area at 1 frame prior       0.057261
# Min adjac Cell volume at 1 frame prior                      0.057454
# Median adjac cyto_shcoeffs_L0M0C at 1 frame prior           0.057715
# Mean adjac cyto_shcoeffs_L0M0C at 1 frame prior             0.057916
# Min adjac Mean curvature - cell coords                      0.057940
# Relative Height to BM                                       0.058020
# Mean adjac Cell volume at 1 frame prior                     0.058093
# Median adjac Cell volume at 1 frame prior                   0.058167
# Min adjac Mean curvature - cell coords at 1 frame prior     0.058194
# Median adjac cyto_shcoeffs_surface_area at 1 frame prior    0.059055
# Mean adjac cyto_shcoeffs_surface_area at 1 frame prior      0.059446
# Min adjac Basal area at 1 frame prior                       0.059586
# Min adjac Total FUCCI intensity at 1 frame prior            0.060347
# Min adjac Basal area                                        0.063731
# Name: 5, dtype: float64

# %%
basals_components[5].sort_values().head(20)
# Out:
# Name
# Relative Total H2B intensity          -0.119223
# Relative cyto_shcoeffs_L0M0C          -0.117997
# Relative cyto_shcoeffs_surface_area   -0.115592
# Relative Cell volume                  -0.112570
# Relative Cell volume standard         -0.112570
# Relative nuc_shcoeffs_L0M0C           -0.104893
# Total H2B intensity                   -0.104061
# Total H2B intensity smoothed          -0.103998
# Relative Nuclear volume               -0.103491
# Relative Nuclear volume standard      -0.103491
# Relative nuc_shcoeffs_surface_area    -0.103210
# Nuclear volume standard               -0.102501
# nuc_shcoeffs_surface_area             -0.099049
# Relative Middle area                  -0.098613
# cyto_shcoeffs_surface_area            -0.097996
# Nuclear volume smoothed               -0.097846
# Nuclear volume                        -0.097762
# Cell volume standard                  -0.097713
# cyto_shcoeffs_L0M0C                   -0.096722
# nuc_shcoeffs_L0M0C                    -0.095904
# Name: 5, dtype: float64

# %% [markdown]
# ### Logistic

# %%
# Run classifier
# axis0: observation axis1: prediction

feature2predict = 'Will differentiate'
predictions,models = predict_feature(basals_pca, linear_model.LogisticRegression(), feature2predict)
# Out:
# 100%|████████████████████████████████████████| 100/100 [00:00<00:00, 158.83it/s]

# %%
# Calculate the confusion matrix
avg_confusion = np.array([metrics.confusion_matrix(a,b)/len(a) for a,b in zip(predictions[0,:],predictions[1,:])])

plt.title('Predict self-fate from birth frame (random forest)')
sb.heatmap(avg_confusion.mean(axis=0),annot=True,vmin=0,vmax=0.5)
plt.gca().set_xticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.gca().set_yticks([0.5,1.5],labels=['Divide','Differentiate'])
plt.xlabel('Measured fate')
plt.ylabel('Predicted fate')

# Calculate AUC scores
AUCs = np.array([metrics.roc_auc_score(a,b) for a,b in zip(predictions[0,:],predictions[1,:])])
plt.figure()
plt.title('Predict self-fate from birth frame (random forest)')
sb.histplot(AUCs)
plt.xlabel('AUCs')
# Out:
# Text(0.5, 0, 'AUCs')

# %%
importances = pd.DataFrame([m.coef_.squeeze() for m in models],columns=pca_names)
importances.mean(axis=0).abs().sort_values().tail(20).plot.bar()

plt.ylabel('Linear effect size')
# Out:
# Text(0, 0.5, 'Linear effect size')

# %%
sb.catplot(basals_pca.droplevel(axis=1,level=1),x='Will differentiate',y='PC5_basals',kind='violin')

# %%
basals_components.loc['Mean curvature'].plot.bar()
# Out:
# <Axes: >

# %%
basals_components[12].sort_values()
# Out:
# Name
# Relative Cell height                                           -0.115878
# Relative Planar component 2                                    -0.114740
# Relative Planar component 1                                    -0.114321
# Relative Height to BM                                          -0.111304
# Relative Height to BM at 1 frame prior                         -0.102707
#                                                                   ...
# Nuclear height                                                  0.086473
# Cell volume G1 only exponential growth rate at 1 frame prior    0.086864
# Cell volume exponential growth rate at 1 frame prior            0.088544
# Mean curvature                                                  0.090395
# Mean curvature - cell coords                                    0.103253
# Name: 12, Length: 1377, dtype: float64

# %% [markdown]
# ## Misc: visualizations

# %%
plt.figure()
x = 'Mean curvature'
y = 'Cell volume G1 only exponential growth rate'
sb.lmplot(all_df.droplevel(axis=1,level=1)[[x,y]].groupby('TrackID').mean(),x=x,y=y,
          scatter_kws={'alpha':0.1})

plt.figure()
x = 'Basal area'
y = 'Cell volume G1 only exponential growth rate'
sb.lmplot(all_df.droplevel(axis=1,level=1)[[x,y]].groupby('TrackID').mean(),x=x,y=y,
          scatter_kws={'alpha':0.1}, fit_reg=True)

# %%
features2drop = [f for f in all_df.droplevel(axis=1,level=1).columns if 'smoothed' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'shcoeffs' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'prior' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'standard' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'BM' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'intensity' in f]
features2drop += [f for f in all_df.droplevel(axis=1,level=1).columns if 'Time' in f]
A = all_df.droplevel(axis=1,level=1).drop(
    columns=['X','X-pixels','Y','Y-pixels','X-cyto','Y-cyto','Z','Z-cyto',
             'Daughter a','Daughter b','Mother','Sister']+features2drop).select_dtypes(numerics).corr(numeric_only=True)

B = A.abs().unstack().sort_values(ascending=False)

unique_pairs = []
# Iterate over the top pairs and add only unique pairs to the list
for pair in B.index:
    if pair[0] != pair[1] and (pair[1], pair[0]) not in unique_pairs:
        unique_pairs.append(pair)

# Create a dataframe with the top pairs and their correlation coefficients
corr_df = pd.DataFrame(columns=['feature_1', 'feature_2', 'corr_coef'])
for i, pair in enumerate(unique_pairs):
    corr_df.loc[i] = [pair[0], pair[1], B.loc[pair[0], pair[1]]]

display(corr_df.dropna().head(50))
# Out:
#                                             feature_1  \
# 0                                 Nuclear bbox bottom
# 1              Nuclear volume exponential growth rate
# 2                 Cell volume exponential growth rate
# 3                                  Planar component 2
# 4                                     Axial component
# 5                                               Right
# 6                        Mean curvature - cell coords
# 7                                      Nuclear volume
# 8                                    Nuclear bbox top
# 9                                         Cell height
# 10                                        Cell volume
# 11                                        Cell volume
# 12                                 Planar component 2
# 13                                                Age
# 14                                         Basal area
# 15                                        Cell volume
# 16                                                Age
# 17                                     Nuclear volume
# 18                                     Nuclear volume
# 19                                         Basal area
# 20                                        Cell volume
# 21                                    Axial component
# 22                                               Left
# 23                                                Age
# 24                                     Nuclear volume
# 25                Cell volume exponential growth rate
# 26                                     Nuclear height
# 27                                     Mean curvature
# 28                                     Nuclear volume
# 29                                 Planar component 2
# 30                                   Nuclear bbox top
# 31                       Mean curvature - cell coords
# 32                                Nuclear bbox bottom
# 33                                               Left
# 34  Nuclear volume (filter_name) exponential growt...
# 35                                                Age
# 36                Cell volume exponential growth rate
# 37                                Nuclear bbox bottom
# 38  Cell volume (filter_name) exponential growth rate
# 39                                     Mean curvature
# 40                                        Apical area
# 41                       Mean curvature - cell coords
# 42                                        Cell volume
# 43                   Gaussian curvature - cell coords
# 44                       Mean curvature - cell coords
# 45                                        Cell height
# 46                                              Right
# 47                                         Basal area
# 48                                Nuclear bbox bottom
# 49                                     Nuclear height
#
#                                             feature_2  corr_coef
# 0                                    Nuclear bbox top   0.979166
# 1   Nuclear volume (filter_name) exponential growt...   0.919772
# 2   Cell volume (filter_name) exponential growth rate   0.904737
# 3                                  Planar component 1   0.823052
# 4                                         Middle area   0.747579
# 5                                                Left   0.747405
# 6                                 Nuclear bbox bottom   0.742856
# 7                                         Cell volume   0.731716
# 8                        Mean curvature - cell coords   0.714124
# 9                                  Planar component 1   0.693165
# 10                                    Axial component   0.667787
# 11                                        Middle area   0.662634
# 12                                        Cell height   0.661607
# 13                                Nuclear bbox bottom   0.641208
# 14                                        Middle area   0.628931
# 15                                 Planar component 2   0.628114
# 16                                   Nuclear bbox top   0.612001
# 17                                   Nuclear bbox top   0.598682
# 18                                                Age   0.588559
# 19                                    Axial component   0.587837
# 20                                 Planar component 1   0.580992
# 21                                     Nuclear volume   0.579717
# 22                                Nuclear bbox bottom   0.557465
# 23                       Mean curvature - cell coords   0.548884
# 24                                Nuclear bbox bottom   0.548524
# 25             Nuclear volume exponential growth rate   0.543454
# 26                                 Planar component 1   0.537833
# 27                                   Nuclear bbox top   0.531308
# 28                                        Middle area   0.529813
# 29                                     Nuclear height   0.526052
# 30                                               Left   0.522807
# 31                                               Left   0.522402
# 32                                     Mean curvature   0.516032
# 33                                                Age   0.486130
# 34  Cell volume (filter_name) exponential growth rate   0.485417
# 35                                        Cell volume   0.472507
# 36  Nuclear volume (filter_name) exponential growt...   0.463318
# 37                                     Nuclear height   0.459355
# 38             Nuclear volume exponential growth rate   0.457069
# 39                       Mean curvature - cell coords   0.454429
# 40                                        Cell height   0.446865
# 41                                         Basal area   0.412454
# 42                                         Basal area   0.410414
# 43                                Nuclear bbox bottom   0.404653
# 44                                     Nuclear height   0.399217
# 45                                         Basal area   0.398984
# 46                       Mean curvature - cell coords   0.395751
# 47                                     Nuclear volume   0.378462
# 48                                         Basal area   0.375618
# 49                                        Cell volume   0.373174
