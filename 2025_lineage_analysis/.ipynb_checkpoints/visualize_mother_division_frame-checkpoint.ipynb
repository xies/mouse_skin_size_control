# %%
import numpy as np
import pandas as pd

# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb

# General utils
from tqdm import tqdm
from os import path

from skimage import io
from sklearn import preprocessing, model_selection, linear_model
from sklearn import ensemble, metrics

# %%
dirnames = {'R1':'/Users/xies/OneDrive - Stanford/Skin/Mesa et al/W-R1/',
           'R2':'/Users/xies/OneDrive - Stanford/Skin/Mesa et al/W-R2/'}
all_df = []
for name,dirname in dirnames.items():
    _df = pd.read_pickle(path.join(dirname,'Mastodon/single_timepoints_dynamics_aggregated_lookback_history.pkl'))
    _df = _df.drop_duplicates().sort_index().reset_index()
    _df['Region','Meta'] = name
    _df['TrackID'] = name + '_' + _df['TrackID'].astype(str)
    _df = _df.set_index(['Frame','TrackID'])
    all_df.append(_df)

all_df = pd.concat(all_df)
all_tracks = {trackID:t for trackID,t in all_df.reset_index().groupby('TrackID')}

# %%
df = all_df[all_df['Fate known','Meta']]
df = df[ ~df['Border','Meta']]
df = df[ df['Cell type','Meta'] == 'Basal']

births = df[df['Birth frame','Meta']]
births[('Relative basal area','Measurement')] = \
    births['Basal area','Measurement'] / births['Mean adjac Basal area','Measurement']

len(births)
# Out:
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19153/1390024279.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   births[('Relative basal area','Measurement')] = \
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19153/1390024279.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   births[('Relative basal area','Measurement')] = \
# 766

# %%
g = sb.FacetGrid(births.droplevel(1,axis=1), col='Region',hue='Will differentiate')
g.map(sb.scatterplot,'X','Y',alpha=0.5)

# %%
dx = .25
t0 = io.imread(path.join(path.join(dirname,'im_seq/t0.tif')))
ax = plt.imshow(t0[55,...,1])
_df = births[births['Will differentiate','Meta']].droplevel(level=1,axis=1)
plt.scatter(_df['X']/dx,_df['Y']/dx,color='r',alpha=0.5)

# %%
sb.scatterplot(births[~births['Will differentiate','Meta']].droplevel(level=1,axis=1),x='X',y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df = all_df[~np.isnan(all_df['Num daughter differentiated','Meta'])]
divisions = df[df['Division','Meta']]
divisions[('Relative basal area','Measurement')] = \
    divisions['Basal area','Measurement'] / divisions['Mean adjac Basal area','Measurement']
g = sb.FacetGrid(divisions.droplevel(1,axis=1), col='Region',hue='Num daughter differentiated')
g.map(sb.scatterplot,'X','Y')
g.add_legend()
# Out:
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19153/477426830.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   divisions[('Relative basal area','Measurement')] = \
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_19153/477426830.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   divisions[('Relative basal area','Measurement')] = \

# %%
sb.catplot(divisions.droplevel(1,axis=1),x='Num daughter differentiated',y='Relative basal area',hue='Region',kind='violin')
sb.catplot(divisions.droplevel(1,axis=1),x='Num daughter differentiated',y='Mean curvature',hue='Region',kind='violin')
sb.catplot(divisions.droplevel(1,axis=1),x='Num daughter differentiated',y='Mean curvature',hue='Region',kind='box',dodge=True)

# %%
sb.lmplot(all_df.droplevel(1,axis=1),x='Mean curvature',y='Basal area',hue='Region',scatter_kws={'alpha':.1})

# %%
sb.catplot(divisions.droplevel(1,axis=1),x='Num daughter differentiated',y='Num neighbor division 1 frame prior',kind='violin')
sb.catplot(divisions.droplevel(1,axis=1),x='Num daughter differentiated',y='Num neighbor delamination 1 frame prior',kind='violin')

# %%
divisions.droplevel(1,axis=1).groupby('Num daughter differentiated')['Num neighbor division 1 frame prior'].mean()
# Out:
# Num daughter differentiated
# 0.0    0.696429
# 1.0    0.620690
# 2.0    0.519481
# Name: Num neighbor division 1 frame prior, dtype: float64

# %%
divisions.droplevel(1,axis=1).groupby('Num daughter differentiated')['Num neighbor delamination 1 frame prior'].mean()
# Out:
# Num daughter differentiated
# 0.0    0.732143
# 1.0    0.612069
# 2.0    0.493506
# Name: Num neighbor delamination 1 frame prior, dtype: float64

# %%
births
# Out:
# Name          Nuclear volume Nuclear solidity Nuclear bbox top  \
# Metadata         Measurement      Measurement      Measurement
# Frame TrackID
# 1     R1_3          116.6250         0.848954             41.0
#       R1_4          101.6875         0.813500             42.0
#       R1_29         151.6250         0.854526             49.0
#       R1_30         143.4375         0.811815             41.0
#       R1_39         138.8750         0.915157             44.0
# ...                      ...              ...              ...
# 11    R2_1064       160.0625         0.822943             41.0
#       R2_1065       123.1250         0.861767             40.0
#       R2_1112       164.1250         0.833916             38.0
#       R2_1135       228.8750         0.887973             39.0
# 12    R2_1091        99.5625         0.789004             45.0
#
# Name          Nuclear bbox bottom           Z           Y           X  \
# Metadata              Measurement Measurement Measurement Measurement
# Frame TrackID
# 1     R1_3                   51.0   45.346731  107.626340   36.175643
#       R1_4                   52.0   46.580824  106.917179   41.199754
#       R1_29                  56.0   51.597279   22.018343   78.469291
#       R1_30                  52.0   46.395643   18.079521   82.449455
#       R1_39                  54.0   47.996850   47.045792   87.840684
# ...                           ...         ...         ...         ...
# 11    R2_1064                52.0   46.100742   85.722276   25.094885
#       R2_1065                49.0   43.363452   81.018782   26.719289
#       R2_1112                47.0   41.880807  103.229817   39.728960
#       R2_1135                52.0   44.300382   15.694839   96.979929
# 12    R2_1091                56.0   49.696171   81.698211   12.495763
#
# Name          Nuclear height Cell volume      Z-cyto  ...  \
# Metadata         Measurement Measurement Measurement  ...
# Frame TrackID                                         ...
# 1     R1_3             -10.0    278.5000   44.794434  ...
#       R1_4             -10.0    294.6250   46.476665  ...
#       R1_29             -7.0    291.5000   51.080189  ...
#       R1_30            -11.0    497.6875   47.175688  ...
#       R1_39            -10.0    345.6875   47.974146  ...
# ...                      ...         ...         ...  ...
# 11    R2_1064          -11.0    335.0625   46.032270  ...
#       R2_1065           -9.0    373.6875   43.187155  ...
#       R2_1112           -9.0    429.1875   41.724916  ...
#       R2_1135          -13.0    508.8750   44.462171  ...
# 12    R2_1091          -11.0    400.3750   50.700437  ...
#
# Name          Median adjac Nuclear volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                                             Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.003926
#       R2_1065                                           0.003926
#       R2_1112                                           0.008983
#       R2_1135                                                NaN
# 12    R2_1091                                          -0.000273
#
# Name          Std adjac Nuclear volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                                          Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.002915
#       R2_1065                                           0.002915
#       R2_1112                                            0.00726
#       R2_1135                                                NaN
# 12    R2_1091                                           0.001208
#
# Name          Std adjac Cell volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                                       Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.003799
#       R2_1065                                           0.003799
#       R2_1112                                           0.002867
#       R2_1135                                                NaN
# 12    R2_1091                                            0.00428
#
# Name          Mean adjac Reviewed by at 1 frame prior  \
# Metadata                                  Measurement
# Frame TrackID
# 1     R1_3                                        NaN
#       R1_4                                        NaN
#       R1_29                                       NaN
#       R1_30                                       NaN
#       R1_39                                       NaN
# ...                                               ...
# 11    R2_1064                                     0.0
#       R2_1065                                     0.0
#       R2_1112                                     0.0
#       R2_1135                                     0.0
# 12    R2_1091                                     0.0
#
# Name          Cell volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                             Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.010945
#       R2_1065                                           0.010945
#       R2_1112                                           0.005336
#       R2_1135                                           0.009108
# 12    R2_1091                                           0.004733
#
# Name          Min adjac Nuclear volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                                          Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.001707
#       R2_1065                                           0.001707
#       R2_1112                                          -0.006341
#       R2_1135                                                NaN
# 12    R2_1091                                          -0.001537
#
# Name          Median adjac Reviewed by at 1 frame prior  \
# Metadata                                    Measurement
# Frame TrackID
# 1     R1_3                                          NaN
#       R1_4                                          NaN
#       R1_29                                         NaN
#       R1_30                                         NaN
#       R1_39                                         NaN
# ...                                                 ...
# 11    R2_1064                                       0.0
#       R2_1065                                       0.0
#       R2_1112                                       0.0
#       R2_1135                                       0.0
# 12    R2_1091                                       0.0
#
# Name          Max adjac Reviewed by at 1 frame prior  \
# Metadata                                 Measurement
# Frame TrackID
# 1     R1_3                                       NaN
#       R1_4                                       NaN
#       R1_29                                      NaN
#       R1_30                                      NaN
#       R1_39                                      NaN
# ...                                              ...
# 11    R2_1064                                  False
#       R2_1065                                  False
#       R2_1112                                  False
#       R2_1135                                  False
# 12    R2_1091                                  False
#
# Name          Mean adjac Cell volume (filter_name) exponential growth rate at 1 frame prior  \
# Metadata                                                                        Measurement
# Frame TrackID
# 1     R1_3                                                   NaN
#       R1_4                                                   NaN
#       R1_29                                                  NaN
#       R1_30                                                  NaN
#       R1_39                                                  NaN
# ...                                                          ...
# 11    R2_1064                                           0.009736
#       R2_1065                                           0.009736
#       R2_1112                                           0.009748
#       R2_1135                                                NaN
# 12    R2_1091                                           0.001427
#
# Name          Relative basal area
# Metadata              Measurement
# Frame TrackID
# 1     R1_3               1.059543
#       R1_4               0.551845
#       R1_29              0.801679
#       R1_30                   NaN
#       R1_39              0.686334
# ...                           ...
# 11    R2_1064            0.644013
#       R2_1065                 NaN
#       R2_1112                2.25
#       R2_1135                 NaN
# 12    R2_1091                 NaN
#
# [766 rows x 2380 columns]
