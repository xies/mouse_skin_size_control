# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sb
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.special import expit
from basicUtils import *
from os import path
from tqdm import tqdm

from numpy import random
from sklearn.metrics import roc_curve, auc, confusion_matrix, average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

from sklearn.linear_model import LogisticRegression


def keep_only_first_sg2(df):
    collated_first_s = []
    # Groupby CellID and then drop non-first S phase
    for (cellID,frame),cell in df.groupby(['cellID','region']):
        if cell.G1S_logistic.sum() > 1:
            first_sphase_frame = np.where(cell.G1S_logistic)[0][0]
            collated_first_s.append(cell.iloc[0:first_sphase_frame+1])
        else:
            collated_first_s.append(cell)
    return pd.concat(collated_first_s,ignore_index=True)

def rebalance_g1(df,Ng1):
    #% Rebalance class
    g1_sampled = df_g1s[df_g1s['G1S_logistic'] == 0].sample(Ng1,replace=False)
    # df_g1s[df_g1s['Phase' == 'G1']].sample
    sg2 = df_g1s[df_g1s['G1S_logistic'] == 1]

    df_g1s_balanced = pd.concat((g1_sampled,sg2),ignore_index=True)
    return df_g1s_balanced


def run_cross_validation(X,y,split_ratio,model,random_state=42):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=split_ratio,random_state=random_state)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    
    C = confusion_matrix(y_test,y_pred,normalize='all')
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    AUC = auc(fpr,tpr)
    AP = average_precision_score(y_test,y_pred)
    return C, AUC, AP

# %%
# Load datasets

df_ = pd.read_csv('/Users/xies/OneDrive - Stanford/Skin/Mesa et al/Tissue model/df_.csv',index_col=0)
df_g1s = pd.read_csv('/Users/xies/OneDrive - Stanford/Skin/Mesa et al/Tissue model/df_g1s.csv',index_col=0)

df_g1s = keep_only_first_sg2(df_g1s)

df_g1s = df_g1s.drop(columns=['time_g1s','fucci_int_12h','cellID','diff','region'])

# %%
#%% Find how balance changes classification

Niter = 50
Ng12try = np.arange(130,250,10)
C_mlr = np.zeros((Niter,2,2))
frac_withheld = 0.1

Nsg2 = df_g1s.groupby('G1S_logistic').count().loc[1]['age']

AUC = pd.DataFrame(); AP = pd.DataFrame()

for Ng1 in tqdm(Ng12try):
    
    _AUC = np.zeros(Niter)
    _AP = np.zeros(Niter)
    
    for j in range(Niter):
        
        df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
        y_balanced = df_g1s_balanced['G1S_logistic']
        df_g1s_balanced = df_g1s_balanced.drop(columns='G1S_logistic')

        mlr = LogisticRegression()
        C_mlr[j,:,:],_auc,ap = run_cross_validation(df_g1s_balanced,y_balanced,frac_withheld,mlr)
        _AUC[j] = _auc
        _AP[j] = ap
    
    AUC.at[Ng1/Nsg2,'MLR'] = _AUC.mean()
    AP.at[Ng1/Nsg2,'MLR'] = _AP.mean()
    
AUC.plot()
plt.xlabel('G1 to SG2 ratio')
plt.ylabel('AUC')
AP.plot()
plt.xlabel('G1 to SG2 ratio')
plt.ylabel('Average precision')
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:06<00:00,  1.77it/s]
# Text(0, 0.5, 'Average precision')

# %%
#%% Logistic for G1/S transition: skip all non-first SG2 timepoints
# Random rebalance with 1:1 ratio
# No cross-validation, in-model estimates only

Ng1 = 150
Niter = 100

coefficients = np.ones((Niter,df_g1s.shape[1]-1)) * np.nan
li = np.ones((Niter,df_g1s.shape[1]-1)) * np.nan
ui = np.ones((Niter,df_g1s.shape[1]-1)) * np.nan
pvalues = np.ones((Niter,df_g1s.shape[1]-1)) * np.nan

for i in tqdm(range(Niter)):
    
    #% Rebalance class
    df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
    
    ############### G1S logistic as function of age ###############
    try:
        model_g1s = smf.logit('G1S_logistic ~ ' + str.join(' + ',df_g1s.columns[df_g1s.columns != 'G1S_logistic']),
                      data=df_g1s_balanced).fit(maxiter=1000)
    except:
        continue
    
    # plt.figure()
    params = model_g1s.params.drop('Intercept')
    pvals = model_g1s.pvalues.drop('Intercept')

    coefficients[i,:] = params.values
    li[i,:] = model_g1s.conf_int()[0].drop('Intercept')
    ui[i,:] = model_g1s.conf_int()[1].drop('Intercept')
    pvalues[i,:] = pvals.values
# Out:
#   4%|█▋                                         | 4/100 [00:00<00:05, 19.17it/s]
# Optimization terminated successfully.
#          Current function value: 0.226456
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.203934
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.210523
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.175874
#          Iterations 10
#   8%|███▍                                       | 8/100 [00:00<00:04, 19.42it/s]
# Optimization terminated successfully.
#          Current function value: 0.231134
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.205468
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.132442
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.228714
#          Iterations 9
#  10%|████▏                                     | 10/100 [00:00<00:04, 19.22it/s]
# Optimization terminated successfully.
#          Current function value: 0.209750
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.222848
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.221215
#          Iterations 9
#  14%|█████▉                                    | 14/100 [00:00<00:05, 16.52it/s]
# Optimization terminated successfully.
#          Current function value: 0.164837
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.191723
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.239783
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.193248
#          Iterations 9
#  18%|███████▌                                  | 18/100 [00:01<00:04, 17.52it/s]
# Optimization terminated successfully.
#          Current function value: 0.198716
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.243498
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.197016
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.233772
#          Iterations 9
#  22%|█████████▏                                | 22/100 [00:01<00:04, 17.59it/s]
# Optimization terminated successfully.
#          Current function value: 0.200868
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.196669
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.194263
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.246703
#          Iterations 9
#  26%|██████████▉                               | 26/100 [00:01<00:04, 18.17it/s]
# Optimization terminated successfully.
#          Current function value: 0.216817
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.237431
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.252967
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.200519
#          Iterations 9
#  30%|████████████▌                             | 30/100 [00:01<00:03, 18.17it/s]
# Optimization terminated successfully.
#          Current function value: 0.182213
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.219576
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.169713
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.217252
#          Iterations 9
#  34%|██████████████▎                           | 34/100 [00:01<00:03, 18.66it/s]
# Optimization terminated successfully.
#          Current function value: 0.198720
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.205887
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.194180
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.209738
#          Iterations 9
#  38%|███████████████▉                          | 38/100 [00:02<00:03, 18.06it/s]
# Optimization terminated successfully.
#          Current function value: 0.218126
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.224845
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.184704
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.201696
#          Iterations 9
#  42%|█████████████████▋                        | 42/100 [00:02<00:03, 18.37it/s]
# Optimization terminated successfully.
#          Current function value: 0.229051
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.246172
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.180864
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.208279
#          Iterations 9
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 18.15it/s]
# Optimization terminated successfully.
#          Current function value: 0.253262
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.176302
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.211769
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.210798
#          Iterations 9
#  50%|█████████████████████                     | 50/100 [00:02<00:02, 18.13it/s]
# Optimization terminated successfully.
#          Current function value: 0.221731
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.215679
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.189465
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.218810
#          Iterations 9
#  54%|██████████████████████▋                   | 54/100 [00:02<00:02, 17.93it/s]
# Optimization terminated successfully.
#          Current function value: 0.187442
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.207441
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.231321
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.215728
#          Iterations 9
#  58%|████████████████████████▎                 | 58/100 [00:03<00:02, 18.17it/s]
# Optimization terminated successfully.
#          Current function value: 0.152447
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.181005
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.228761
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.223396
#          Iterations 9
#  62%|██████████████████████████                | 62/100 [00:03<00:02, 18.07it/s]
# Optimization terminated successfully.
#          Current function value: 0.211858
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.220721
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.259052
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.255833
#          Iterations 8
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 17.94it/s]
# Optimization terminated successfully.
#          Current function value: 0.199568
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.218698
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.218377
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.191360
#          Iterations 9
#  70%|█████████████████████████████▍            | 70/100 [00:03<00:01, 17.35it/s]
# Optimization terminated successfully.
#          Current function value: 0.206654
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.167364
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.235965
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.232688
#          Iterations 9
#  74%|███████████████████████████████           | 74/100 [00:04<00:01, 17.57it/s]
# Optimization terminated successfully.
#          Current function value: 0.184571
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.208722
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.214517
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.206022
#          Iterations 9
#  78%|████████████████████████████████▊         | 78/100 [00:04<00:01, 17.35it/s]
# Optimization terminated successfully.
#          Current function value: 0.205362
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.181685
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.244172
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.229135
#          Iterations 9
#  82%|██████████████████████████████████▍       | 82/100 [00:04<00:01, 17.74it/s]
# Optimization terminated successfully.
#          Current function value: 0.237888
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.221164
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.227956
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.260468
#          Iterations 8
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 17.81it/s]
# Optimization terminated successfully.
#          Current function value: 0.193149
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.261592
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.202046
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.210859
#          Iterations 9
#  90%|█████████████████████████████████████▊    | 90/100 [00:05<00:00, 18.21it/s]
# Optimization terminated successfully.
#          Current function value: 0.210760
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.187709
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.236847
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.222024
#          Iterations 9
#  94%|███████████████████████████████████████▍  | 94/100 [00:05<00:00, 18.44it/s]
# Optimization terminated successfully.
#          Current function value: 0.160634
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.219465
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.201376
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.199709
#          Iterations 9
#  98%|█████████████████████████████████████████▏| 98/100 [00:05<00:00, 17.87it/s]
# Optimization terminated successfully.
#          Current function value: 0.210970
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.218413
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.194897
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.201362
#          Iterations 9
# 100%|█████████████████████████████████████████| 100/100 [00:05<00:00, 17.94it/s]
# Optimization terminated successfully.
#          Current function value: 0.168674
#          Iterations 10

# %%
df_g1s_balanced.
# Out:
#           age         y         x  rel_height_to_bm    vol_sm  nuc_vol_sm  \
# 0   -0.857852 -0.154797 -1.506695          1.548961 -0.211312    0.227172
# 1    0.991517  0.393786 -1.443206         -0.271910  1.105406    0.970453
# 2   -0.395510 -1.233021  1.559266          0.484017 -0.857902   -0.810780
# 3    0.991517  1.257050 -0.201720         -1.610975  0.853619    0.514815
# 4   -0.395510 -0.027453  0.875933          0.027220 -0.947492   -0.931174
# ..        ...       ...       ...               ...       ...         ...
# 285  0.066833  0.017973 -0.983785         -0.233379  1.098259    0.706623
# 286  0.066833  1.250137 -0.144708         -0.287535  1.599498    1.238344
# 287  0.066833 -1.888554  0.031676          0.713079  1.629551    1.924186
# 288  0.066833 -0.281835  0.302073         -1.387781  1.479823    1.602071
# 289  0.066833 -0.622389  0.294177         -1.268288  1.250133    0.483146
#
#      sa_to_vol  nc_ratio  nuc_solid  axial_ecc  ...  mean_neighb_fucci_int  \
# 0     2.089119  1.041176   0.128612   0.483691  ...               0.189175
# 1    -0.275319 -0.151038   0.530834  -0.819963  ...              -0.284127
# 2     0.729543 -0.027563   0.450815  -0.819785  ...              -0.815277
# 3     0.263099 -0.575004  -0.005076  -0.961727  ...              -0.702807
# 4     0.980106 -0.141252  -0.326519  -0.030767  ...               0.088385
# ..         ...       ...        ...        ...  ...                    ...
# 285   0.039586 -0.617142  -0.145672  -0.878269  ...              -0.722469
# 286  -1.032738 -0.463694   0.217142   2.963640  ...              -0.858325
# 287   0.007150  0.611625   0.867695   0.848978  ...              -0.815634
# 288  -0.585255  0.326117   0.573362   0.484819  ...              -0.670801
# 289   0.324229 -1.242955  -0.867754   1.828722  ...              -0.752820
#
#           sgr  collagen_alignment_12h  mean_neighb_vol_12h  \
# 0   -0.354152                1.149144             0.028561
# 1   -1.057961                0.826283             0.461021
# 2   -0.132233                0.761514            -0.834495
# 3    0.173164                0.702791            -0.298629
# 4   -0.858721                1.036093             0.049411
# ..        ...                     ...                  ...
# 285  1.106645               -1.489145             0.326491
# 286  1.466725               -1.054087            -1.833100
# 287 -0.630319                0.525419            -0.574711
# 288 -0.076751                1.213457             0.987633
# 289 -0.440716                1.081515             0.283056
#
#      std_neighb_vol_12h  max_neighb_height_to_bm_12h  \
# 0             -1.028110                     0.734148
# 1             -0.065102                     0.408720
# 2              0.499794                     1.681999
# 3              0.413630                     1.360005
# 4             -0.132616                     0.594874
# ..                  ...                          ...
# 285            1.332674                     0.830644
# 286           -1.131077                     0.200257
# 287           -0.755473                     0.472155
# 288            2.231309                    -0.012892
# 289           -0.195000                    -0.988156
#
#      mean_neighb_collagen_align_12h  num_planar_neighb_12h  \
# 0                          1.187463               1.435862
# 1                         -0.533596              -0.259677
# 2                          1.232805               0.588092
# 3                         -0.502807               1.435862
# 4                         -1.046617              -0.259677
# ..                              ...                    ...
# 285                        1.184263               0.588092
# 286                       -2.011211              -0.259677
# 287                        1.360687               0.588092
# 288                        0.324597               0.588092
# 289                        0.413639               1.435862
#
#      num_diff_neighb_12h  G1S_logistic
# 0              -0.701453         False
# 1               0.674883         False
# 2              -0.701453         False
# 3              -0.701453         False
# 4               0.674883         False
# ..                   ...           ...
# 285             0.674883          True
# 286             0.674883          True
# 287             0.674883          True
# 288            -0.701453          True
# 289            -0.701453          True
#
# [290 rows x 40 columns]

# %%
coefficients = pd.DataFrame(coefficients,columns = df_g1s.columns.drop('G1S_logistic')).dropna()
pvalues = pd.DataFrame(pvalues,columns = df_g1s.columns.drop('G1S_logistic')).dropna()
li = pd.DataFrame(li,columns = df_g1s.columns.drop('G1S_logistic')).dropna()
ui = pd.DataFrame(ui,columns = df_g1s.columns.drop('G1S_logistic')).dropna()

# Effect size v. pvalue
plt.errorbar(x=coefficients.mean(axis=0), y=-np.log10(pvalues).mean(axis=0),
             xerr = coefficients.std(axis=0),
             yerr = np.log10(pvalues).std(axis=0),
             fmt='bo')

# Label sig variables
sig_params = pvalues.columns[-np.log10(pvalues).mean(axis=0) > -np.log10(0.01)]
for p in sig_params:
    plt.text(coefficients[p].mean() + 0.01, -np.log10(pvalues[p]).mean() + 0.01, p)
plt.hlines(-np.log10(0.01),xmin=-1.5,xmax=2.0,color='r')
plt.xlabel('Regression coefficient')
plt.ylabel('-Log(P)')

params = pd.DataFrame()
params['var'] = coefficients.columns.values
params['coef'] = coefficients.mean(axis=0).values
params['li'] = li.mean(axis=0).values
params['ui'] = ui.mean(axis=0).values

params['err'] = params['ui'] - params['coef']
params['effect size'] = params['coef']

order = np.argsort( np.abs(params['coef']) )[::-1][0:5]
params = params.iloc[order]

plt.figure()
plt.bar(range(len(params)),params['coef'],yerr=params['err'])
plt.xticks(range(5),params['var'],rotation=30)
# Out:
# /Users/xies/anaconda3/envs/python39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: The behavior of Series.argsort in the presence of NA values is deprecated. In a future version, NA values will be ordered last instead of set to -1.
#   return bound(*args, **kwds)
# ([<matplotlib.axis.XTick at 0x7f7b50f8f790>,
#   <matplotlib.axis.XTick at 0x7f7b50f8f760>,
#   <matplotlib.axis.XTick at 0x7f7b50f86f10>,
#   <matplotlib.axis.XTick at 0x7f7b50fcf910>,
#   <matplotlib.axis.XTick at 0x7f7b50fcfa60>],
#  [Text(0, 0, 'num_diff_neighb_12h'),
#   Text(1, 0, 'num_diff_neighb_12h'),
#   Text(2, 0, 'num_diff_neighb_12h'),
#   Text(3, 0, 'num_diff_neighb_12h'),
#   Text(4, 0, 'num_diff_neighb_12h')])

# %%
params
# Out:
#                     var  coef  li  ui  err  effect size
# 38  num_diff_neighb_12h   NaN NaN NaN  NaN          NaN
# 38  num_diff_neighb_12h   NaN NaN NaN  NaN          NaN
# 38  num_diff_neighb_12h   NaN NaN NaN  NaN          NaN
# 38  num_diff_neighb_12h   NaN NaN NaN  NaN          NaN
# 38  num_diff_neighb_12h   NaN NaN NaN  NaN          NaN

# %%
#%% Cross-validation for MLR

Niter = 1000
frac_withheld = 0.1
N = len(df_g1s_balanced)

AUC = pd.DataFrame(np.zeros((Niter,2)),columns=['MLR','Random data'])
AP = pd.DataFrame(np.zeros((Niter,2)),columns=['MLR','Random data'])
C_mlr = np.zeros((Niter,2,2))
C_random = np.zeros((Niter,2,2))

for i in tqdm(range(Niter)):
    
    df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
    y_balanced = df_g1s_balanced['G1S_logistic']
    df_g1s_balanced = df_g1s_balanced.drop(columns='G1S_logistic')

    #Logistic regression
    mlr = LogisticRegression(random_state = i,max_iter=1000)
    C_mlr[i,:,:],_AUC,_AP = run_cross_validation(df_g1s_balanced,y_balanced,frac_withheld,mlr)
    AUC.at[i,'MLR'] = _AUC
    AP.at[i,'MLR'] = _AP
    
    #Random data model
    df_random = pd.DataFrame(random.randn(*df_g1s_balanced.shape))
    random_model = LogisticRegression(random_state = i)
    C_random[i,:,:],_AUC,_AP = run_cross_validation(df_random,y_balanced,frac_withheld,random_model)
    AUC.at[i,'Random data'] = _AUC
    AP.at[i,'Random data'] = _AP
    
hist_weights = np.ones(Niter)/Niter
plt.figure()
sb.histplot(AUC.melt(),x='value',hue='variable',element='poly',stat='probability'); plt.title(f'MLR classification cross-validation, {frac_withheld*100}% withheld');plt.xlabel('AUC')
plt.vlines(AUC['MLR'].mean(),0,0.2,'r')
plt.figure()
sb.histplot(AP.melt(),x='value',hue='variable',element='poly',stat='probability'); plt.title(f'MLR classification cross-validation, {frac_withheld*100}% withheld');plt.xlabel('Average precision')
plt.vlines(AP['MLR'].mean(),0,0.2,'r')

plt.figure();sb.heatmap(np.mean(C_mlr,axis=0),xticklabels=['G1','SG2M'],yticklabels=['G1','SG2M'],annot=True)
plt.title(f'MLR Confusion matrix, {frac_withheld*100}% withheld, average over {Niter} iterations')

#%%  Permutation importance for MLR

from sklearn.linear_model import LogisticRegression
from sklearn.inspection import permutation_importance

df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
y_balanced = df_g1s_balanced['G1S_logistic']

X = df_g1s_balanced.drop(columns='G1S_logistic'); y = df_g1s_balanced['G1S_logistic']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=frac_withheld,random_state=42)
logist_model = LogisticRegression(random_state=42,max_iter=1000).fit(X_train,y_train)
result = permutation_importance(logist_model,X_test,y_test,n_repeats=100,random_state=42,n_jobs=2)
logit_importances = pd.Series(result.importances_mean, index=X_train.columns).sort_values(ascending=False)

plt.figure()
logit_importances.plot.bar(yerr=result.importances_std)
plt.ylabel("Mean accuracy decrease")
plt.tight_layout()
plt.show()

#%% Random forest classifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree

Niter = 100
frac_withheld = 0.1

AUC = pd.DataFrame()
AP = pd.DataFrame()
C_rf = np.zeros((Niter,2,2))
C_random = np.zeros((Niter,2,2))

for i in tqdm(range(Niter)):
    
    df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
    y_balanced = df_g1s_balanced['G1S_logistic']
    df_g1s_balanced = df_g1s_balanced.drop(columns='G1S_logistic')
    
    # Random forest
    forest = RandomForestClassifier(n_estimators=100, random_state=i)
    C_rf[i,:,:],_AUC,_AP = run_cross_validation(df_g1s_balanced,y_balanced,frac_withheld,forest)
    AUC.at[i,'RF'] = _AUC
    AP.at[i,'RF'] = _AP
    
    # Random data model
    df_random = pd.DataFrame(random.randn(*df_g1s_balanced.shape))
    random_model = RandomForestClassifier(random_state = i)
    C_random[i,:,:],_AUC,_AP = run_cross_validation(df_random,y_balanced,frac_withheld,random_model)
    AUC.at[i,'Random data'] = _AUC
    AP.at[i,'Random data'] = _AP
    
hist_weights = np.ones(Niter)/Niter
sb.histplot(AUC.melt(),x='value',hue='variable',stat='probability',element='poly'); plt.title(f'RF classification cross-validation, {frac_withheld*100}% withheld');plt.xlabel('AUC')
plt.vlines(AUC['RF'].mean(),0,0.25,'r')
AP.plot.hist(bins=25,weights=hist_weights); plt.title(f'RF classification cross-validation, {frac_withheld*100}% withheld');plt.xlabel('Average precision')
plt.vlines(AP['RF'].mean(),0,0.8,'r')

plt.figure();sb.heatmap(np.mean(C_rf[:390,...],axis=0),xticklabels=['G1','SG2M'],yticklabels=['G1','SG2M'],annot=True)
plt.title(f'RF Confusion matrix, {frac_withheld*100}% withheld, average over {Niter} iterations')

#%% RF: Permutation importance

df_g1s_balanced = rebalance_g1(df_g1s,Ng1)
y_balanced = df_g1s_balanced['G1S_logistic']

forest = RandomForestClassifier(n_estimators=100, random_state=i)
X = df_g1s_balanced.drop(columns='G1S_logistic'); y = df_g1s_balanced['G1S_logistic']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=frac_withheld,random_state=42)
forest.fit(X_train,y_train)
result = permutation_importance(forest,X_test,y_test,n_repeats=1000,random_state=42,n_jobs=2)
forest_importances = pd.Series(result.importances_mean, index=X_train.columns)

top_forest_imp = forest_importances.iloc[forest_importances.argsort()][-10:][::-1]
top_forest_imp_std = result.importances_std[forest_importances.argsort()][-10:][::-1]
top_forest_imp.plot.bar(yerr=top_forest_imp_std)
plt.ylabel("Mean accuracy decrease")
plt.tight_layout()
plt.show()

#%%

# plt.figure()
# sb.barplot(data=imp.melt(value_vars=imp.columns),x='variable',y='value',order=imp.columns[imp.mean(axis=0).values.argsort()[::-1]]);
# plt.xticks(rotation=45);plt.ylabel('Importance')

import os
from sklearn import tree
# tree.plot_tree(rf_random.best_estimator_.estimators_[k])

plt.figure()
# Export as dot file
# tree.plot_tree(forest[0])
tree.plot_tree(forest.estimators_[0],
               feature_names = df_g1s.columns,
                     filled=True,
                     max_depth=1)


# param_dist = {'n_estimators': randint(50,500),
#               'max_depth': randint(1,20)}

# # Create a random forest classifier
# rf = RandomForestClassifier()

# # Use random search to find the best hyperparameters
# rand_search = RandomizedSearchCV(rf, 
#                                  param_distributions = param_dist, 
#                                  n_iter=5, 
#                                  cv=5)

# # Fit the random search object to the data
# rand_search.fit(X_train, y_train)

#%% Compare MLR v RF

plt.figure()
sb.heatmap(C_mlr.mean(axis=0),annot=True,xticklabels=['G1','SG2'],yticklabels=['Pred G1','Pred SG2'])
plt.title('Logistic')
plt.figure()
sb.heatmap(C_rf.mean(axis=0),annot=True,xticklabels=['G1','SG2'],yticklabels=['Pred G1','Pred SG2'])
plt.title('Rand Forest')
plt.savefig('/Users/xies/Desktop/rfm.eps')
