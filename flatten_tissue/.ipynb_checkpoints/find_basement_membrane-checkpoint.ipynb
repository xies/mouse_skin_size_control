# %%
import numpy as np
from skimage import io, util, measure
from scipy.ndimage import gaussian_filter
from scipy import interpolate
import pandas as pd

from os import path
import stackview
import matplotlib.pyplot as plt

def make_image_from_heightmap(heightmap,maxZ):
    # Reconstruct flattened movie
    heightmap[heightmap >=maxZ] = maxZ-1
    YY,XX = heightmap.shape
    # Iz[Iz >= ZZ] = ZZ-1
    # NB: tried using np.take and np.choose, doesn't work bc of size limit. DO NOT use np.take
    height_image = np.zeros((maxZ,YY,XX),dtype=np.uint16)
    for x in range(XX):
        for y in range(XX):
            height_image[heightmap[y,x],y,x] = 1
    return height_image

def get_z_gradient(imblur,sign):
    _tmp = imblur.copy().astype(float)
    _tmp[np.isnan(_tmp)] = 0
    _tmp_diff = sign * np.diff(_tmp,axis=0)
    
    return _tmp_diff

def find_z_of_maximal_gradient(im_diff,z_shift):
    ZZ,YY,XX = imstack.shape
    
    idx = np.zeros((YY,XX))
    for x in range(XX):
        for y in range(YY):
            hits = np.where(im_diff[:,y,x] > 10)[0]
            if len(hits)>0:
                idx[y,x] = hits[0]
    heightmap = idx
    
    Iz = np.round(heightmap + z_shift).astype(int)
    Iz[Iz >= ZZ] = ZZ-1
    return Iz

# %% [markdown]
# # 0. Load stack

# %%
dirname = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Two photon/NMS/Palbo senescence pilot/09-29-2025 Ear palbo pilot/M1tail 3017 H2B FUCCI/Left ear/1. Day 0/R1/'
imstack = io.imread(path.join(dirname,'R_shg_reg_reg.tif'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zp/5k1kvm9j0t19cvq8h628kr8h0000gn/T/ipykernel_40713/3639037165.py in ?()
#       1 dirname = '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Two photon/NMS/Palbo senescence pilot/09-29-2025 Ear palbo pilot/M1tail 3017 H2B FUCCI/Left ear/1. Day 0/R1/'
# ----> 2 imstack = io.imread(path.join(dirname,'R_shg_reg.tif'))
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/skimage/_shared/utils.py in ?(*args, **kwargs)
#     324                 elif self.new_name is not None:
#     325                     # Assign old value to new one
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/skimage/io/_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      78         if fname.lower().endswith(('.tiff', '.tif')):
#      79             plugin = 'tifffile'
#      80
#      81     with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      83
#      84     if not hasattr(img, 'ndim'):
#      85         return img
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/skimage/_shared/utils.py in ?(*args, **kwargs)
#     534         @functools.wraps(func)
#     535         def wrapped(*args, **kwargs):
#     536             stacklevel = 1 + self.get_stack_length(func) - stack_rank
#     537             warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 538             return func(*args, **kwargs)
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/skimage/io/manage_plugins.py in ?(kind, *args, **kwargs)
#     250             func = [f for (p, f) in plugin_funcs if p == plugin][0]
#     251         except IndexError:
#     252             raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
#     253
# --> 254     return func(*args, **kwargs)
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/skimage/io/_plugins/tifffile_plugin.py in ?(fname, **kwargs)
#      70     """
#      71     if 'img_num' in kwargs:
#      72         kwargs['key'] = kwargs.pop('img_num')
#      73
# ---> 74     return tifffile_imread(fname, **kwargs)
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1163         ):
#    1164             files = files[0]
#    1165
#    1166         if isinstance(files, str) or not isinstance(files, Sequence):
# -> 1167             with TiffFile(
#    1168                 files,
#    1169                 mode=mode,
#    1170                 name=name,
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    4245                 raise ValueError('invalid OME-XML')
#    4246             self._omexml = omexml
#    4247             self.is_ome = True
#    4248
# -> 4249         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4250         self._fh = fh
#    4251         self._multifile = True if _multifile is None else bool(_multifile)
#    4252         self._files = {fh.name: self}
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size)
#   13355         self._offset = -1 if offset is None else offset
#   13356         self._size = -1 if size is None else size
#   13357         self._close = True
#   13358         self._lock = NullContext()
# > 13359         self.open()
#   13360         assert self._fh is not None
#
# /opt/miniconda3/envs/jupyter/lib/python3.12/site-packages/tifffile/tifffile.py in ?(self)
#   13374             if self._mode not in {'rb', 'r+b', 'wb', 'xb'}:
#   13375                 raise ValueError(f'invalid mode {self._mode}')
#   13376             self._file = os.path.realpath(self._file)
#   13377             self._dir, self._name = os.path.split(self._file)
# > 13378             self._fh = open(self._file, self._mode, encoding=None)
#   13379             self._close = True
#   13380             self._offset = max(0, self._offset)
#   13381         elif isinstance(self._file, FileHandle):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/xies/Library/CloudStorage/OneDrive-Stanford/Skin/Two photon/NMS/Palbo senescence pilot/09-29-2025 Ear palbo pilot/M1tail 3017 H2B FUCCI/Left ear/1. Day 0/R1/R_shg_reg.tif'

# %% [markdown]
# # 1. Tune parameters and calculate preliminary mesh

# %%
ZZ,YY,XX = imstack.shape

# Pixels to blur in XY or Z
XY_sigma = 10
Z_sigma = 5

im_z_blur = gaussian_filter(imstack,sigma=[Z_sigma,XY_sigma,XY_sigma])

# %%
cropper = stackview.crop(im_z_blur.transpose(),zoom_factor=0.5)
cropper
# Out:
# _Cropper(children=(HBox(children=(VBox(children=(VBox(children=(IntRangeSlider(value=(0, 1024), description='Z…

# %%
# Crop along the z-axis, and save the crop range for padding later
Z_top = cropper.range[2].start
Z_bottom = cropper.range[2].stop
cropped_blur = im_z_blur[cropper.range[2],...]

# %%
# Set sign to +1 if using 'collagen only' and -1 if keratinocytes only
sign = +1

# How much to 'shift up or down' (NB: +z is down)
z_shift = 5

im_diff = get_z_gradient(cropped_blur,sign)
Iz = find_z_of_maximal_gradient(im_diff,z_shift)
Iz += Z_top

stackview.imshow(Iz.astype(np.int8),axes=True,colormap='pure_magenta',colorbar=True)

# %%
# Reconstruct the height image
height_image = make_image_from_heightmap(Iz + Z_top,ZZ)
stackview.switch(
    {'image': imstack,
     'height_image':height_image,},
    colormap=["pure_magenta", "pure_green"],
    toggleable=True,
    zoom_factor=0.5,
)
# Out:
# HBox(children=(VBox(children=(VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=512, width=512),…

# %% [markdown]
# # Repair any holes

# %%
# Find the single connected region with the largest area, from which to 
# reconstruct the basal surface
L = measure.label(height_image,connectivity=2)
df = pd.DataFrame(measure.regionprops_table(L,properties=['label','area'])).sort_values('area')
surf_region = df.iloc[-1]['label']

# %%
# interpolate the 'missing' regions
Z,Y,X = np.where(L == surf_region)
grid_y,grid_x = np.meshgrid(range(YY),range(XX))
fixed_heightmap = np.round(
    interpolate.griddata(np.array([Y,X]).T,Z,(grid_y,grid_x), method='linear')).astype(int).T

# Remake the height image
height_image = make_image_from_heightmap(fixed_heightmap,ZZ)

# %%
stackview.switch(
    {'image': imstack,
     'height_image':height_image,},
    colormap=["pure_magenta", "pure_green"],
    toggleable=True,
    zoom_factor=0.5,
)
# Out:
# HBox(children=(VBox(children=(VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=512, width=512),…

# %% [markdown]
# # Save heightmap and height images

# %%
io.imsave(path.join(dirname,'heightmap.tif'), fixed_heightmap.astype(np.uint16),check_contrast=False)
io.imsave(path.join(dirname,'height_image.tif'), height_image.astype(np.uint16),check_contrast=False)

# %% [markdown]
# # Prune for basal cells

# %%
# Load segmentations

_tmp = []

masks = io.imread(path.join(dirname,'G_decon_masks.tif'))

table = pd.DataFrame(measure.regionprops_table(masks,properties={'label','area','centroid','bbox'}))

# Look at each XY coord and look up heightmap
Z = heightmaps[ table['centroid-1'].round().astype(int), table['centroid-1'].round().astype(int) ]
table['Corrected Z'] = table['bbox-0'] - Z

table['Time'] = t

_tmp.append(table)

# %%
df = pd.concat(_tmp)
df.to_excel(path.join(dirname,'pre_gated.xlsx'))

# %%
cluster_lot = stackview.clusterplot(image=viewer,
                     labels=masks,
                     df=df,
                     column_x="area",
                     column_y="aspect_ratio", 
                     zoom_factor=0.5,
                     alpha=0.2)
cluster_plot
